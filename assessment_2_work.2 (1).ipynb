# %% [markdown]
# # simulating the stroke unit

# %%
import numpy as np
import pandas as pd
import random 
import itertools
import math
import matplotlib.pyplot as plt

# %%
import simpy
simpy.__version__
# Out:
# '4.1.1'

# %% [markdown]
# # distribution classes
#
# distribution classes used
# - exponential for IAT (inter arrival time)
# - lognormal for length of stay

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

class Bernoulli:
    '''
    Convenience class for the Bernoulli distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, p, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        p: float
            probability of drawing a 1
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.p = p
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.binomial(n=1, p=self.p, size=size)

# %% [markdown]
# # utility function

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %% [markdown]
# # model parameters

# %%
# resource counts
N_BEDS = 10

# time between arrivals in days (exponential)
MEAN_IAT_STROKE = 1.2
MEAN_IAT_TIA = 9.3
MEAN_IAT_CN = 3.6
MEAN_IAT_OTHER = 3.2

# acute stroke unit length of stay in days (lognormal)
STAY_MEAN = 7.4
STAY_STD = 1.2

# transfer (bernoulli)
PROB_ESD = 0.13

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = True

if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %%
class Scenario:
    '''
    Parameter container class for acute stroke unit model.
    '''
    def __init__(self, 
                 iat_stroke = MEAN_IAT_STROKE,
                 iat_tia = MEAN_IAT_TIA,
                 iat_cn = MEAN_IAT_CN,
                 iat_other = MEAN_IAT_OTHER, 
                 name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        
        # optional name
        self.name = name
        
        # beds
        self.unit_beds = N_BEDS

        #store the parameters 
        self.iat_stroke = iat_stroke
        self.iat_tia = iat_tia
        self.iat_cn = iat_cn
        self.iat_other = iat_other

        #initialise results to zero
        self.init_results_variables()
        #Initialise patient arrival distribution
        self.init_sampling()
        self.patients = []
        

        # assessment distribution
        self.length_of_stay_dist = Lognormal(STAY_MEAN, STAY_STD, 
                                         random_seed=SEEDS[4])
        
        # ESD transfer: prob that patient goes to ESD.
        self.esd_transfer = Bernoulli(PROB_ESD, random_seed=SEEDS[5])
        
    def init_sampling(self):
    # inter-arrival distribution for different patient types
        self.arrival_dist = {
            "Stroke": Exponential(MEAN_IAT_STROKE, random_seed=SEEDS[0]),
            "TIA": Exponential(MEAN_IAT_TIA, random_seed=SEEDS[1]),
            "ComplexNeuro": Exponential(MEAN_IAT_CN, random_seed=SEEDS[2]),
            "Other": Exponential(MEAN_IAT_OTHER, random_seed=SEEDS[3]),
        }

    def init_results_variables(self):
        self.results = {}
        self.results["n_stroke"] = 0
        self.results["n_tia"] = 0
        self.results["n_cn"] = 0
        self.results["n_other"] = 0

# %% [markdown]
# # build the model

# %% [markdown]
# ## model the unit
# ## Arrival Generator per patient_type
# Function which creates an arrival generator per patient type. Therefore, 4 functions for each patient entering the Acute Stroke Unit.
#
# !!! Note to self: code redundancy can be fixed by creating one arrival generator but this is better to do after making sure the model runs properly.

# %%
class AcuteStrokeUnit:  
    '''
    Model of an acute stroke unit
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []

        # Start the arrival processes for different patient types
        env.process(self.stroke_arrivals_generator())
        env.process(self.tia_arrivals_generator())
        env.process(self.complexneuro_arrivals_generator())
        env.process(self.other_arrivals_generator())

        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''
        args.unit_beds = simpy.Resource(self.env, 
                                          capacity=args.unit_beds)  

    def start_patient_arrivals(self):
        '''Start arrival processes for all patient types'''
        self.env.process(self.stroke_arrivals_generator())
        self.env.process(self.tia_arrivals_generator())
        self.env.process(self.complexneuro_arrivals_generator())
        self.env.process(self.other_arrivals_generator())

    def stroke_arrivals_generator(self):
        """Arrival process for stroke patients."""
        patient_count = 0
        while True:
            inter_arrival_time = self.args.arrival_dist["Stroke"].sample()
            yield self.env.timeout(inter_arrival_time)
            patient_count += 1
            new_patient = AcutePatient(patient_count, self.env, self.args, patient_type="Stroke")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
            trace(f'STROKE arrival at: {self.env.now:.3f}')

    def tia_arrivals_generator(self):
        """Arrival process for TIA patients."""
        patient_count = 0
        while True:
            inter_arrival_time = self.args.arrival_dist["TIA"].sample()
            yield self.env.timeout(inter_arrival_time)
            patient_count += 1
            new_patient = AcutePatient(patient_count, self.env, self.args, patient_type="TIA")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
            trace(f'TIA arrival at: {self.env.now:.3f}')

    def complexneuro_arrivals_generator(self):
        """Arrival process for ComplexNeuro patients."""
        patient_count = 0
        while True:
            inter_arrival_time = self.args.arrival_dist["ComplexNeuro"].sample()
            yield self.env.timeout(inter_arrival_time)
            patient_count += 1
            new_patient = AcutePatient(patient_count, self.env, self.args, patient_type="ComplexNeuro")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
            trace(f'ComplexNeuro arrival at: {self.env.now:.3f}')

    def other_arrivals_generator(self):
        """Arrival process for Other patients."""
        patient_count = 0
        while True:
            inter_arrival_time = self.args.arrival_dist["Other"].sample()
            yield self.env.timeout(inter_arrival_time)
            patient_count += 1
            new_patient = AcutePatient(patient_count, self.env, self.args, patient_type="Other")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
            trace(f'Other arrival at: {self.env.now:.3f}')

# %% [markdown]
# ## model the patient

# %%
class AcutePatient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args, patient_type):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env
        self.patient_type = patient_type  # Track patient category
        
        

        # stroke unit parameters
        self.unit_beds = args.unit_beds
        self.length_of_stay_dist = args.length_of_stay_dist
        
        # esd transfer: prob that patient is transfered to ESD.
        self.esd_transfer = args.esd_transfer
                
        # individual patient metrics
        self.time_to_bed = 0.0
        self.time_to_esd = 0.0
        self.time_in_system = 0.0
        self.four_hour_target = 0.0
    
    def assessment(self):
        '''
        simulates the process for acute stroke unit
        
        1. Patient enters the system and requests a bed
        2. Wait for bed availability and simulate length of stay
        3. Calculate time in system, ESD transfer, and if the 4-hour target is met
        
        '''
        # record the time that patient entered the system
        arrival_time = self.env.now
    
        # Request a bed from the stroke unit
        with self.unit_beds.request() as req:
            yield req
            
            # Record when the patient gets the bed
            trace(f'Patient {self.identifier} ({self.patient_type}) gets a bed at {self.env.now:.3f}')
            
            # Calculate time to bed (how long the patient waited for a bed)
            self.time_to_bed = self.env.now - arrival_time
            
            # Simulate the patient's length of stay in the acute unit
            length_of_stay = self.length_of_stay_dist.sample()
            
            # Simulate the time the patient spends in the unit
            yield self.env.timeout(length_of_stay)
            
            # Calculate the total time the patient spends in the system (arrival to discharge)
            self.time_in_system = self.env.now - arrival_time
           
            # Log the patient's departure and the total time in the system
            trace(f'Patient {self.identifier} departs at {self.env.now:.3f}; '
                  f'Time in system: {self.time_in_system:.3f}')
    
            # Check if the patient met the 4-hour target (240 minutes)
            if self.time_in_system <= (4 * 60):  # 4 hours = 240 minutes
                self.four_hour_target = 1  # Patient met the target
            else:
                self.four_hour_target = 0  # Patient exceeded the target
            
            # Check if the patient is transferred to the ESD (Early Supported Discharge)
            if self.esd_transfer.sample():
                self.time_to_esd = self.env.now
                trace(f'Patient {self.identifier} transferred to ESD at {self.env.now:.3f}')
            
            # Final discharge time log
            trace(f'Patient {self.identifier} discharged at {self.env.now:.3f}')

# %% [markdown]
# # script to run the model

# %%
# run length in minutes
RUN_LENGTH = 1445

# Define trace as on/off
#TRACE = False
TRACE = True 

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()
# reset all results variables to zero and empty
default_args.init_results_variables()

# create the model
model = AcuteStrokeUnit(env, default_args)

# we pass all arrival generators to simpy 
env.process(model.stroke_arrivals_generator())  # Calling as a method of the model instance
env.process(model.tia_arrivals_generator())    # Calling as a method of the model instance
env.process(model.complexneuro_arrivals_generator())  # Calling as a method of the model instance
env.process(model.other_arrivals_generator())  # Calling as a method of the model instance



env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')
scenario = Scenario()  # Create an instance
print(scenario.results)  # Access and print the results dictionary
# Out:
# Other arrival at: 1.333
# Patient 1 (Other) gets a bed at 1.333
# Other arrival at: 1.569
# Patient 2 (Other) gets a bed at 1.569
# Other arrival at: 2.721
# Patient 3 (Other) gets a bed at 2.721
# STROKE arrival at: 2.803
# Patient 1 (Stroke) gets a bed at 2.803
# STROKE arrival at: 2.885
# Patient 1 (Stroke) gets a bed at 2.885
# STROKE arrival at: 3.221
# Patient 2 (Stroke) gets a bed at 3.221
# STROKE arrival at: 3.325
# Patient 3 (Stroke) gets a bed at 3.325
# Other arrival at: 3.388
# Patient 1 (Other) gets a bed at 3.388
# ComplexNeuro arrival at: 4.199
# Patient 1 (ComplexNeuro) gets a bed at 4.199
# ComplexNeuro arrival at: 4.530
# Patient 2 (ComplexNeuro) gets a bed at 4.530
# Other arrival at: 4.931
# STROKE arrival at: 5.068
# Other arrival at: 5.160
# Other arrival at: 5.294
# TIA arrival at: 5.377
# STROKE arrival at: 5.665
# Other arrival at: 6.208
# Other arrival at: 6.338
# STROKE arrival at: 6.760
# STROKE arrival at: 6.855
# ComplexNeuro arrival at: 6.935
# ComplexNeuro arrival at: 7.757
# ComplexNeuro arrival at: 7.908
# STROKE arrival at: 8.111
# Patient 1 departs at 8.187; Time in system: 6.854
# Patient 1 discharged at 8.187
# Patient 2 (Other) gets a bed at 8.187
# STROKE arrival at: 8.195
# ComplexNeuro arrival at: 9.065
# Patient 2 departs at 9.203; Time in system: 7.634
# Patient 2 discharged at 9.203
# Patient 4 (Stroke) gets a bed at 9.203
# Patient 1 departs at 9.225; Time in system: 6.421
# Patient 1 discharged at 9.225
# Patient 4 (Other) gets a bed at 9.225
# STROKE arrival at: 9.414
# STROKE arrival at: 9.502
# Patient 1 departs at 9.560; Time in system: 6.675
# Patient 1 discharged at 9.560
# Patient 3 (Other) gets a bed at 9.560
# Patient 3 departs at 9.915; Time in system: 6.590
# Patient 3 discharged at 9.915
# Patient 1 (TIA) gets a bed at 9.915
# STROKE arrival at: 9.966
# Other arrival at: 10.153
# Patient 3 departs at 10.344; Time in system: 7.623
# Patient 3 transferred to ESD at 10.344
# Patient 3 discharged at 10.344
# Patient 2 (Stroke) gets a bed at 10.344
# Other arrival at: 10.350
# STROKE arrival at: 11.444
# STROKE arrival at: 11.492
# STROKE arrival at: 11.602
# STROKE arrival at: 11.629
# Patient 2 departs at 11.671; Time in system: 8.450
# Patient 2 discharged at 11.671
# Patient 4 (Other) gets a bed at 11.671
# Patient 1 departs at 11.915; Time in system: 8.527
# Patient 1 discharged at 11.915
# Patient 5 (Other) gets a bed at 11.915
# STROKE arrival at: 11.980
# ComplexNeuro arrival at: 11.981
# Patient 1 departs at 12.244; Time in system: 8.045
# Patient 1 transferred to ESD at 12.244
# Patient 1 discharged at 12.244
# Patient 5 (Stroke) gets a bed at 12.244
# STROKE arrival at: 12.476
# ComplexNeuro arrival at: 12.661
# STROKE arrival at: 12.710
# Patient 2 departs at 12.818; Time in system: 8.288
# Patient 2 discharged at 12.818
# Patient 6 (Stroke) gets a bed at 12.818
# STROKE arrival at: 12.978
# ComplexNeuro arrival at: 13.071
# Other arrival at: 13.631
# STROKE arrival at: 13.972
# TIA arrival at: 14.271
# Other arrival at: 14.328
# Other arrival at: 14.820
# Patient 2 departs at 14.951; Time in system: 10.019
# Patient 2 discharged at 14.951
# Patient 3 (ComplexNeuro) gets a bed at 14.951
# Other arrival at: 15.097
# STROKE arrival at: 15.184
# ComplexNeuro arrival at: 15.372
# STROKE arrival at: 15.445
# STROKE arrival at: 15.945
# STROKE arrival at: 15.971
# STROKE arrival at: 16.063
# STROKE arrival at: 16.279
# Patient 3 departs at 16.310; Time in system: 11.016
# Patient 3 discharged at 16.310
# Patient 1 (ComplexNeuro) gets a bed at 16.310
# STROKE arrival at: 16.489
# Patient 4 departs at 16.754; Time in system: 11.593
# Patient 4 discharged at 16.754
# Patient 4 (ComplexNeuro) gets a bed at 16.754
# STROKE arrival at: 16.956
# STROKE arrival at: 17.101
# Patient 2 departs at 17.299; Time in system: 11.634
# Patient 2 discharged at 17.299
# Patient 7 (Stroke) gets a bed at 17.299
# Patient 1 departs at 17.695; Time in system: 12.318
# Patient 1 discharged at 17.695
# Patient 8 (Stroke) gets a bed at 17.695
# STROKE arrival at: 17.952
# Patient 4 departs at 17.968; Time in system: 12.900
# Patient 4 discharged at 17.968
# Patient 5 (ComplexNeuro) gets a bed at 17.968
# STROKE arrival at: 18.237
# Patient 5 departs at 18.452; Time in system: 11.692
# Patient 5 discharged at 18.452
# Patient 3 (Stroke) gets a bed at 18.452
# STROKE arrival at: 18.473
# STROKE arrival at: 18.790
# STROKE arrival at: 19.203
# STROKE arrival at: 19.243
# Patient 6 departs at 19.328; Time in system: 12.473
# Patient 6 discharged at 19.328
# Patient 9 (Stroke) gets a bed at 19.328
# Patient 5 departs at 19.513; Time in system: 13.175
# Patient 5 discharged at 19.513
# Patient 10 (Stroke) gets a bed at 19.513
# ComplexNeuro arrival at: 19.579
# STROKE arrival at: 19.589
# Other arrival at: 19.640
# Patient 4 departs at 19.834; Time in system: 13.627
# Patient 4 discharged at 19.834
# Patient 6 (Other) gets a bed at 19.834
# STROKE arrival at: 19.946
# Other arrival at: 20.131
# STROKE arrival at: 20.297
# ComplexNeuro arrival at: 20.714
# Other arrival at: 20.762
# Other arrival at: 21.290
# ComplexNeuro arrival at: 21.312
# STROKE arrival at: 21.546
# STROKE arrival at: 21.966
# Other arrival at: 22.004
# STROKE arrival at: 22.054
# Patient 1 departs at 22.078; Time in system: 14.321
# Patient 1 discharged at 22.078
# Patient 5 (Other) gets a bed at 22.078
# STROKE arrival at: 22.847
# Other arrival at: 22.914
# Patient 3 departs at 23.059; Time in system: 16.125
# Patient 3 discharged at 23.059
# Patient 11 (Stroke) gets a bed at 23.059
# STROKE arrival at: 23.415
# Patient 7 departs at 23.475; Time in system: 15.364
# Patient 7 discharged at 23.475
# Patient 4 (Stroke) gets a bed at 23.475
# ComplexNeuro arrival at: 23.627
# TIA arrival at: 23.875
# ComplexNeuro arrival at: 24.020
# Patient 4 departs at 24.074; Time in system: 16.166
# Patient 4 discharged at 24.074
# Patient 5 (Stroke) gets a bed at 24.074
# STROKE arrival at: 24.472
# Patient 8 departs at 24.541; Time in system: 16.346
# Patient 8 discharged at 24.541
# Patient 12 (Stroke) gets a bed at 24.541
# STROKE arrival at: 24.761
# STROKE arrival at: 24.808
# STROKE arrival at: 25.007
# STROKE arrival at: 25.147
# STROKE arrival at: 25.172
# STROKE arrival at: 25.373
# Patient 3 departs at 25.432; Time in system: 16.018
# Patient 3 discharged at 25.432
# Patient 6 (Stroke) gets a bed at 25.432
# STROKE arrival at: 25.432
# Patient 9 departs at 25.824; Time in system: 16.322
# Patient 9 discharged at 25.824
# Patient 2 (ComplexNeuro) gets a bed at 25.824
# Patient 6 departs at 25.923; Time in system: 15.770
# Patient 6 discharged at 25.923
# Patient 7 (Stroke) gets a bed at 25.923
# Patient 5 departs at 25.926; Time in system: 16.861
# Patient 5 discharged at 25.926
# Patient 3 (ComplexNeuro) gets a bed at 25.926
# STROKE arrival at: 26.951
# STROKE arrival at: 27.627
# STROKE arrival at: 27.968
# Other arrival at: 28.101
# STROKE arrival at: 28.445
# STROKE arrival at: 28.879
# STROKE arrival at: 29.034
# Other arrival at: 29.300
# Patient 10 departs at 29.408; Time in system: 19.442
# Patient 10 discharged at 29.408
# Patient 13 (Stroke) gets a bed at 29.408
# Other arrival at: 29.414
# Patient 4 departs at 29.454; Time in system: 17.962
# Patient 4 discharged at 29.454
# Patient 14 (Stroke) gets a bed at 29.454
# Patient 5 departs at 29.814; Time in system: 19.464
# Patient 5 discharged at 29.814
# Patient 6 (ComplexNeuro) gets a bed at 29.814
# TIA arrival at: 29.827
# STROKE arrival at: 30.227
# STROKE arrival at: 30.334
# Patient 12 departs at 30.792; Time in system: 19.164
# Patient 12 transferred to ESD at 30.792
# Patient 12 discharged at 30.792
# Patient 7 (Other) gets a bed at 30.792
# ComplexNeuro arrival at: 31.602
# STROKE arrival at: 31.878
# STROKE arrival at: 32.144
# Patient 11 departs at 32.376; Time in system: 20.932
# Patient 11 discharged at 32.376
# Patient 8 (Stroke) gets a bed at 32.376
# Patient 2 departs at 32.416; Time in system: 20.435
# Patient 2 discharged at 32.416
# Patient 2 (TIA) gets a bed at 32.416
# Patient 5 departs at 33.024; Time in system: 21.422
# Patient 5 discharged at 33.024
# Patient 8 (Other) gets a bed at 33.024
# Patient 3 departs at 33.086; Time in system: 20.425
# Patient 3 discharged at 33.086
# Patient 6 (Other) gets a bed at 33.086
# TIA arrival at: 33.370
# Patient 6 departs at 33.620; Time in system: 21.640
# Patient 6 transferred to ESD at 33.620
# Patient 6 discharged at 33.620
# Patient 7 (Other) gets a bed at 33.620
# ComplexNeuro arrival at: 33.664
# Patient 7 departs at 34.342; Time in system: 21.867
# Patient 7 discharged at 34.342
# Patient 15 (Stroke) gets a bed at 34.342
# STROKE arrival at: 34.672
# Patient 13 departs at 35.777; Time in system: 23.067
# Patient 13 discharged at 35.777
# Patient 4 (ComplexNeuro) gets a bed at 35.777
# Patient 14 departs at 36.133; Time in system: 23.155
# Patient 14 discharged at 36.133
# Patient 9 (Stroke) gets a bed at 36.133
# STROKE arrival at: 36.646
# Patient 8 departs at 37.390; Time in system: 23.417
# Patient 8 discharged at 37.390
# Patient 10 (Stroke) gets a bed at 37.390
# STROKE arrival at: 37.898
# TIA arrival at: 38.034
# Other arrival at: 38.083
# STROKE arrival at: 38.250
# STROKE arrival at: 38.304
# STROKE arrival at: 38.609
# Patient 6 departs at 38.851; Time in system: 25.779
# Patient 6 transferred to ESD at 38.851
# Patient 6 discharged at 38.851
# Patient 16 (Stroke) gets a bed at 38.851
# Other arrival at: 38.871
# Patient 8 departs at 39.107; Time in system: 24.779
# Patient 8 discharged at 39.107
# Patient 17 (Stroke) gets a bed at 39.107
# STROKE arrival at: 39.354
# Patient 2 departs at 39.417; Time in system: 25.147
# Patient 2 discharged at 39.417
# Patient 18 (Stroke) gets a bed at 39.417
# STROKE arrival at: 39.451
# ComplexNeuro arrival at: 39.865
# Patient 6 departs at 40.175; Time in system: 25.354
# Patient 6 transferred to ESD at 40.175
# Patient 6 discharged at 40.175
# Patient 11 (Stroke) gets a bed at 40.175
# Patient 15 departs at 41.141; Time in system: 25.957
# Patient 15 discharged at 41.141
# Patient 12 (Stroke) gets a bed at 41.141
# STROKE arrival at: 41.164
# Patient 7 departs at 41.278; Time in system: 27.647
# Patient 7 discharged at 41.278
# Patient 19 (Stroke) gets a bed at 41.278
# STROKE arrival at: 41.563
# STROKE arrival at: 41.622
# Patient 4 departs at 41.671; Time in system: 26.300
# Patient 4 discharged at 41.671
# Patient 20 (Stroke) gets a bed at 41.671
# STROKE arrival at: 41.885
# Other arrival at: 41.911
# Patient 7 departs at 42.263; Time in system: 27.166
# Patient 7 discharged at 42.263
# Patient 21 (Stroke) gets a bed at 42.263
# STROKE arrival at: 42.732
# Other arrival at: 42.908
# Patient 9 departs at 43.132; Time in system: 27.687
# Patient 9 discharged at 43.132
# Patient 13 (Stroke) gets a bed at 43.132
# ComplexNeuro arrival at: 43.316
# Patient 10 departs at 43.600; Time in system: 27.655
# Patient 10 discharged at 43.600
# Patient 22 (Stroke) gets a bed at 43.600
# Other arrival at: 43.610
# STROKE arrival at: 43.717
# ComplexNeuro arrival at: 43.766
# TIA arrival at: 43.834
# Other arrival at: 44.432
# Other arrival at: 44.655
# STROKE arrival at: 44.949
# Patient 17 departs at 45.026; Time in system: 28.963
# Patient 17 discharged at 45.026
# Patient 23 (Stroke) gets a bed at 45.026
# STROKE arrival at: 45.853
# STROKE arrival at: 46.274
# STROKE arrival at: 46.621
# Patient 16 departs at 46.629; Time in system: 30.658
# Patient 16 discharged at 46.629
# Patient 14 (Stroke) gets a bed at 46.629
# STROKE arrival at: 46.782
# STROKE arrival at: 46.953
# ComplexNeuro arrival at: 47.010
# STROKE arrival at: 47.094
# STROKE arrival at: 47.160
# STROKE arrival at: 47.430
# Patient 11 departs at 47.487; Time in system: 30.998
# Patient 11 discharged at 47.487
# Patient 5 (ComplexNeuro) gets a bed at 47.487
# Patient 18 departs at 47.778; Time in system: 31.499
# Patient 18 discharged at 47.778
# Patient 24 (Stroke) gets a bed at 47.778
# ComplexNeuro arrival at: 47.900
# STROKE arrival at: 47.968
# Other arrival at: 47.977
# Patient 12 departs at 48.220; Time in system: 31.264
# Patient 12 discharged at 48.220
# Patient 9 (Other) gets a bed at 48.220
# STROKE arrival at: 48.431
# Patient 19 departs at 48.573; Time in system: 31.471
# Patient 19 transferred to ESD at 48.573
# Patient 19 discharged at 48.573
# Patient 25 (Stroke) gets a bed at 48.573
# STROKE arrival at: 49.220
# Other arrival at: 49.333
# ComplexNeuro arrival at: 49.433
# STROKE arrival at: 49.445
# STROKE arrival at: 49.553
# Patient 21 departs at 49.787; Time in system: 31.550
# Patient 21 discharged at 49.787
# Patient 8 (Other) gets a bed at 49.787
# ComplexNeuro arrival at: 51.077
# STROKE arrival at: 51.104
# Patient 20 departs at 51.185; Time in system: 33.234
# Patient 20 discharged at 51.185
# Patient 15 (Stroke) gets a bed at 51.185
# STROKE arrival at: 51.499
# STROKE arrival at: 51.739
# STROKE arrival at: 51.747
# ComplexNeuro arrival at: 51.760
# STROKE arrival at: 52.112
# STROKE arrival at: 52.203
# STROKE arrival at: 52.377
# Patient 22 departs at 52.499; Time in system: 33.709
# Patient 22 discharged at 52.499
# Patient 6 (ComplexNeuro) gets a bed at 52.499
# Patient 13 departs at 52.565; Time in system: 34.093
# Patient 13 discharged at 52.565
# Patient 9 (Other) gets a bed at 52.565
# ComplexNeuro arrival at: 52.787
# STROKE arrival at: 52.808
# Other arrival at: 52.837
# Patient 14 departs at 52.848; Time in system: 33.606
# Patient 14 discharged at 52.848
# Patient 10 (Other) gets a bed at 52.848
# Patient 23 departs at 52.935; Time in system: 33.732
# Patient 23 transferred to ESD at 52.935
# Patient 23 discharged at 52.935
# Patient 7 (ComplexNeuro) gets a bed at 52.935
# ComplexNeuro arrival at: 53.464
# Patient 25 departs at 53.638; Time in system: 33.692
# Patient 25 discharged at 53.638
# Patient 26 (Stroke) gets a bed at 53.638
# STROKE arrival at: 54.018
# ComplexNeuro arrival at: 54.322
# Patient 9 departs at 54.841; Time in system: 35.201
# Patient 9 discharged at 54.841
# Patient 16 (Stroke) gets a bed at 54.841
# Other arrival at: 54.934
# STROKE arrival at: 55.079
# Patient 5 departs at 55.468; Time in system: 35.889
# Patient 5 discharged at 55.468
# Patient 11 (Other) gets a bed at 55.468
# Patient 8 departs at 55.721; Time in system: 35.590
# Patient 8 transferred to ESD at 55.721
# Patient 8 discharged at 55.721
# Patient 17 (Stroke) gets a bed at 55.721
# Other arrival at: 55.795
# Patient 24 departs at 56.009; Time in system: 36.420
# Patient 24 discharged at 56.009
# Patient 27 (Stroke) gets a bed at 56.009
# Other arrival at: 56.653
# ComplexNeuro arrival at: 56.850
# Other arrival at: 57.201
# ComplexNeuro arrival at: 57.378
# STROKE arrival at: 57.535
# STROKE arrival at: 57.717
# TIA arrival at: 58.715
# STROKE arrival at: 58.876
# Patient 9 departs at 59.459; Time in system: 38.697
# Patient 9 discharged at 59.459
# Patient 12 (Other) gets a bed at 59.459
# Patient 15 departs at 59.499; Time in system: 39.202
# Patient 15 discharged at 59.499
# Patient 18 (Stroke) gets a bed at 59.499
# STROKE arrival at: 59.748
# Patient 6 departs at 59.764; Time in system: 39.050
# Patient 6 discharged at 59.764
# Patient 8 (ComplexNeuro) gets a bed at 59.764
# Patient 10 departs at 59.921; Time in system: 38.632
# Patient 10 discharged at 59.921
# Patient 3 (TIA) gets a bed at 59.921
# STROKE arrival at: 59.938
# STROKE arrival at: 60.394
# ComplexNeuro arrival at: 60.536
# Other arrival at: 60.608
# ComplexNeuro arrival at: 60.618
# STROKE arrival at: 60.657
# STROKE arrival at: 61.030
# STROKE arrival at: 61.198
# Patient 7 departs at 61.303; Time in system: 39.991
# Patient 7 discharged at 61.303
# Patient 7 (ComplexNeuro) gets a bed at 61.303
# STROKE arrival at: 61.424
# STROKE arrival at: 61.796
# Patient 26 departs at 62.055; Time in system: 40.509
# Patient 26 discharged at 62.055
# Patient 28 (Stroke) gets a bed at 62.055
# Other arrival at: 62.320
# STROKE arrival at: 62.957
# Patient 11 departs at 63.120; Time in system: 41.116
# Patient 11 discharged at 63.120
# Patient 19 (Stroke) gets a bed at 63.120
# Patient 27 departs at 63.210; Time in system: 40.363
# Patient 27 discharged at 63.210
# Patient 29 (Stroke) gets a bed at 63.210
# STROKE arrival at: 63.231
# STROKE arrival at: 63.454
# Patient 16 departs at 63.748; Time in system: 41.781
# Patient 16 transferred to ESD at 63.748
# Patient 16 discharged at 63.748
# Patient 30 (Stroke) gets a bed at 63.748
# STROKE arrival at: 64.052
# Patient 17 departs at 65.036; Time in system: 42.982
# Patient 17 discharged at 65.036
# Patient 20 (Stroke) gets a bed at 65.036
# ComplexNeuro arrival at: 65.080
# Patient 3 departs at 65.677; Time in system: 41.802
# Patient 3 discharged at 65.677
# Patient 21 (Stroke) gets a bed at 65.677
# STROKE arrival at: 65.902
# ComplexNeuro arrival at: 65.925
# STROKE arrival at: 66.045
# Patient 18 departs at 66.066; Time in system: 42.651
# Patient 18 discharged at 66.066
# Patient 22 (Stroke) gets a bed at 66.066
# ComplexNeuro arrival at: 66.123
# STROKE arrival at: 66.250
# TIA arrival at: 66.432
# ComplexNeuro arrival at: 66.953
# STROKE arrival at: 67.308
# Patient 8 departs at 67.317; Time in system: 43.690
# Patient 8 transferred to ESD at 67.317
# Patient 8 discharged at 67.317
# Patient 31 (Stroke) gets a bed at 67.317
# ComplexNeuro arrival at: 67.480
# ComplexNeuro arrival at: 67.509
# STROKE arrival at: 67.678
# STROKE arrival at: 67.826
# STROKE arrival at: 67.853
# STROKE arrival at: 67.938
# Patient 12 departs at 68.226; Time in system: 45.313
# Patient 12 discharged at 68.226
# Patient 23 (Stroke) gets a bed at 68.226
# STROKE arrival at: 68.306
# Other arrival at: 68.340
# Patient 7 departs at 68.419; Time in system: 44.399
# Patient 7 discharged at 68.419
# Patient 24 (Stroke) gets a bed at 68.419
# Patient 29 departs at 68.873; Time in system: 44.065
# Patient 29 discharged at 68.873
# Patient 25 (Stroke) gets a bed at 68.873
# STROKE arrival at: 69.036
# Patient 28 departs at 69.115; Time in system: 44.643
# Patient 28 discharged at 69.115
# Patient 10 (Other) gets a bed at 69.115
# ComplexNeuro arrival at: 69.324
# STROKE arrival at: 69.389
# STROKE arrival at: 69.444
# STROKE arrival at: 69.472
# Other arrival at: 70.137
# TIA arrival at: 70.264
# STROKE arrival at: 70.441
# TIA arrival at: 70.674
# Patient 19 departs at 70.855; Time in system: 46.094
# Patient 19 discharged at 70.855
# Patient 26 (Stroke) gets a bed at 70.855
# Patient 30 departs at 71.803; Time in system: 46.796
# Patient 30 discharged at 71.803
# Patient 27 (Stroke) gets a bed at 71.803
# STROKE arrival at: 72.227
# Patient 21 departs at 72.519; Time in system: 47.347
# Patient 21 discharged at 72.519
# Patient 28 (Stroke) gets a bed at 72.519
# Patient 20 departs at 72.590; Time in system: 47.443
# Patient 20 discharged at 72.590
# Patient 13 (Other) gets a bed at 72.590
# STROKE arrival at: 72.650
# STROKE arrival at: 72.719
# Patient 22 departs at 73.108; Time in system: 47.735
# Patient 22 discharged at 73.108
# Patient 14 (Other) gets a bed at 73.108
# Other arrival at: 73.528
# Patient 31 departs at 73.622; Time in system: 48.190
# Patient 31 discharged at 73.622
# Patient 4 (TIA) gets a bed at 73.622
# ComplexNeuro arrival at: 73.623
# Other arrival at: 74.473
# STROKE arrival at: 74.662
# ComplexNeuro arrival at: 74.685
# STROKE arrival at: 74.689
# STROKE arrival at: 74.773
# Patient 24 departs at 74.877; Time in system: 47.250
# Patient 24 discharged at 74.877
# Patient 32 (Stroke) gets a bed at 74.877
# Other arrival at: 75.066
# STROKE arrival at: 75.582
# ComplexNeuro arrival at: 75.705
# ComplexNeuro arrival at: 75.942
# Patient 25 departs at 75.951; Time in system: 47.983
# Patient 25 discharged at 75.951
# Patient 29 (Stroke) gets a bed at 75.951
# Patient 23 departs at 76.166; Time in system: 49.215
# Patient 23 transferred to ESD at 76.166
# Patient 23 discharged at 76.166
# Patient 9 (ComplexNeuro) gets a bed at 76.166
# Patient 26 departs at 76.998; Time in system: 48.553
# Patient 26 discharged at 76.998
# Patient 33 (Stroke) gets a bed at 76.998
# Patient 10 departs at 77.254; Time in system: 49.153
# Patient 10 discharged at 77.254
# Patient 30 (Stroke) gets a bed at 77.254
# STROKE arrival at: 77.259
# Other arrival at: 77.417
# STROKE arrival at: 77.551
# ComplexNeuro arrival at: 78.118
# Other arrival at: 78.305
# Other arrival at: 78.678
# Other arrival at: 78.698
# Patient 27 departs at 78.717; Time in system: 49.838
# Patient 27 discharged at 78.717
# Patient 5 (TIA) gets a bed at 78.717
# STROKE arrival at: 78.732
# ComplexNeuro arrival at: 78.745
# Patient 14 departs at 78.869; Time in system: 49.455
# Patient 14 discharged at 78.869
# Patient 10 (ComplexNeuro) gets a bed at 78.869
# STROKE arrival at: 79.076
# Patient 4 departs at 79.661; Time in system: 49.834
# Patient 4 discharged at 79.661
# Patient 31 (Stroke) gets a bed at 79.661
# Patient 13 departs at 80.024; Time in system: 50.724
# Patient 13 discharged at 80.024
# Patient 32 (Stroke) gets a bed at 80.024
# ComplexNeuro arrival at: 80.157
# ComplexNeuro arrival at: 80.213
# ComplexNeuro arrival at: 80.222
# STROKE arrival at: 81.012
# Patient 32 departs at 81.035; Time in system: 50.808
# Patient 32 discharged at 81.035
# Patient 33 (Stroke) gets a bed at 81.035
# Patient 28 departs at 81.117; Time in system: 52.083
# Patient 28 discharged at 81.117
# Patient 1 (TIA) gets a bed at 81.117
# STROKE arrival at: 81.207
# ComplexNeuro arrival at: 81.338
# STROKE arrival at: 81.568
# TIA arrival at: 81.696
# STROKE arrival at: 82.142
# STROKE arrival at: 82.202
# Patient 29 departs at 82.579; Time in system: 52.245
# Patient 29 discharged at 82.579
# Patient 11 (Other) gets a bed at 82.579
# STROKE arrival at: 82.768
# Other arrival at: 82.884
# Patient 30 departs at 82.893; Time in system: 50.750
# Patient 30 discharged at 82.893
# Patient 34 (Stroke) gets a bed at 82.893
# STROKE arrival at: 83.046
# STROKE arrival at: 83.080
# STROKE arrival at: 83.504
# Other arrival at: 83.813
# Patient 33 departs at 83.930; Time in system: 52.052
# Patient 33 discharged at 83.930
# Patient 35 (Stroke) gets a bed at 83.930
# STROKE arrival at: 84.985
# Other arrival at: 85.160
# Patient 9 departs at 85.345; Time in system: 53.743
# Patient 9 discharged at 85.345
# Patient 34 (Stroke) gets a bed at 85.345
# STROKE arrival at: 85.682
# Other arrival at: 85.853
# Patient 5 departs at 86.503; Time in system: 53.133
# Patient 5 discharged at 86.503
# Patient 12 (Other) gets a bed at 86.503
# STROKE arrival at: 86.516
# STROKE arrival at: 86.717
# Patient 10 departs at 86.822; Time in system: 53.158
# Patient 10 discharged at 86.822
# Patient 35 (Stroke) gets a bed at 86.822
# Patient 1 departs at 86.880; Time in system: 48.846
# Patient 1 discharged at 86.880
# Patient 36 (Stroke) gets a bed at 86.880
# Patient 32 departs at 87.620; Time in system: 50.974
# Patient 32 discharged at 87.620
# Patient 8 (ComplexNeuro) gets a bed at 87.620
# Patient 33 departs at 87.745; Time in system: 49.847
# Patient 33 discharged at 87.745
# Patient 36 (Stroke) gets a bed at 87.745
# Patient 31 departs at 87.818; Time in system: 53.146
# Patient 31 discharged at 87.818
# Patient 37 (Stroke) gets a bed at 87.818
# Patient 34 departs at 88.436; Time in system: 50.186
# Patient 34 discharged at 88.436
# Patient 38 (Stroke) gets a bed at 88.436
# Other arrival at: 88.917
# Patient 11 departs at 88.927; Time in system: 50.844
# Patient 11 discharged at 88.927
# Patient 37 (Stroke) gets a bed at 88.927
# STROKE arrival at: 89.767
# STROKE arrival at: 90.059
# STROKE arrival at: 90.205
# ComplexNeuro arrival at: 90.540
# Patient 35 departs at 90.857; Time in system: 52.553
# Patient 35 discharged at 90.857
# Patient 13 (Other) gets a bed at 90.857
# STROKE arrival at: 90.861
# Other arrival at: 90.986
# STROKE arrival at: 91.014
# STROKE arrival at: 91.243
# Other arrival at: 91.376
# Patient 34 departs at 91.862; Time in system: 53.253
# Patient 34 discharged at 91.862
# Patient 39 (Stroke) gets a bed at 91.862
# Other arrival at: 92.154
# Patient 12 departs at 92.787; Time in system: 53.916
# Patient 12 transferred to ESD at 92.787
# Patient 12 discharged at 92.787
# Patient 15 (Other) gets a bed at 92.787
# STROKE arrival at: 92.854
# STROKE arrival at: 93.129
# Patient 35 departs at 93.175; Time in system: 53.820
# Patient 35 discharged at 93.175
# Patient 11 (ComplexNeuro) gets a bed at 93.175
# ComplexNeuro arrival at: 93.398
# STROKE arrival at: 93.475
# STROKE arrival at: 94.007
# STROKE arrival at: 94.033
# ComplexNeuro arrival at: 94.282
# Patient 8 departs at 94.527; Time in system: 54.662
# Patient 8 discharged at 94.527
# Patient 14 (Other) gets a bed at 94.527
# Patient 36 departs at 94.688; Time in system: 55.237
# Patient 36 discharged at 94.688
# Patient 40 (Stroke) gets a bed at 94.688
# STROKE arrival at: 94.906
# Patient 37 departs at 95.108; Time in system: 53.223
# Patient 37 transferred to ESD at 95.108
# Patient 37 discharged at 95.108
# Patient 12 (ComplexNeuro) gets a bed at 95.108
# STROKE arrival at: 95.336
# Patient 37 departs at 95.353; Time in system: 53.791
# Patient 37 discharged at 95.353
# Patient 2 (TIA) gets a bed at 95.353
# Other arrival at: 95.445
# Patient 38 departs at 95.701; Time in system: 54.079
# Patient 38 discharged at 95.701
# Patient 16 (Other) gets a bed at 95.701
# Patient 36 departs at 95.759; Time in system: 54.595
# Patient 36 discharged at 95.759
# Patient 15 (Other) gets a bed at 95.759
# STROKE arrival at: 96.254
# STROKE arrival at: 96.312
# ComplexNeuro arrival at: 96.456
# STROKE arrival at: 96.677
# STROKE arrival at: 96.680
# STROKE arrival at: 97.347
# ComplexNeuro arrival at: 97.694
# Other arrival at: 98.663
# STROKE arrival at: 98.955
# ComplexNeuro arrival at: 99.229
# STROKE arrival at: 99.238
# STROKE arrival at: 99.318
# STROKE arrival at: 99.461
# ComplexNeuro arrival at: 99.476
# ComplexNeuro arrival at: 99.791
# Patient 13 departs at 99.858; Time in system: 57.947
# Patient 13 discharged at 99.858
# Patient 38 (Stroke) gets a bed at 99.858
# Patient 15 departs at 100.114; Time in system: 57.206
# Patient 15 discharged at 100.114
# Patient 39 (Stroke) gets a bed at 100.114
# Patient 11 departs at 100.364; Time in system: 57.048
# Patient 11 discharged at 100.364
# Patient 41 (Stroke) gets a bed at 100.364
# Patient 39 departs at 100.387; Time in system: 57.655
# Patient 39 discharged at 100.387
# Patient 42 (Stroke) gets a bed at 100.387
# STROKE arrival at: 100.689
# Patient 2 departs at 100.720; Time in system: 56.886
# Patient 2 discharged at 100.720
# Patient 43 (Stroke) gets a bed at 100.720
# Other arrival at: 100.823
# Patient 40 departs at 100.910; Time in system: 57.193
# Patient 40 discharged at 100.910
# Patient 44 (Stroke) gets a bed at 100.910
# Other arrival at: 100.929
# STROKE arrival at: 101.162
# Patient 15 departs at 101.489; Time in system: 56.834
# Patient 15 transferred to ESD at 101.489
# Patient 15 discharged at 101.489
# Patient 9 (ComplexNeuro) gets a bed at 101.489
# STROKE arrival at: 101.830
# Patient 16 departs at 102.054; Time in system: 57.622
# Patient 16 discharged at 102.054
# Patient 45 (Stroke) gets a bed at 102.054
# Patient 14 departs at 102.210; Time in system: 58.600
# Patient 14 discharged at 102.210
# Patient 46 (Stroke) gets a bed at 102.210
# STROKE arrival at: 102.587
# STROKE arrival at: 103.053
# Other arrival at: 103.696
# STROKE arrival at: 103.897
# Other arrival at: 103.988
# Patient 12 departs at 104.361; Time in system: 60.595
# Patient 12 discharged at 104.361
# Patient 40 (Stroke) gets a bed at 104.361
# ComplexNeuro arrival at: 104.596
# Patient 42 departs at 105.018; Time in system: 58.397
# Patient 42 discharged at 105.018
# Patient 10 (ComplexNeuro) gets a bed at 105.018
# Other arrival at: 105.557
# STROKE arrival at: 105.758
# STROKE arrival at: 106.553
# STROKE arrival at: 106.662
# Patient 38 departs at 106.734; Time in system: 61.785
# Patient 38 discharged at 106.734
# Patient 41 (Stroke) gets a bed at 106.734
# ComplexNeuro arrival at: 106.840
# ComplexNeuro arrival at: 107.021
# Other arrival at: 107.059
# STROKE arrival at: 107.285
# Other arrival at: 107.394
# Other arrival at: 107.721
# Patient 43 departs at 107.887; Time in system: 61.105
# Patient 43 discharged at 107.887
# Patient 16 (Other) gets a bed at 107.887
# Patient 41 departs at 107.957; Time in system: 61.682
# Patient 41 discharged at 107.957
# Patient 42 (Stroke) gets a bed at 107.957
# Other arrival at: 107.969
# Patient 39 departs at 108.200; Time in system: 62.347
# Patient 39 discharged at 108.200
# Patient 47 (Stroke) gets a bed at 108.200
# STROKE arrival at: 108.301
# ComplexNeuro arrival at: 108.301
# STROKE arrival at: 108.346
# ComplexNeuro arrival at: 108.636
# Patient 44 departs at 109.588; Time in system: 62.634
# Patient 44 discharged at 109.588
# Patient 17 (Other) gets a bed at 109.588
# STROKE arrival at: 109.600
# Patient 45 departs at 109.682; Time in system: 62.588
# Patient 45 discharged at 109.682
# Patient 11 (ComplexNeuro) gets a bed at 109.682
# STROKE arrival at: 109.768
# Patient 9 departs at 109.831; Time in system: 62.822
# Patient 9 discharged at 109.831
# Patient 48 (Stroke) gets a bed at 109.831
# ComplexNeuro arrival at: 110.533
# Patient 46 departs at 110.750; Time in system: 63.590
# Patient 46 discharged at 110.750
# Patient 43 (Stroke) gets a bed at 110.750
# STROKE arrival at: 111.027
# ComplexNeuro arrival at: 111.080
# Other arrival at: 111.221
# STROKE arrival at: 111.229
# STROKE arrival at: 111.367
# Other arrival at: 111.379
# Other arrival at: 111.440
# Patient 40 departs at 111.630; Time in system: 64.201
# Patient 40 discharged at 111.630
# Patient 13 (ComplexNeuro) gets a bed at 111.630
# ComplexNeuro arrival at: 111.657
# STROKE arrival at: 111.696
# Other arrival at: 111.709
# Patient 10 departs at 111.712; Time in system: 63.812
# Patient 10 discharged at 111.712
# Patient 44 (Stroke) gets a bed at 111.712
# STROKE arrival at: 111.714
# STROKE arrival at: 112.198
# Patient 41 departs at 112.330; Time in system: 64.362
# Patient 41 discharged at 112.330
# Patient 45 (Stroke) gets a bed at 112.330
# STROKE arrival at: 112.507
# STROKE arrival at: 113.040
# Other arrival at: 113.193
# Other arrival at: 113.728
# Other arrival at: 113.796
# Patient 42 departs at 114.115; Time in system: 65.683
# Patient 42 transferred to ESD at 114.115
# Patient 42 discharged at 114.115
# Patient 46 (Stroke) gets a bed at 114.115
# Patient 16 departs at 115.045; Time in system: 67.068
# Patient 16 discharged at 115.045
# Patient 49 (Stroke) gets a bed at 115.045
# STROKE arrival at: 115.521
# Patient 47 departs at 115.724; Time in system: 66.504
# Patient 47 discharged at 115.724
# Patient 12 (ComplexNeuro) gets a bed at 115.724
# STROKE arrival at: 115.867
# STROKE arrival at: 116.105
# STROKE arrival at: 116.114
# Patient 48 departs at 116.165; Time in system: 66.720
# Patient 48 discharged at 116.165
# Patient 50 (Stroke) gets a bed at 116.165
# ComplexNeuro arrival at: 116.527
# STROKE arrival at: 116.640
# Patient 11 departs at 116.737; Time in system: 67.304
# Patient 11 discharged at 116.737
# Patient 51 (Stroke) gets a bed at 116.737
# STROKE arrival at: 116.821
# STROKE arrival at: 116.828
# STROKE arrival at: 116.956
# ComplexNeuro arrival at: 116.971
# Patient 43 departs at 117.387; Time in system: 67.833
# Patient 43 discharged at 117.387
# Patient 47 (Stroke) gets a bed at 117.387
# STROKE arrival at: 117.777
# TIA arrival at: 118.725
# Patient 44 departs at 118.914; Time in system: 67.810
# Patient 44 transferred to ESD at 118.914
# Patient 44 discharged at 118.914
# Patient 13 (ComplexNeuro) gets a bed at 118.914
# STROKE arrival at: 118.998
# Patient 17 departs at 119.032; Time in system: 69.698
# Patient 17 discharged at 119.032
# Patient 52 (Stroke) gets a bed at 119.032
# Patient 13 departs at 119.240; Time in system: 68.163
# Patient 13 discharged at 119.240
# Patient 18 (Other) gets a bed at 119.240
# STROKE arrival at: 119.302
# Other arrival at: 119.476
# STROKE arrival at: 119.650
# Patient 45 departs at 119.675; Time in system: 68.176
# Patient 45 discharged at 119.675
# Patient 14 (ComplexNeuro) gets a bed at 119.675
# ComplexNeuro arrival at: 119.911
# Other arrival at: 119.980
# ComplexNeuro arrival at: 120.055
# Other arrival at: 120.649
# ComplexNeuro arrival at: 120.717
# TIA arrival at: 121.098
# STROKE arrival at: 121.733
# Patient 46 departs at 121.742; Time in system: 70.002
# Patient 46 discharged at 121.742
# Patient 53 (Stroke) gets a bed at 121.742
# STROKE arrival at: 122.442
# Patient 49 departs at 122.497; Time in system: 70.750
# Patient 49 discharged at 122.497
# Patient 15 (ComplexNeuro) gets a bed at 122.497
# STROKE arrival at: 122.650
# Patient 51 departs at 122.788; Time in system: 70.585
# Patient 51 discharged at 122.788
# Patient 17 (Other) gets a bed at 122.788
# Other arrival at: 122.821
# ComplexNeuro arrival at: 122.873
# Other arrival at: 122.918
# Patient 12 departs at 122.959; Time in system: 71.199
# Patient 12 transferred to ESD at 122.959
# Patient 12 discharged at 122.959
# Patient 48 (Stroke) gets a bed at 122.959
# Patient 47 departs at 123.000; Time in system: 70.623
# Patient 47 discharged at 123.000
# Patient 18 (Other) gets a bed at 123.000
# STROKE arrival at: 123.079
# Other arrival at: 123.474
# STROKE arrival at: 123.479
# STROKE arrival at: 123.782
# Patient 50 departs at 123.858; Time in system: 71.746
# Patient 50 discharged at 123.858
# Patient 19 (Other) gets a bed at 123.858
# ComplexNeuro arrival at: 124.338
# ComplexNeuro arrival at: 124.442
# Other arrival at: 124.481
# STROKE arrival at: 124.518
# STROKE arrival at: 125.035
# STROKE arrival at: 125.297
# Other arrival at: 125.384
# Other arrival at: 125.398
# Other arrival at: 125.488
# Other arrival at: 125.533
# ComplexNeuro arrival at: 125.995
# STROKE arrival at: 126.074
# ComplexNeuro arrival at: 126.232
# Other arrival at: 126.667
# Other arrival at: 126.668
# STROKE arrival at: 126.837
# Patient 14 departs at 126.863; Time in system: 73.399
# Patient 14 discharged at 126.863
# Patient 16 (ComplexNeuro) gets a bed at 126.863
# Other arrival at: 126.931
# Patient 18 departs at 127.394; Time in system: 74.557
# Patient 18 discharged at 127.394
# Patient 20 (Other) gets a bed at 127.394
# STROKE arrival at: 127.459
# ComplexNeuro arrival at: 127.822
# ComplexNeuro arrival at: 127.895
# Patient 13 departs at 127.913; Time in system: 75.126
# Patient 13 transferred to ESD at 127.913
# Patient 13 discharged at 127.913
# Patient 14 (ComplexNeuro) gets a bed at 127.913
# ComplexNeuro arrival at: 127.932
# STROKE arrival at: 128.091
# STROKE arrival at: 128.132
# TIA arrival at: 128.435
# ComplexNeuro arrival at: 128.454
# Patient 52 departs at 128.552; Time in system: 75.745
# Patient 52 transferred to ESD at 128.552
# Patient 52 discharged at 128.552
# Patient 49 (Stroke) gets a bed at 128.552
# Patient 15 departs at 128.902; Time in system: 74.579
# Patient 15 discharged at 128.902
# Patient 54 (Stroke) gets a bed at 128.902
# STROKE arrival at: 129.137
# Patient 48 departs at 129.169; Time in system: 74.091
# Patient 48 discharged at 129.169
# Patient 6 (TIA) gets a bed at 129.169
# ComplexNeuro arrival at: 129.207
# Patient 53 departs at 129.503; Time in system: 75.485
# Patient 53 discharged at 129.503
# Patient 50 (Stroke) gets a bed at 129.503
# STROKE arrival at: 129.938
# Patient 18 departs at 130.242; Time in system: 74.447
# Patient 18 discharged at 130.242
# Patient 51 (Stroke) gets a bed at 130.242
# STROKE arrival at: 130.465
# STROKE arrival at: 130.698
# STROKE arrival at: 130.752
# Other arrival at: 131.278
# ComplexNeuro arrival at: 131.519
# STROKE arrival at: 131.551
# TIA arrival at: 131.939
# STROKE arrival at: 131.942
# Patient 19 departs at 132.081; Time in system: 75.428
# Patient 19 discharged at 132.081
# Patient 55 (Stroke) gets a bed at 132.081
# Patient 17 departs at 132.380; Time in system: 77.446
# Patient 17 discharged at 132.380
# Patient 56 (Stroke) gets a bed at 132.380
# STROKE arrival at: 133.183
# Other arrival at: 133.352
# STROKE arrival at: 133.662
# Patient 16 departs at 133.843; Time in system: 76.992
# Patient 16 discharged at 133.843
# Patient 17 (ComplexNeuro) gets a bed at 133.843
# Patient 20 departs at 133.888; Time in system: 76.688
# Patient 20 discharged at 133.888
# Patient 21 (Other) gets a bed at 133.888
# STROKE arrival at: 134.140
# Other arrival at: 134.249
# Patient 14 departs at 134.682; Time in system: 77.304
# Patient 14 discharged at 134.682
# Patient 15 (ComplexNeuro) gets a bed at 134.682
# Patient 49 departs at 135.704; Time in system: 78.169
# Patient 49 discharged at 135.704
# Patient 57 (Stroke) gets a bed at 135.704
# STROKE arrival at: 136.746
# STROKE arrival at: 136.818
# Patient 51 departs at 136.831; Time in system: 77.083
# Patient 51 discharged at 136.831
# Patient 52 (Stroke) gets a bed at 136.831
# STROKE arrival at: 136.863
# Patient 6 departs at 136.977; Time in system: 78.262
# Patient 6 discharged at 136.977
# Patient 53 (Stroke) gets a bed at 136.977
# ComplexNeuro arrival at: 137.336
# ComplexNeuro arrival at: 137.503
# Patient 54 departs at 137.588; Time in system: 79.871
# Patient 54 discharged at 137.588
# Patient 54 (Stroke) gets a bed at 137.588
# Patient 50 departs at 138.508; Time in system: 79.632
# Patient 50 discharged at 138.508
# Patient 55 (Stroke) gets a bed at 138.508
# Other arrival at: 138.908
# STROKE arrival at: 139.092
# STROKE arrival at: 139.304
# Patient 56 departs at 139.631; Time in system: 79.237
# Patient 56 discharged at 139.631
# Patient 19 (Other) gets a bed at 139.631
# Patient 55 departs at 139.646; Time in system: 79.708
# Patient 55 discharged at 139.646
# Patient 56 (Stroke) gets a bed at 139.646
# STROKE arrival at: 139.866
# STROKE arrival at: 140.031
# Patient 17 departs at 140.145; Time in system: 79.609
# Patient 17 discharged at 140.145
# Patient 58 (Stroke) gets a bed at 140.145
# Patient 21 departs at 142.004; Time in system: 81.396
# Patient 21 transferred to ESD at 142.004
# Patient 21 discharged at 142.004
# Patient 57 (Stroke) gets a bed at 142.004
# STROKE arrival at: 142.217
# Patient 57 departs at 142.529; Time in system: 81.872
# Patient 57 discharged at 142.529
# Patient 59 (Stroke) gets a bed at 142.529
# Patient 53 departs at 142.578; Time in system: 81.380
# Patient 53 discharged at 142.578
# Patient 16 (ComplexNeuro) gets a bed at 142.578
# TIA arrival at: 142.844
# STROKE arrival at: 143.001
# STROKE arrival at: 143.206
# Patient 52 departs at 143.499; Time in system: 82.469
# Patient 52 discharged at 143.499
# Patient 60 (Stroke) gets a bed at 143.499
# ComplexNeuro arrival at: 144.041
# Patient 15 departs at 144.189; Time in system: 83.572
# Patient 15 discharged at 144.189
# Patient 18 (ComplexNeuro) gets a bed at 144.189
# ComplexNeuro arrival at: 144.290
# STROKE arrival at: 144.419
# Patient 54 departs at 144.538; Time in system: 83.114
# Patient 54 discharged at 144.538
# Patient 58 (Stroke) gets a bed at 144.538
# ComplexNeuro arrival at: 144.638
# Other arrival at: 144.708
# STROKE arrival at: 145.021
# Other arrival at: 145.201
# STROKE arrival at: 145.313
# STROKE arrival at: 145.529
# Other arrival at: 145.544
# Patient 55 departs at 145.593; Time in system: 83.797
# Patient 55 discharged at 145.593
# Patient 17 (ComplexNeuro) gets a bed at 145.593
# Other arrival at: 145.719
# ComplexNeuro arrival at: 145.946
# Other arrival at: 146.074
# TIA arrival at: 146.399
# STROKE arrival at: 146.965
# Patient 57 departs at 147.654; Time in system: 84.201
# Patient 57 discharged at 147.654
# Patient 59 (Stroke) gets a bed at 147.654
# Patient 58 departs at 147.788; Time in system: 84.557
# Patient 58 discharged at 147.788
# Patient 7 (TIA) gets a bed at 147.788
# STROKE arrival at: 148.098
# Patient 16 departs at 148.367; Time in system: 83.287
# Patient 16 discharged at 148.367
# Patient 18 (ComplexNeuro) gets a bed at 148.367
# STROKE arrival at: 148.460
# Other arrival at: 148.806
# Patient 56 departs at 148.876; Time in system: 85.919
# Patient 56 transferred to ESD at 148.876
# Patient 56 discharged at 148.876
# Patient 61 (Stroke) gets a bed at 148.876
# Patient 60 departs at 149.609; Time in system: 83.707
# Patient 60 transferred to ESD at 149.609
# Patient 60 discharged at 149.609
# Patient 19 (ComplexNeuro) gets a bed at 149.609
# STROKE arrival at: 149.691
# ComplexNeuro arrival at: 149.797
# STROKE arrival at: 150.169
# STROKE arrival at: 150.307
# Other arrival at: 150.522
# Patient 19 departs at 150.563; Time in system: 88.243
# Patient 19 discharged at 150.563
# Patient 20 (ComplexNeuro) gets a bed at 150.563
# STROKE arrival at: 150.572
# STROKE arrival at: 150.643
# Patient 18 departs at 150.990; Time in system: 85.065
# Patient 18 discharged at 150.990
# Patient 60 (Stroke) gets a bed at 150.990
# STROKE arrival at: 151.076
# STROKE arrival at: 151.161
# ComplexNeuro arrival at: 151.490
# STROKE arrival at: 151.726
# STROKE arrival at: 152.223
# Other arrival at: 152.266
# Patient 58 departs at 152.303; Time in system: 86.258
# Patient 58 discharged at 152.303
# Patient 61 (Stroke) gets a bed at 152.303
# STROKE arrival at: 152.311
# TIA arrival at: 152.335
# STROKE arrival at: 152.359
# Patient 59 departs at 152.363; Time in system: 88.310
# Patient 59 discharged at 152.363
# Patient 62 (Stroke) gets a bed at 152.363
# STROKE arrival at: 152.722
# TIA arrival at: 152.823
# Patient 17 departs at 152.888; Time in system: 86.765
# Patient 17 discharged at 152.888
# Patient 63 (Stroke) gets a bed at 152.888
# TIA arrival at: 153.978
# STROKE arrival at: 154.158
# STROKE arrival at: 154.399
# Patient 7 departs at 154.594; Time in system: 88.163
# Patient 7 transferred to ESD at 154.594
# Patient 7 discharged at 154.594
# Patient 62 (Stroke) gets a bed at 154.594
# Patient 61 departs at 154.840; Time in system: 87.532
# Patient 61 discharged at 154.840
# Patient 22 (Other) gets a bed at 154.840
# STROKE arrival at: 155.009
# STROKE arrival at: 155.118
# Patient 59 departs at 155.232; Time in system: 88.981
# Patient 59 discharged at 155.232
# Patient 64 (Stroke) gets a bed at 155.232
# STROKE arrival at: 155.259
# STROKE arrival at: 155.272
# Patient 18 departs at 155.917; Time in system: 88.964
# Patient 18 discharged at 155.917
# Patient 19 (ComplexNeuro) gets a bed at 155.917
# TIA arrival at: 155.918
# Patient 19 departs at 155.983; Time in system: 88.503
# Patient 19 transferred to ESD at 155.983
# Patient 19 discharged at 155.983
# Patient 65 (Stroke) gets a bed at 155.983
# STROKE arrival at: 156.016
# STROKE arrival at: 156.442
# Other arrival at: 156.932
# Patient 61 departs at 157.157; Time in system: 89.330
# Patient 61 discharged at 157.157
# Patient 66 (Stroke) gets a bed at 157.157
# STROKE arrival at: 157.211
# STROKE arrival at: 157.273
# STROKE arrival at: 157.489
# Patient 60 departs at 158.163; Time in system: 90.486
# Patient 60 discharged at 158.163
# Patient 63 (Stroke) gets a bed at 158.163
# STROKE arrival at: 158.254
# ComplexNeuro arrival at: 158.355
# STROKE arrival at: 158.909
# STROKE arrival at: 159.000
# STROKE arrival at: 159.130
# Patient 63 departs at 159.607; Time in system: 91.669
# Patient 63 discharged at 159.607
# Patient 23 (Other) gets a bed at 159.607
# STROKE arrival at: 159.725
# STROKE arrival at: 159.878
# STROKE arrival at: 160.269
# Patient 20 departs at 160.376; Time in system: 92.867
# Patient 20 discharged at 160.376
# Patient 8 (TIA) gets a bed at 160.376
# Patient 62 departs at 160.561; Time in system: 92.708
# Patient 62 discharged at 160.561
# Patient 64 (Stroke) gets a bed at 160.561
# STROKE arrival at: 161.009
# STROKE arrival at: 161.059
# ComplexNeuro arrival at: 161.085
# STROKE arrival at: 161.161
# Other arrival at: 161.221
# STROKE arrival at: 161.489
# STROKE arrival at: 161.579
# Patient 66 departs at 161.979; Time in system: 92.535
# Patient 66 discharged at 161.979
# Patient 9 (TIA) gets a bed at 161.979
# Patient 62 departs at 162.106; Time in system: 93.800
# Patient 62 transferred to ESD at 162.106
# Patient 62 discharged at 162.106
# Patient 65 (Stroke) gets a bed at 162.106
# Patient 65 departs at 162.461; Time in system: 93.071
# Patient 65 discharged at 162.461
# Patient 66 (Stroke) gets a bed at 162.461
# Patient 19 departs at 162.479; Time in system: 93.155
# Patient 19 discharged at 162.479
# Patient 67 (Stroke) gets a bed at 162.479
# Other arrival at: 162.577
# Patient 64 departs at 162.583; Time in system: 93.547
# Patient 64 transferred to ESD at 162.583
# Patient 64 discharged at 162.583
# Patient 20 (Other) gets a bed at 162.583
# STROKE arrival at: 162.743
# STROKE arrival at: 162.804
# STROKE arrival at: 163.045
# STROKE arrival at: 163.350
# TIA arrival at: 163.552
# Other arrival at: 163.586
# Patient 22 departs at 163.595; Time in system: 95.255
# Patient 22 discharged at 163.595
# Patient 20 (ComplexNeuro) gets a bed at 163.595
# STROKE arrival at: 163.644
# ComplexNeuro arrival at: 163.824
# STROKE arrival at: 164.952
# ComplexNeuro arrival at: 165.606
# STROKE arrival at: 166.018
# ComplexNeuro arrival at: 166.286
# Patient 8 departs at 166.503; Time in system: 96.239
# Patient 8 discharged at 166.503
# Patient 24 (Other) gets a bed at 166.503
# Patient 63 departs at 166.512; Time in system: 97.040
# Patient 63 transferred to ESD at 166.512
# Patient 63 discharged at 166.512
# Patient 67 (Stroke) gets a bed at 166.512
# Patient 23 departs at 166.586; Time in system: 96.449
# Patient 23 discharged at 166.586
# Patient 21 (ComplexNeuro) gets a bed at 166.586
# ComplexNeuro arrival at: 167.442
# STROKE arrival at: 167.664
# Other arrival at: 169.158
# STROKE arrival at: 169.322
# Patient 66 departs at 169.628; Time in system: 96.978
# Patient 66 discharged at 169.628
# Patient 68 (Stroke) gets a bed at 169.628
# STROKE arrival at: 169.843
# Patient 64 departs at 170.159; Time in system: 99.719
# Patient 64 discharged at 170.159
# Patient 68 (Stroke) gets a bed at 170.159
# Patient 65 departs at 170.884; Time in system: 98.657
# Patient 65 discharged at 170.884
# Patient 21 (Other) gets a bed at 170.884
# STROKE arrival at: 171.159
# Patient 67 departs at 171.196; Time in system: 98.477
# Patient 67 discharged at 171.196
# Patient 69 (Stroke) gets a bed at 171.196
# Patient 20 departs at 171.315; Time in system: 97.787
# Patient 20 discharged at 171.315
# Patient 21 (ComplexNeuro) gets a bed at 171.315
# STROKE arrival at: 171.390
# STROKE arrival at: 171.395
# Other arrival at: 171.504
# STROKE arrival at: 171.595
# Patient 20 departs at 172.129; Time in system: 98.506
# Patient 20 discharged at 172.129
# Patient 22 (ComplexNeuro) gets a bed at 172.129
# Patient 24 departs at 172.166; Time in system: 97.693
# Patient 24 discharged at 172.166
# Patient 70 (Stroke) gets a bed at 172.166
# STROKE arrival at: 172.782
# STROKE arrival at: 172.789
# Patient 9 departs at 172.995; Time in system: 102.321
# Patient 9 discharged at 172.995
# Patient 22 (Other) gets a bed at 172.995
# STROKE arrival at: 173.218
# Patient 21 departs at 173.272; Time in system: 98.587
# Patient 21 discharged at 173.272
# Patient 71 (Stroke) gets a bed at 173.272
# Patient 67 departs at 173.506; Time in system: 98.844
# Patient 67 discharged at 173.506
# Patient 23 (ComplexNeuro) gets a bed at 173.506
# STROKE arrival at: 173.703
# Other arrival at: 173.748
# STROKE arrival at: 174.070
# STROKE arrival at: 174.348
# STROKE arrival at: 174.785
# STROKE arrival at: 174.850
# STROKE arrival at: 174.985
# TIA arrival at: 175.048
# Other arrival at: 175.283
# STROKE arrival at: 175.293
# STROKE arrival at: 175.332
# Patient 68 departs at 175.962; Time in system: 101.273
# Patient 68 transferred to ESD at 175.962
# Patient 68 discharged at 175.962
# Patient 23 (Other) gets a bed at 175.962
# Patient 68 departs at 176.431; Time in system: 101.658
# Patient 68 discharged at 176.431
# Patient 25 (Other) gets a bed at 176.431
# STROKE arrival at: 176.524
# Other arrival at: 176.669
# STROKE arrival at: 176.767
# ComplexNeuro arrival at: 176.934
# STROKE arrival at: 177.213
# Other arrival at: 177.309
# Patient 69 departs at 177.328; Time in system: 101.747
# Patient 69 discharged at 177.328
# Patient 24 (Other) gets a bed at 177.328
# STROKE arrival at: 177.486
# STROKE arrival at: 177.690
# Other arrival at: 177.866
# Patient 22 departs at 178.171; Time in system: 102.229
# Patient 22 discharged at 178.171
# Patient 72 (Stroke) gets a bed at 178.171
# STROKE arrival at: 178.178
# ComplexNeuro arrival at: 178.203
# Other arrival at: 178.273
# Patient 21 departs at 178.481; Time in system: 103.415
# Patient 21 discharged at 178.481
# Patient 22 (ComplexNeuro) gets a bed at 178.481
# Other arrival at: 178.620
# Patient 21 departs at 178.710; Time in system: 103.005
# Patient 21 discharged at 178.710
# Patient 73 (Stroke) gets a bed at 178.710
# Other arrival at: 178.732
# Other arrival at: 178.815
# STROKE arrival at: 178.886
# STROKE arrival at: 179.327
# STROKE arrival at: 179.655
# STROKE arrival at: 180.048
# ComplexNeuro arrival at: 180.172
# Patient 70 departs at 180.757; Time in system: 103.498
# Patient 70 transferred to ESD at 180.757
# Patient 70 discharged at 180.757
# Patient 23 (ComplexNeuro) gets a bed at 180.757
# Patient 23 departs at 181.634; Time in system: 103.517
# Patient 23 discharged at 181.634
# Patient 24 (ComplexNeuro) gets a bed at 181.634
# Other arrival at: 181.941
# Patient 22 departs at 182.179; Time in system: 104.762
# Patient 22 discharged at 182.179
# Patient 25 (ComplexNeuro) gets a bed at 182.179
# Patient 71 departs at 182.213; Time in system: 104.662
# Patient 71 discharged at 182.213
# Patient 74 (Stroke) gets a bed at 182.213
# STROKE arrival at: 182.622
# Patient 24 departs at 182.694; Time in system: 103.997
# Patient 24 discharged at 182.694
# Patient 69 (Stroke) gets a bed at 182.694
# STROKE arrival at: 183.102
# Patient 23 departs at 183.403; Time in system: 105.098
# Patient 23 discharged at 183.403
# Patient 26 (ComplexNeuro) gets a bed at 183.403
# ComplexNeuro arrival at: 183.444
# STROKE arrival at: 183.766
# STROKE arrival at: 183.944
# Other arrival at: 184.127
# Patient 73 departs at 184.454; Time in system: 105.378
# Patient 73 discharged at 184.454
# Patient 75 (Stroke) gets a bed at 184.454
# Other arrival at: 184.494
# STROKE arrival at: 184.500
# ...
# STROKE arrival at: 1386.761
# STROKE arrival at: 1387.589
# Other arrival at: 1387.804
# Patient 179 departs at 1387.904; Time in system: 777.071
# Patient 179 discharged at 1387.904
# Patient 480 (Stroke) gets a bed at 1387.904
# STROKE arrival at: 1387.911
# Other arrival at: 1388.217
# STROKE arrival at: 1388.218
# Patient 180 departs at 1388.219; Time in system: 776.651
# Patient 180 discharged at 1388.219
# Patient 481 (Stroke) gets a bed at 1388.219
# STROKE arrival at: 1388.538
# Patient 479 departs at 1388.589; Time in system: 776.184
# Patient 479 discharged at 1388.589
# Patient 482 (Stroke) gets a bed at 1388.589
# STROKE arrival at: 1388.626
# Patient 476 departs at 1388.657; Time in system: 777.243
# Patient 476 discharged at 1388.657
# Patient 483 (Stroke) gets a bed at 1388.657
# ComplexNeuro arrival at: 1388.682
# TIA arrival at: 1388.735
# TIA arrival at: 1389.661
# Patient 477 departs at 1390.167; Time in system: 778.671
# Patient 477 discharged at 1390.167
# Patient 484 (Stroke) gets a bed at 1390.167
# Patient 182 departs at 1391.039; Time in system: 777.852
# Patient 182 transferred to ESD at 1391.039
# Patient 182 discharged at 1391.039
# Patient 533 (Stroke) gets a bed at 1391.039
# STROKE arrival at: 1391.285
# Other arrival at: 1391.405
# Patient 478 departs at 1391.428; Time in system: 779.320
# Patient 478 discharged at 1391.428
# Patient 485 (Stroke) gets a bed at 1391.428
# Patient 181 departs at 1392.448; Time in system: 779.965
# Patient 181 discharged at 1392.448
# Patient 170 (ComplexNeuro) gets a bed at 1392.448
# ComplexNeuro arrival at: 1392.742
# Other arrival at: 1392.888
# Patient 200 departs at 1392.990; Time in system: 779.114
# Patient 200 discharged at 1392.990
# Patient 171 (ComplexNeuro) gets a bed at 1392.990
# Patient 532 departs at 1393.169; Time in system: 779.405
# Patient 532 discharged at 1393.169
# Patient 486 (Stroke) gets a bed at 1393.169
# STROKE arrival at: 1393.841
# Other arrival at: 1394.301
# STROKE arrival at: 1395.191
# STROKE arrival at: 1395.247
# STROKE arrival at: 1395.269
# STROKE arrival at: 1395.383
# STROKE arrival at: 1395.398
# Patient 481 departs at 1396.451; Time in system: 782.150
# Patient 481 discharged at 1396.451
# Patient 172 (ComplexNeuro) gets a bed at 1396.451
# Patient 483 departs at 1396.739; Time in system: 781.626
# Patient 483 transferred to ESD at 1396.739
# Patient 483 discharged at 1396.739
# Patient 191 (Other) gets a bed at 1396.739
# Other arrival at: 1396.754
# Patient 480 departs at 1396.781; Time in system: 782.886
# Patient 480 discharged at 1396.781
# Patient 56 (TIA) gets a bed at 1396.781
# Patient 482 departs at 1396.914; Time in system: 781.860
# Patient 482 discharged at 1396.914
# Patient 534 (Stroke) gets a bed at 1396.914
# ComplexNeuro arrival at: 1396.928
# Other arrival at: 1397.519
# Other arrival at: 1397.575
# Other arrival at: 1397.706
# STROKE arrival at: 1397.923
# STROKE arrival at: 1398.107
# STROKE arrival at: 1398.317
# Patient 485 departs at 1398.409; Time in system: 782.092
# Patient 485 discharged at 1398.409
# Patient 535 (Stroke) gets a bed at 1398.409
# STROKE arrival at: 1398.578
# Patient 484 departs at 1398.618; Time in system: 782.745
# Patient 484 discharged at 1398.618
# Patient 201 (Other) gets a bed at 1398.618
# Patient 170 departs at 1398.681; Time in system: 781.952
# Patient 170 discharged at 1398.681
# Patient 192 (Other) gets a bed at 1398.681
# Patient 486 departs at 1398.731; Time in system: 781.610
# Patient 486 discharged at 1398.731
# Patient 193 (Other) gets a bed at 1398.731
# Other arrival at: 1399.444
# STROKE arrival at: 1399.626
# Patient 171 departs at 1399.949; Time in system: 783.114
# Patient 171 discharged at 1399.949
# Patient 536 (Stroke) gets a bed at 1399.949
# Other arrival at: 1400.004
# STROKE arrival at: 1400.801
# STROKE arrival at: 1400.913
# STROKE arrival at: 1400.925
# Patient 533 departs at 1400.937; Time in system: 784.625
# Patient 533 discharged at 1400.937
# Patient 487 (Stroke) gets a bed at 1400.937
# Other arrival at: 1401.336
# STROKE arrival at: 1401.657
# STROKE arrival at: 1401.916
# Other arrival at: 1401.933
# STROKE arrival at: 1402.241
# STROKE arrival at: 1402.296
# STROKE arrival at: 1402.462
# Other arrival at: 1402.845
# Patient 534 departs at 1403.150; Time in system: 785.674
# Patient 534 transferred to ESD at 1403.150
# Patient 534 discharged at 1403.150
# Patient 194 (Other) gets a bed at 1403.150
# Patient 191 departs at 1403.293; Time in system: 785.962
# Patient 191 discharged at 1403.293
# Patient 488 (Stroke) gets a bed at 1403.293
# STROKE arrival at: 1403.567
# STROKE arrival at: 1403.693
# STROKE arrival at: 1404.002
# Patient 56 departs at 1404.103; Time in system: 786.647
# Patient 56 discharged at 1404.103
# Patient 489 (Stroke) gets a bed at 1404.103
# Other arrival at: 1404.699
# Patient 193 departs at 1405.192; Time in system: 786.680
# Patient 193 discharged at 1405.192
# Patient 537 (Stroke) gets a bed at 1405.192
# Patient 172 departs at 1405.545; Time in system: 788.283
# Patient 172 discharged at 1405.545
# Patient 490 (Stroke) gets a bed at 1405.545
# Patient 535 departs at 1405.623; Time in system: 787.483
# Patient 535 transferred to ESD at 1405.623
# Patient 535 discharged at 1405.623
# Patient 202 (Other) gets a bed at 1405.623
# Patient 201 departs at 1405.632; Time in system: 787.359
# Patient 201 discharged at 1405.632
# Patient 57 (TIA) gets a bed at 1405.632
# STROKE arrival at: 1405.825
# STROKE arrival at: 1405.971
# Other arrival at: 1406.432
# STROKE arrival at: 1406.732
# Patient 192 departs at 1406.920; Time in system: 788.518
# Patient 192 transferred to ESD at 1406.920
# Patient 192 discharged at 1406.920
# Patient 173 (ComplexNeuro) gets a bed at 1406.920
# STROKE arrival at: 1407.404
# STROKE arrival at: 1407.758
# ComplexNeuro arrival at: 1408.383
# TIA arrival at: 1408.432
# STROKE arrival at: 1408.535
# Patient 536 departs at 1408.910; Time in system: 790.005
# Patient 536 discharged at 1408.910
# Patient 174 (ComplexNeuro) gets a bed at 1408.910
# Other arrival at: 1409.312
# Patient 194 departs at 1409.377; Time in system: 790.150
# Patient 194 transferred to ESD at 1409.377
# Patient 194 discharged at 1409.377
# Patient 183 (ComplexNeuro) gets a bed at 1409.377
# Patient 487 departs at 1409.636; Time in system: 790.578
# Patient 487 discharged at 1409.636
# Patient 491 (Stroke) gets a bed at 1409.636
# ComplexNeuro arrival at: 1409.918
# Other arrival at: 1410.341
# Patient 488 departs at 1410.764; Time in system: 791.012
# Patient 488 discharged at 1410.764
# Patient 538 (Stroke) gets a bed at 1410.764
# STROKE arrival at: 1410.880
# ComplexNeuro arrival at: 1411.218
# Patient 489 departs at 1411.566; Time in system: 790.627
# Patient 489 discharged at 1411.566
# Patient 195 (Other) gets a bed at 1411.566
# Patient 490 departs at 1412.021; Time in system: 790.779
# Patient 490 transferred to ESD at 1412.021
# Patient 490 discharged at 1412.021
# Patient 203 (Other) gets a bed at 1412.021
# Other arrival at: 1412.397
# STROKE arrival at: 1412.534
# STROKE arrival at: 1412.595
# TIA arrival at: 1412.885
# Other arrival at: 1413.114
# ComplexNeuro arrival at: 1413.312
# STROKE arrival at: 1413.365
# Other arrival at: 1413.478
# STROKE arrival at: 1413.707
# Other arrival at: 1413.866
# Patient 202 departs at 1414.210; Time in system: 792.821
# Patient 202 discharged at 1414.210
# Patient 204 (Other) gets a bed at 1414.210
# Patient 57 departs at 1414.224; Time in system: 792.825
# Patient 57 discharged at 1414.224
# Patient 492 (Stroke) gets a bed at 1414.224
# Other arrival at: 1414.383
# STROKE arrival at: 1414.452
# STROKE arrival at: 1414.600
# ComplexNeuro arrival at: 1414.762
# ComplexNeuro arrival at: 1414.786
# STROKE arrival at: 1414.900
# Patient 173 departs at 1415.008; Time in system: 793.522
# Patient 173 discharged at 1415.008
# Patient 539 (Stroke) gets a bed at 1415.008
# STROKE arrival at: 1415.368
# Other arrival at: 1415.377
# STROKE arrival at: 1415.432
# Other arrival at: 1415.546
# Patient 183 departs at 1415.842; Time in system: 793.384
# Patient 183 discharged at 1415.842
# Patient 540 (Stroke) gets a bed at 1415.842
# STROKE arrival at: 1415.858
# STROKE arrival at: 1415.960
# ComplexNeuro arrival at: 1416.372
# STROKE arrival at: 1416.462
# STROKE arrival at: 1416.721
# STROKE arrival at: 1416.953
# Patient 537 departs at 1417.048; Time in system: 795.899
# Patient 537 discharged at 1417.048
# Patient 541 (Stroke) gets a bed at 1417.048
# TIA arrival at: 1417.227
# STROKE arrival at: 1417.703
# Patient 195 departs at 1417.740; Time in system: 794.868
# Patient 195 transferred to ESD at 1417.740
# Patient 195 discharged at 1417.740
# Patient 493 (Stroke) gets a bed at 1417.740
# Patient 491 departs at 1417.743; Time in system: 795.260
# Patient 491 discharged at 1417.743
# Patient 196 (Other) gets a bed at 1417.743
# STROKE arrival at: 1417.828
# STROKE arrival at: 1417.910
# Patient 538 departs at 1418.050; Time in system: 795.195
# Patient 538 discharged at 1418.050
# Patient 197 (Other) gets a bed at 1418.050
# Patient 174 departs at 1418.681; Time in system: 797.112
# Patient 174 discharged at 1418.681
# Patient 205 (Other) gets a bed at 1418.681
# STROKE arrival at: 1419.089
# ComplexNeuro arrival at: 1419.101
# Patient 203 departs at 1419.332; Time in system: 795.999
# Patient 203 transferred to ESD at 1419.332
# Patient 203 discharged at 1419.332
# Patient 206 (Other) gets a bed at 1419.332
# Other arrival at: 1419.875
# ComplexNeuro arrival at: 1419.897
# STROKE arrival at: 1420.384
# Patient 492 departs at 1420.694; Time in system: 796.923
# Patient 492 transferred to ESD at 1420.694
# Patient 492 discharged at 1420.694
# Patient 494 (Stroke) gets a bed at 1420.694
# ComplexNeuro arrival at: 1420.729
# STROKE arrival at: 1421.705
# Patient 204 departs at 1421.763; Time in system: 798.139
# Patient 204 discharged at 1421.763
# Patient 184 (ComplexNeuro) gets a bed at 1421.763
# Other arrival at: 1422.759
# ComplexNeuro arrival at: 1422.842
# ComplexNeuro arrival at: 1423.152
# Patient 540 departs at 1423.426; Time in system: 799.119
# Patient 540 discharged at 1423.426
# Patient 542 (Stroke) gets a bed at 1423.426
# Other arrival at: 1423.472
# TIA arrival at: 1423.481
# ComplexNeuro arrival at: 1424.357
# STROKE arrival at: 1424.406
# TIA arrival at: 1424.554
# ComplexNeuro arrival at: 1425.021
# Patient 197 departs at 1425.174; Time in system: 798.703
# Patient 197 transferred to ESD at 1425.174
# Patient 197 discharged at 1425.174
# Patient 198 (Other) gets a bed at 1425.174
# STROKE arrival at: 1425.291
# Patient 539 departs at 1425.349; Time in system: 801.139
# Patient 539 discharged at 1425.349
# Patient 495 (Stroke) gets a bed at 1425.349
# Other arrival at: 1425.554
# Other arrival at: 1425.853
# STROKE arrival at: 1425.923
# Other arrival at: 1426.319
# Patient 493 departs at 1426.348; Time in system: 801.447
# Patient 493 discharged at 1426.348
# Patient 58 (TIA) gets a bed at 1426.348
# Patient 541 departs at 1426.362; Time in system: 801.615
# Patient 541 discharged at 1426.362
# Patient 496 (Stroke) gets a bed at 1426.362
# Patient 206 departs at 1426.581; Time in system: 799.591
# Patient 206 discharged at 1426.581
# Patient 543 (Stroke) gets a bed at 1426.581
# ComplexNeuro arrival at: 1426.706
# Patient 196 departs at 1426.726; Time in system: 801.305
# Patient 196 discharged at 1426.726
# Patient 497 (Stroke) gets a bed at 1426.726
# Patient 205 departs at 1426.754; Time in system: 800.225
# Patient 205 discharged at 1426.754
# Patient 498 (Stroke) gets a bed at 1426.754
# STROKE arrival at: 1426.764
# ComplexNeuro arrival at: 1426.920
# ComplexNeuro arrival at: 1427.607
# STROKE arrival at: 1427.640
# Patient 494 departs at 1427.813; Time in system: 800.810
# Patient 494 discharged at 1427.813
# Patient 544 (Stroke) gets a bed at 1427.813
# Other arrival at: 1428.001
# ComplexNeuro arrival at: 1428.025
# Patient 184 departs at 1428.682; Time in system: 801.586
# Patient 184 discharged at 1428.682
# Patient 499 (Stroke) gets a bed at 1428.682
# ComplexNeuro arrival at: 1428.692
# STROKE arrival at: 1429.277
# ComplexNeuro arrival at: 1429.937
# ComplexNeuro arrival at: 1430.083
# Patient 542 departs at 1430.329; Time in system: 803.067
# Patient 542 transferred to ESD at 1430.329
# Patient 542 discharged at 1430.329
# Patient 500 (Stroke) gets a bed at 1430.329
# STROKE arrival at: 1430.411
# STROKE arrival at: 1430.817
# Patient 198 departs at 1431.180; Time in system: 802.796
# Patient 198 discharged at 1431.180
# Patient 59 (TIA) gets a bed at 1431.180
# Patient 495 departs at 1431.320; Time in system: 802.253
# Patient 495 discharged at 1431.320
# Patient 545 (Stroke) gets a bed at 1431.320
# ComplexNeuro arrival at: 1431.334
# ComplexNeuro arrival at: 1431.956
# STROKE arrival at: 1432.033
# Patient 496 departs at 1432.479; Time in system: 802.406
# Patient 496 discharged at 1432.479
# Patient 175 (ComplexNeuro) gets a bed at 1432.479
# STROKE arrival at: 1432.593
# Other arrival at: 1432.794
# Other arrival at: 1432.850
# Patient 543 departs at 1433.000; Time in system: 802.217
# Patient 543 discharged at 1433.000
# Patient 546 (Stroke) gets a bed at 1433.000
# Other arrival at: 1433.179
# STROKE arrival at: 1433.259
# Patient 497 departs at 1433.461; Time in system: 802.455
# Patient 497 discharged at 1433.461
# Patient 199 (Other) gets a bed at 1433.461
# Patient 58 departs at 1433.501; Time in system: 804.025
# Patient 58 discharged at 1433.501
# Patient 501 (Stroke) gets a bed at 1433.501
# STROKE arrival at: 1434.167
# Other arrival at: 1434.215
# STROKE arrival at: 1434.390
# TIA arrival at: 1434.464
# Other arrival at: 1434.504
# Patient 499 departs at 1434.600; Time in system: 802.630
# Patient 499 discharged at 1434.600
# Patient 547 (Stroke) gets a bed at 1434.600
# STROKE arrival at: 1434.982
# Patient 498 departs at 1435.085; Time in system: 803.999
# Patient 498 discharged at 1435.085
# Patient 502 (Stroke) gets a bed at 1435.085
# STROKE arrival at: 1435.216
# ComplexNeuro arrival at: 1435.276
# STROKE arrival at: 1435.522
# TIA arrival at: 1435.692
# STROKE arrival at: 1436.433
# STROKE arrival at: 1437.066
# Patient 544 departs at 1437.402; Time in system: 805.787
# Patient 544 transferred to ESD at 1437.402
# Patient 544 discharged at 1437.402
# Patient 503 (Stroke) gets a bed at 1437.402
# STROKE arrival at: 1437.641
# Patient 59 departs at 1437.803; Time in system: 804.997
# Patient 59 transferred to ESD at 1437.803
# Patient 59 discharged at 1437.803
# Patient 185 (ComplexNeuro) gets a bed at 1437.803
# Patient 175 departs at 1438.354; Time in system: 804.546
# Patient 175 discharged at 1438.354
# Patient 207 (Other) gets a bed at 1438.354
# STROKE arrival at: 1438.564
# TIA arrival at: 1438.580
# ComplexNeuro arrival at: 1438.591
# Patient 545 departs at 1438.834; Time in system: 805.625
# Patient 545 discharged at 1438.834
# Patient 504 (Stroke) gets a bed at 1438.834
# STROKE arrival at: 1438.956
# TIA arrival at: 1438.980
# Patient 199 departs at 1439.149; Time in system: 804.187
# Patient 199 discharged at 1439.149
# Patient 548 (Stroke) gets a bed at 1439.149
# Patient 501 departs at 1439.373; Time in system: 804.324
# Patient 501 discharged at 1439.373
# Patient 505 (Stroke) gets a bed at 1439.373
# ComplexNeuro arrival at: 1439.468
# Other arrival at: 1439.736
# Other arrival at: 1439.818
# Patient 500 departs at 1440.502; Time in system: 808.136
# Patient 500 transferred to ESD at 1440.502
# Patient 500 discharged at 1440.502
# Patient 506 (Stroke) gets a bed at 1440.502
# ComplexNeuro arrival at: 1440.799
# STROKE arrival at: 1440.801
# ComplexNeuro arrival at: 1441.345
# Patient 547 departs at 1441.712; Time in system: 805.860
# Patient 547 discharged at 1441.712
# Patient 549 (Stroke) gets a bed at 1441.712
# Patient 546 departs at 1441.787; Time in system: 807.371
# Patient 546 discharged at 1441.787
# Patient 200 (Other) gets a bed at 1441.787
# Other arrival at: 1443.365
# ComplexNeuro arrival at: 1443.902
# Patient 502 departs at 1443.947; Time in system: 807.771
# Patient 502 discharged at 1443.947
# Patient 208 (Other) gets a bed at 1443.947
# STROKE arrival at: 1443.952
# ComplexNeuro arrival at: 1444.044
# STROKE arrival at: 1444.155
# Patient 503 departs at 1444.714; Time in system: 807.795
# Patient 503 transferred to ESD at 1444.714
# Patient 503 discharged at 1444.714
# Patient 550 (Stroke) gets a bed at 1444.714
# Patient 185 departs at 1444.934; Time in system: 807.956
# Patient 185 discharged at 1444.934
# Patient 61 (TIA) gets a bed at 1444.934
# end of run. simulation clock time = 1445
# {'n_stroke': 0, 'n_tia': 0, 'n_cn': 0, 'n_other': 0}

# %% [markdown]
# ## Running metrics

# %%
import numpy as np

# Ensure there are patients in the system
if model.patients:

    # Group patients by their type (e.g., "Stroke", "TIA", etc.)
    patient_types = set(p.patient_type for p in model.patients)  # Get unique patient types
    for patient_type in patient_types:
        # Filter patients by type
        patients_by_type = [p for p in model.patients if p.patient_type == patient_type]

        # 1. Mean time in system (from arrival to discharge)
        mean_time_in_system = np.mean([p.time_in_system for p in patients_by_type])

        # 2. Proportion of patients who met the 4-hour target
        four_hours = np.mean([p.four_hour_target for p in patients_by_type])

        # 3. Mean time to bed (arrival → bed assignment)
        mean_time_to_bed = np.mean([p.time_to_bed for p in patients_by_type])

        # 4. Mean time to ESD transfer (arrival → ESD transfer, only for transferred patients)
        patients_with_esd = [p for p in patients_by_type if p.time_to_esd > 0]
        mean_time_to_esd = np.mean([p.time_to_esd - p.time_to_bed for p in patients_with_esd]) if patients_with_esd else 0

        # Print results for this patient type
        print(f'\nResults for {patient_type} Patients\n------------------')
        print(f'Mean Time in System (days): {mean_time_in_system:.2f}')
        print(f'Mean Time to Bed (days): {mean_time_to_bed:.2f}')
        print(f'Mean Time to ESD (days): {mean_time_to_esd:.2f}' if patients_with_esd else "No ESD transfers")
        print(f'Proportion Discharged Before 4 Hours: {four_hours:.2f}')
else:
    print("No patients recorded in this simulation run.")
# Out:
# Results for ComplexNeuro Patients
# ------------------
# Mean Time in System (days): 181.20
# Mean Time to Bed (days): 177.95
# Mean Time to ESD (days): 319.69
# Proportion Discharged Before 4 Hours: 0.12
#
# Results for Other Patients
# ------------------
# Mean Time in System (days): 170.95
# Mean Time to Bed (days): 170.32
# Mean Time to ESD (days): 352.73
# Proportion Discharged Before 4 Hours: 0.12
#
# Results for Stroke Patients
# ------------------
# Mean Time in System (days): 180.65
# Mean Time to Bed (days): 179.38
# Mean Time to ESD (days): 342.57
# Proportion Discharged Before 4 Hours: 0.14
#
# Results for TIA Patients
# ------------------
# Mean Time in System (days): 182.10
# Mean Time to Bed (days): 181.83
# Mean Time to ESD (days): 403.99
# Proportion Discharged Before 4 Hours: 0.08

# %%
# check between minutes and days
