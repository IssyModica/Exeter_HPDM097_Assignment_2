# %% [markdown]
# # simulating the stroke unit

# %%
import numpy as np
import pandas as pd
import random 
import itertools
import math
import matplotlib.pyplot as plt

# %%
import simpy
simpy.__version__
# Out:
# '4.1.1'

# %% [markdown]
# # distribution classes
#
# distribution classes used
# - exponential for IAT (inter arrival time)
# - lognormal for length of stay

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

class Bernoulli:
    '''
    Convenience class for the Bernoulli distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, p, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        p: float
            probability of drawing a 1
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.p = p
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.binomial(n=1, p=self.p, size=size)

# %% [markdown]
# # utility function

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %% [markdown]
# # model parameters

# %%
# resource counts
N_BEDS = 10

# time between arrivals in days (exponential)
MEAN_IAT_STROKE = 1.2
MEAN_IAT_TIA = 9.3
MEAN_IAT_CN = 3.6
MEAN_IAT_OTHER = 3.2

# acute stroke unit length of stay in days (lognormal)
STAY_MEAN = 7.4
STAY_STD = 1.2

# transfer (bernoulli)
PROB_ESD = 0.13

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = True

if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %%
class Scenario:
    '''
    Parameter container class for acute stroke unit model.
    '''
    def __init__(self, 
                 iat_stroke = MEAN_IAT_STROKE,
                 iat_tia = MEAN_IAT_TIA,
                 iat_cn = MEAN_IAT_CN,
                 iat_other = MEAN_IAT_OTHER, 
                 name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        
        # optional name
        self.name = name
        
        # beds
        self.unit_beds = N_BEDS

        #store the parameters 
        self.iat_stroke = iat_stroke
        self.iat_tia = iat_tia
        self.iat_cn = iat_cn
        self.iat_other = iat_other

        #initialise results to zero
        self.init_results_variables()
        #Initialise patient arrival distribution
        self.init_sampling()
        self.patients = []
        

        # assessment distribution
        self.length_of_stay_dist = Lognormal(STAY_MEAN, STAY_STD, 
                                         random_seed=SEEDS[4])
        
        # ESD transfer: prob that patient goes to ESD.
        self.esd_transfer = Bernoulli(PROB_ESD, random_seed=SEEDS[5])
        
    def init_sampling(self):
    # inter-arrival distribution for different patient types
        self.arrival_dist = {
            "Stroke": Exponential(MEAN_IAT_STROKE, random_seed=SEEDS[0]),
            "TIA": Exponential(MEAN_IAT_TIA, random_seed=SEEDS[1]),
            "ComplexNeuro": Exponential(MEAN_IAT_CN, random_seed=SEEDS[2]),
            "Other": Exponential(MEAN_IAT_OTHER, random_seed=SEEDS[3]),
        }

    def init_results_variables(self):
        self.results = {}
        self.results["n_stroke"] = 0
        self.results["n_tia"] = 0
        self.results["n_cn"] = 0
        self.results["n_other"] = 0

# %% [markdown]
# # build the model

# %% [markdown]
# ## model the unit
# ## Arrival Generator per patient_type
# Function which creates an arrival generator per patient type. Therefore, 4 functions for each patient entering the Acute Stroke Unit.
#
# !!! Note to self: code redundancy can be fixed by creating one arrival generator but this is better to do after making sure the model runs properly.

# %%
class AcuteStrokeUnit:  
    '''
    Model of an acute stroke unit
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []

        # 🔹 Add a shared patient ID counter
        self.patient_id_counter = 0  

        # Start the arrival processes for different patient types
        env.process(self.stroke_arrivals_generator())
        env.process(self.tia_arrivals_generator())
        env.process(self.complexneuro_arrivals_generator())
        env.process(self.other_arrivals_generator())

        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''
        args.unit_beds = simpy.Resource(self.env, 
                                          capacity=args.unit_beds)  

    def start_patient_arrivals(self):
        '''Start arrival processes for all patient types'''
        self.env.process(self.stroke_arrivals_generator())
        self.env.process(self.tia_arrivals_generator())
        self.env.process(self.complexneuro_arrivals_generator())
        self.env.process(self.other_arrivals_generator())

    def stroke_arrivals_generator(self):
        """Arrival process for stroke patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["Stroke"].sample()
            yield self.env.timeout(inter_arrival_time)

            # 🔹 Increment global counter
            self.patient_id_counter += 1  
        
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="Stroke")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
            trace(f'Patient {self.patient_id_counter} STROKE arrival at: {self.env.now:.3f}')
            
    def tia_arrivals_generator(self):
        """Arrival process for TIA patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["TIA"].sample()
            yield self.env.timeout(inter_arrival_time)
    
            self.patient_id_counter += 1  
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="TIA")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
    
            trace(f'Patient {self.patient_id_counter} TIA arrival at: {self.env.now:.3f}')

    def complexneuro_arrivals_generator(self):
        """Arrival process for ComplexNeuro patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["ComplexNeuro"].sample()
            yield self.env.timeout(inter_arrival_time)
    
            self.patient_id_counter += 1  
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="ComplexNeuro")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
    
            trace(f'Patient {self.patient_id_counter} ComplexNeuro arrival at: {self.env.now:.3f}')
    
    def other_arrivals_generator(self):
        """Arrival process for Other patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["Other"].sample()
            yield self.env.timeout(inter_arrival_time)
    
            self.patient_id_counter += 1  
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="Other")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
    
            trace(f'Patient {self.patient_id_counter} Other arrival at: {self.env.now:.3f}')

# %% [markdown]
# ## model the patient

# %%
class AcutePatient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args, patient_type):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env
        self.patient_type = patient_type  # Track patient category
        
        

        # stroke unit parameters
        self.unit_beds = args.unit_beds
        self.length_of_stay_dist = args.length_of_stay_dist
        
        # esd transfer: prob that patient is transfered to ESD.
        self.esd_transfer = args.esd_transfer
                
        # individual patient metrics
        self.time_to_bed = 0.0
        self.length_of_stay = 0.0
        self.time_to_esd = 0.0
        self.time_in_system = 0.0
        self.four_hour_target = 0.0
    
    def assessment(self):
        '''
        simulates the process for acute stroke unit
        
        1. Patient enters the system and requests a bed
        2. Wait for bed availability and simulate length of stay
        3. Calculate time in system, ESD transfer, and if the 4-hour target is met
        
        '''
        # record the time that patient entered the system
        arrival_time = self.env.now
    
        # Request a bed from the stroke unit
        with self.unit_beds.request() as req:
            yield req
            
            # Record when the patient actually gets a bed
            bed_time = self.env.now  # Record when the patient gets the bed
            trace(f'Patient {self.identifier} ({self.patient_type}) gets a bed at {self.env.now:.3f}')
            
            # Calculate time to bed (how long the patient waited for a bed)
            self.time_to_bed = self.env.now - arrival_time
            
           # Simulate the patient's length of stay in the acute unit
            length_of_stay = self.length_of_stay_dist.sample()
            
            discharge_time = bed_time + length_of_stay  # When they leave
            
            # Simulate the time the patient spends in the unit
            yield self.env.timeout(length_of_stay)
            
            # Now the patient is leaving
            self.time_in_system = self.env.now - arrival_time  # Total time from arrival to departure
            self.length_of_stay = self.env.now - bed_time  # New length of stay calculation            
            
            # Log the patient's departure and the total time in the system
            trace(f'Patient {self.identifier} departs at {self.env.now:.3f}; '
              f'Length of stay: {self.length_of_stay:.3f} days; '
              f'Time in system: {self.time_in_system:.3f} days')
            
            # Check if the patient met the 4-hour target (240 minutes)
            if self.time_in_system <= (4 * 60):  # 4 hours = 240 minutes
                self.four_hour_target = 1  # Patient met the target
            else:
                self.four_hour_target = 0  # Patient exceeded the target
            
            # Check if the patient is transferred to the ESD (Early Supported Discharge)
            if self.esd_transfer.sample():
                self.time_to_esd = self.env.now
                trace(f'Patient {self.identifier} transferred to ESD at {self.env.now:.3f}')
            
            # Final discharge time log
            trace(f'Patient {self.identifier} discharged at {self.env.now:.3f}')

# %% [markdown]
# # script to run the model

# %%
# run length in minutes
RUN_LENGTH = 1445

# Define trace as on/off
#TRACE = False
TRACE = True 

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()
# reset all results variables to zero and empty
default_args.init_results_variables()

# create the model
model = AcuteStrokeUnit(env, default_args)

# we pass all arrival generators to simpy 
env.process(model.stroke_arrivals_generator())  # Calling as a method of the model instance
env.process(model.tia_arrivals_generator())    # Calling as a method of the model instance
env.process(model.complexneuro_arrivals_generator())  # Calling as a method of the model instance
env.process(model.other_arrivals_generator())  # Calling as a method of the model instance



env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')
scenario = Scenario()  # Create an instance
print(scenario.results)  # Access and print the results dictionary
# Out:
# Patient 1 Other arrival at: 1.333
# Patient 1 (Other) gets a bed at 1.333
# Patient 2 Other arrival at: 1.569
# Patient 2 (Other) gets a bed at 1.569
# Patient 3 Other arrival at: 2.721
# Patient 3 (Other) gets a bed at 2.721
# Patient 4 STROKE arrival at: 2.803
# Patient 4 (Stroke) gets a bed at 2.803
# Patient 5 STROKE arrival at: 2.885
# Patient 5 (Stroke) gets a bed at 2.885
# Patient 6 STROKE arrival at: 3.221
# Patient 6 (Stroke) gets a bed at 3.221
# Patient 7 STROKE arrival at: 3.325
# Patient 7 (Stroke) gets a bed at 3.325
# Patient 8 Other arrival at: 3.388
# Patient 8 (Other) gets a bed at 3.388
# Patient 9 ComplexNeuro arrival at: 4.199
# Patient 9 (ComplexNeuro) gets a bed at 4.199
# Patient 10 ComplexNeuro arrival at: 4.530
# Patient 10 (ComplexNeuro) gets a bed at 4.530
# Patient 11 Other arrival at: 4.931
# Patient 12 STROKE arrival at: 5.068
# Patient 13 Other arrival at: 5.160
# Patient 14 Other arrival at: 5.294
# Patient 15 TIA arrival at: 5.377
# Patient 16 STROKE arrival at: 5.665
# Patient 17 Other arrival at: 6.208
# Patient 18 Other arrival at: 6.338
# Patient 19 STROKE arrival at: 6.760
# Patient 20 STROKE arrival at: 6.855
# Patient 21 ComplexNeuro arrival at: 6.935
# Patient 22 ComplexNeuro arrival at: 7.757
# Patient 23 ComplexNeuro arrival at: 7.908
# Patient 24 STROKE arrival at: 8.111
# Patient 1 departs at 8.187; Length of stay: 6.854 days; Time in system: 6.854 days
# Patient 1 discharged at 8.187
# Patient 11 (Other) gets a bed at 8.187
# Patient 25 STROKE arrival at: 8.195
# Patient 26 ComplexNeuro arrival at: 9.065
# Patient 2 departs at 9.203; Length of stay: 7.634 days; Time in system: 7.634 days
# Patient 2 discharged at 9.203
# Patient 12 (Stroke) gets a bed at 9.203
# Patient 4 departs at 9.225; Length of stay: 6.421 days; Time in system: 6.421 days
# Patient 4 discharged at 9.225
# Patient 13 (Other) gets a bed at 9.225
# Patient 27 STROKE arrival at: 9.414
# Patient 28 STROKE arrival at: 9.502
# Patient 5 departs at 9.560; Length of stay: 6.675 days; Time in system: 6.675 days
# Patient 5 discharged at 9.560
# Patient 14 (Other) gets a bed at 9.560
# Patient 7 departs at 9.915; Length of stay: 6.590 days; Time in system: 6.590 days
# Patient 7 discharged at 9.915
# Patient 15 (TIA) gets a bed at 9.915
# Patient 29 STROKE arrival at: 9.966
# Patient 30 Other arrival at: 10.153
# Patient 3 departs at 10.344; Length of stay: 7.623 days; Time in system: 7.623 days
# Patient 3 transferred to ESD at 10.344
# Patient 3 discharged at 10.344
# Patient 16 (Stroke) gets a bed at 10.344
# Patient 31 Other arrival at: 10.350
# Patient 32 STROKE arrival at: 11.444
# Patient 33 STROKE arrival at: 11.492
# Patient 34 STROKE arrival at: 11.602
# Patient 35 STROKE arrival at: 11.629
# Patient 6 departs at 11.671; Length of stay: 8.450 days; Time in system: 8.450 days
# Patient 6 discharged at 11.671
# Patient 17 (Other) gets a bed at 11.671
# Patient 8 departs at 11.915; Length of stay: 8.527 days; Time in system: 8.527 days
# Patient 8 discharged at 11.915
# Patient 18 (Other) gets a bed at 11.915
# Patient 36 STROKE arrival at: 11.980
# Patient 37 ComplexNeuro arrival at: 11.981
# Patient 9 departs at 12.244; Length of stay: 8.045 days; Time in system: 8.045 days
# Patient 9 transferred to ESD at 12.244
# Patient 9 discharged at 12.244
# Patient 19 (Stroke) gets a bed at 12.244
# Patient 38 STROKE arrival at: 12.476
# Patient 39 ComplexNeuro arrival at: 12.661
# Patient 40 STROKE arrival at: 12.710
# Patient 10 departs at 12.818; Length of stay: 8.288 days; Time in system: 8.288 days
# Patient 10 discharged at 12.818
# Patient 20 (Stroke) gets a bed at 12.818
# Patient 41 STROKE arrival at: 12.978
# Patient 42 ComplexNeuro arrival at: 13.071
# Patient 43 Other arrival at: 13.631
# Patient 44 STROKE arrival at: 13.972
# Patient 45 TIA arrival at: 14.271
# Patient 46 Other arrival at: 14.328
# Patient 47 Other arrival at: 14.820
# Patient 11 departs at 14.951; Length of stay: 6.764 days; Time in system: 10.019 days
# Patient 11 discharged at 14.951
# Patient 21 (ComplexNeuro) gets a bed at 14.951
# Patient 48 Other arrival at: 15.097
# Patient 49 STROKE arrival at: 15.184
# Patient 50 ComplexNeuro arrival at: 15.372
# Patient 51 STROKE arrival at: 15.445
# Patient 52 STROKE arrival at: 15.945
# Patient 53 STROKE arrival at: 15.971
# Patient 54 STROKE arrival at: 16.063
# Patient 55 STROKE arrival at: 16.279
# Patient 14 departs at 16.310; Length of stay: 6.750 days; Time in system: 11.016 days
# Patient 14 discharged at 16.310
# Patient 22 (ComplexNeuro) gets a bed at 16.310
# Patient 56 STROKE arrival at: 16.489
# Patient 13 departs at 16.754; Length of stay: 7.529 days; Time in system: 11.593 days
# Patient 13 discharged at 16.754
# Patient 23 (ComplexNeuro) gets a bed at 16.754
# Patient 57 STROKE arrival at: 16.956
# Patient 58 STROKE arrival at: 17.101
# Patient 16 departs at 17.299; Length of stay: 6.955 days; Time in system: 11.634 days
# Patient 16 discharged at 17.299
# Patient 24 (Stroke) gets a bed at 17.299
# Patient 15 departs at 17.695; Length of stay: 7.780 days; Time in system: 12.318 days
# Patient 15 discharged at 17.695
# Patient 25 (Stroke) gets a bed at 17.695
# Patient 59 STROKE arrival at: 17.952
# Patient 12 departs at 17.968; Length of stay: 8.765 days; Time in system: 12.900 days
# Patient 12 discharged at 17.968
# Patient 26 (ComplexNeuro) gets a bed at 17.968
# Patient 60 STROKE arrival at: 18.237
# Patient 19 departs at 18.452; Length of stay: 6.208 days; Time in system: 11.692 days
# Patient 19 discharged at 18.452
# Patient 27 (Stroke) gets a bed at 18.452
# Patient 61 STROKE arrival at: 18.473
# Patient 62 STROKE arrival at: 18.790
# Patient 63 STROKE arrival at: 19.203
# Patient 64 STROKE arrival at: 19.243
# Patient 20 departs at 19.328; Length of stay: 6.509 days; Time in system: 12.473 days
# Patient 20 discharged at 19.328
# Patient 28 (Stroke) gets a bed at 19.328
# Patient 18 departs at 19.513; Length of stay: 7.599 days; Time in system: 13.175 days
# Patient 18 discharged at 19.513
# Patient 29 (Stroke) gets a bed at 19.513
# Patient 65 ComplexNeuro arrival at: 19.579
# Patient 66 STROKE arrival at: 19.589
# Patient 67 Other arrival at: 19.640
# Patient 17 departs at 19.834; Length of stay: 8.164 days; Time in system: 13.627 days
# Patient 17 discharged at 19.834
# Patient 30 (Other) gets a bed at 19.834
# Patient 68 STROKE arrival at: 19.946
# Patient 69 Other arrival at: 20.131
# Patient 70 STROKE arrival at: 20.297
# Patient 71 ComplexNeuro arrival at: 20.714
# Patient 72 Other arrival at: 20.762
# Patient 73 Other arrival at: 21.290
# Patient 74 ComplexNeuro arrival at: 21.312
# Patient 75 STROKE arrival at: 21.546
# Patient 76 STROKE arrival at: 21.966
# Patient 77 Other arrival at: 22.004
# Patient 78 STROKE arrival at: 22.054
# Patient 22 departs at 22.078; Length of stay: 5.769 days; Time in system: 14.321 days
# Patient 22 discharged at 22.078
# Patient 31 (Other) gets a bed at 22.078
# Patient 79 STROKE arrival at: 22.847
# Patient 80 Other arrival at: 22.914
# Patient 21 departs at 23.059; Length of stay: 8.109 days; Time in system: 16.125 days
# Patient 21 discharged at 23.059
# Patient 32 (Stroke) gets a bed at 23.059
# Patient 81 STROKE arrival at: 23.415
# Patient 24 departs at 23.475; Length of stay: 6.176 days; Time in system: 15.364 days
# Patient 24 discharged at 23.475
# Patient 33 (Stroke) gets a bed at 23.475
# Patient 82 ComplexNeuro arrival at: 23.627
# Patient 83 TIA arrival at: 23.875
# Patient 84 ComplexNeuro arrival at: 24.020
# Patient 23 departs at 24.074; Length of stay: 7.321 days; Time in system: 16.166 days
# Patient 23 discharged at 24.074
# Patient 34 (Stroke) gets a bed at 24.074
# Patient 85 STROKE arrival at: 24.472
# Patient 25 departs at 24.541; Length of stay: 6.847 days; Time in system: 16.346 days
# Patient 25 discharged at 24.541
# Patient 35 (Stroke) gets a bed at 24.541
# Patient 86 STROKE arrival at: 24.761
# Patient 87 STROKE arrival at: 24.808
# Patient 88 STROKE arrival at: 25.007
# Patient 89 STROKE arrival at: 25.147
# Patient 90 STROKE arrival at: 25.172
# Patient 91 STROKE arrival at: 25.373
# Patient 27 departs at 25.432; Length of stay: 6.980 days; Time in system: 16.018 days
# Patient 27 discharged at 25.432
# Patient 36 (Stroke) gets a bed at 25.432
# Patient 92 STROKE arrival at: 25.432
# Patient 28 departs at 25.824; Length of stay: 6.497 days; Time in system: 16.322 days
# Patient 28 discharged at 25.824
# Patient 37 (ComplexNeuro) gets a bed at 25.824
# Patient 30 departs at 25.923; Length of stay: 6.088 days; Time in system: 15.770 days
# Patient 30 discharged at 25.923
# Patient 38 (Stroke) gets a bed at 25.923
# Patient 26 departs at 25.926; Length of stay: 7.958 days; Time in system: 16.861 days
# Patient 26 discharged at 25.926
# Patient 39 (ComplexNeuro) gets a bed at 25.926
# Patient 93 STROKE arrival at: 26.951
# Patient 94 STROKE arrival at: 27.627
# Patient 95 STROKE arrival at: 27.968
# Patient 96 Other arrival at: 28.101
# Patient 97 STROKE arrival at: 28.445
# Patient 98 STROKE arrival at: 28.879
# Patient 99 STROKE arrival at: 29.034
# Patient 100 Other arrival at: 29.300
# Patient 29 departs at 29.408; Length of stay: 9.895 days; Time in system: 19.442 days
# Patient 29 discharged at 29.408
# Patient 40 (Stroke) gets a bed at 29.408
# Patient 101 Other arrival at: 29.414
# Patient 33 departs at 29.454; Length of stay: 5.979 days; Time in system: 17.962 days
# Patient 33 discharged at 29.454
# Patient 41 (Stroke) gets a bed at 29.454
# Patient 31 departs at 29.814; Length of stay: 7.735 days; Time in system: 19.464 days
# Patient 31 discharged at 29.814
# Patient 42 (ComplexNeuro) gets a bed at 29.814
# Patient 102 TIA arrival at: 29.827
# Patient 103 STROKE arrival at: 30.227
# Patient 104 STROKE arrival at: 30.334
# Patient 35 departs at 30.792; Length of stay: 6.251 days; Time in system: 19.164 days
# Patient 35 transferred to ESD at 30.792
# Patient 35 discharged at 30.792
# Patient 43 (Other) gets a bed at 30.792
# Patient 105 ComplexNeuro arrival at: 31.602
# Patient 106 STROKE arrival at: 31.878
# Patient 107 STROKE arrival at: 32.144
# Patient 32 departs at 32.376; Length of stay: 9.317 days; Time in system: 20.932 days
# Patient 32 discharged at 32.376
# Patient 44 (Stroke) gets a bed at 32.376
# Patient 37 departs at 32.416; Length of stay: 6.591 days; Time in system: 20.435 days
# Patient 37 discharged at 32.416
# Patient 45 (TIA) gets a bed at 32.416
# Patient 34 departs at 33.024; Length of stay: 8.950 days; Time in system: 21.422 days
# Patient 34 discharged at 33.024
# Patient 46 (Other) gets a bed at 33.024
# Patient 39 departs at 33.086; Length of stay: 7.160 days; Time in system: 20.425 days
# Patient 39 discharged at 33.086
# Patient 47 (Other) gets a bed at 33.086
# Patient 108 TIA arrival at: 33.370
# Patient 36 departs at 33.620; Length of stay: 8.187 days; Time in system: 21.640 days
# Patient 36 transferred to ESD at 33.620
# Patient 36 discharged at 33.620
# Patient 48 (Other) gets a bed at 33.620
# Patient 109 ComplexNeuro arrival at: 33.664
# Patient 38 departs at 34.342; Length of stay: 8.420 days; Time in system: 21.867 days
# Patient 38 discharged at 34.342
# Patient 49 (Stroke) gets a bed at 34.342
# Patient 110 STROKE arrival at: 34.672
# Patient 40 departs at 35.777; Length of stay: 6.369 days; Time in system: 23.067 days
# Patient 40 discharged at 35.777
# Patient 50 (ComplexNeuro) gets a bed at 35.777
# Patient 41 departs at 36.133; Length of stay: 6.679 days; Time in system: 23.155 days
# Patient 41 discharged at 36.133
# Patient 51 (Stroke) gets a bed at 36.133
# Patient 111 STROKE arrival at: 36.646
# Patient 44 departs at 37.390; Length of stay: 5.013 days; Time in system: 23.417 days
# Patient 44 discharged at 37.390
# Patient 52 (Stroke) gets a bed at 37.390
# Patient 112 STROKE arrival at: 37.898
# Patient 113 TIA arrival at: 38.034
# Patient 114 Other arrival at: 38.083
# Patient 115 STROKE arrival at: 38.250
# Patient 116 STROKE arrival at: 38.304
# Patient 117 STROKE arrival at: 38.609
# Patient 42 departs at 38.851; Length of stay: 9.037 days; Time in system: 25.779 days
# Patient 42 transferred to ESD at 38.851
# Patient 42 discharged at 38.851
# Patient 53 (Stroke) gets a bed at 38.851
# Patient 118 Other arrival at: 38.871
# Patient 46 departs at 39.107; Length of stay: 6.082 days; Time in system: 24.779 days
# Patient 46 discharged at 39.107
# Patient 54 (Stroke) gets a bed at 39.107
# Patient 119 STROKE arrival at: 39.354
# Patient 45 departs at 39.417; Length of stay: 7.002 days; Time in system: 25.147 days
# Patient 45 discharged at 39.417
# Patient 55 (Stroke) gets a bed at 39.417
# Patient 120 STROKE arrival at: 39.451
# Patient 121 ComplexNeuro arrival at: 39.865
# Patient 47 departs at 40.175; Length of stay: 7.088 days; Time in system: 25.354 days
# Patient 47 transferred to ESD at 40.175
# Patient 47 discharged at 40.175
# Patient 56 (Stroke) gets a bed at 40.175
# Patient 49 departs at 41.141; Length of stay: 6.799 days; Time in system: 25.957 days
# Patient 49 discharged at 41.141
# Patient 57 (Stroke) gets a bed at 41.141
# Patient 122 STROKE arrival at: 41.164
# Patient 43 departs at 41.278; Length of stay: 10.486 days; Time in system: 27.647 days
# Patient 43 discharged at 41.278
# Patient 58 (Stroke) gets a bed at 41.278
# Patient 123 STROKE arrival at: 41.563
# Patient 124 STROKE arrival at: 41.622
# Patient 50 departs at 41.671; Length of stay: 5.894 days; Time in system: 26.300 days
# Patient 50 discharged at 41.671
# Patient 59 (Stroke) gets a bed at 41.671
# Patient 125 STROKE arrival at: 41.885
# Patient 126 Other arrival at: 41.911
# Patient 48 departs at 42.263; Length of stay: 8.643 days; Time in system: 27.166 days
# Patient 48 discharged at 42.263
# Patient 60 (Stroke) gets a bed at 42.263
# Patient 127 STROKE arrival at: 42.732
# Patient 128 Other arrival at: 42.908
# Patient 51 departs at 43.132; Length of stay: 6.998 days; Time in system: 27.687 days
# Patient 51 discharged at 43.132
# Patient 61 (Stroke) gets a bed at 43.132
# Patient 129 ComplexNeuro arrival at: 43.316
# Patient 52 departs at 43.600; Length of stay: 6.210 days; Time in system: 27.655 days
# Patient 52 discharged at 43.600
# Patient 62 (Stroke) gets a bed at 43.600
# Patient 130 Other arrival at: 43.610
# Patient 131 STROKE arrival at: 43.717
# Patient 132 ComplexNeuro arrival at: 43.766
# Patient 133 TIA arrival at: 43.834
# Patient 134 Other arrival at: 44.432
# Patient 135 Other arrival at: 44.655
# Patient 136 STROKE arrival at: 44.949
# Patient 54 departs at 45.026; Length of stay: 5.920 days; Time in system: 28.963 days
# Patient 54 discharged at 45.026
# Patient 63 (Stroke) gets a bed at 45.026
# Patient 137 STROKE arrival at: 45.853
# Patient 138 STROKE arrival at: 46.274
# Patient 139 STROKE arrival at: 46.621
# Patient 53 departs at 46.629; Length of stay: 7.778 days; Time in system: 30.658 days
# Patient 53 discharged at 46.629
# Patient 64 (Stroke) gets a bed at 46.629
# Patient 140 STROKE arrival at: 46.782
# Patient 141 STROKE arrival at: 46.953
# Patient 142 ComplexNeuro arrival at: 47.010
# Patient 143 STROKE arrival at: 47.094
# Patient 144 STROKE arrival at: 47.160
# Patient 145 STROKE arrival at: 47.430
# Patient 56 departs at 47.487; Length of stay: 7.313 days; Time in system: 30.998 days
# Patient 56 discharged at 47.487
# Patient 65 (ComplexNeuro) gets a bed at 47.487
# Patient 55 departs at 47.778; Length of stay: 8.360 days; Time in system: 31.499 days
# Patient 55 discharged at 47.778
# Patient 66 (Stroke) gets a bed at 47.778
# Patient 146 ComplexNeuro arrival at: 47.900
# Patient 147 STROKE arrival at: 47.968
# Patient 148 Other arrival at: 47.977
# Patient 57 departs at 48.220; Length of stay: 7.079 days; Time in system: 31.264 days
# Patient 57 discharged at 48.220
# Patient 67 (Other) gets a bed at 48.220
# Patient 149 STROKE arrival at: 48.431
# Patient 58 departs at 48.573; Length of stay: 7.295 days; Time in system: 31.471 days
# Patient 58 transferred to ESD at 48.573
# Patient 58 discharged at 48.573
# Patient 68 (Stroke) gets a bed at 48.573
# Patient 150 STROKE arrival at: 49.220
# Patient 151 Other arrival at: 49.333
# Patient 152 ComplexNeuro arrival at: 49.433
# Patient 153 STROKE arrival at: 49.445
# Patient 154 STROKE arrival at: 49.553
# Patient 60 departs at 49.787; Length of stay: 7.525 days; Time in system: 31.550 days
# Patient 60 discharged at 49.787
# Patient 69 (Other) gets a bed at 49.787
# Patient 155 ComplexNeuro arrival at: 51.077
# Patient 156 STROKE arrival at: 51.104
# Patient 59 departs at 51.185; Length of stay: 9.514 days; Time in system: 33.234 days
# Patient 59 discharged at 51.185
# Patient 70 (Stroke) gets a bed at 51.185
# Patient 157 STROKE arrival at: 51.499
# Patient 158 STROKE arrival at: 51.739
# Patient 159 STROKE arrival at: 51.747
# Patient 160 ComplexNeuro arrival at: 51.760
# Patient 161 STROKE arrival at: 52.112
# Patient 162 STROKE arrival at: 52.203
# Patient 163 STROKE arrival at: 52.377
# Patient 62 departs at 52.499; Length of stay: 8.899 days; Time in system: 33.709 days
# Patient 62 discharged at 52.499
# Patient 71 (ComplexNeuro) gets a bed at 52.499
# Patient 61 departs at 52.565; Length of stay: 9.434 days; Time in system: 34.093 days
# Patient 61 discharged at 52.565
# Patient 72 (Other) gets a bed at 52.565
# Patient 164 ComplexNeuro arrival at: 52.787
# Patient 165 STROKE arrival at: 52.808
# Patient 166 Other arrival at: 52.837
# Patient 64 departs at 52.848; Length of stay: 6.219 days; Time in system: 33.606 days
# Patient 64 discharged at 52.848
# Patient 73 (Other) gets a bed at 52.848
# Patient 63 departs at 52.935; Length of stay: 7.909 days; Time in system: 33.732 days
# Patient 63 transferred to ESD at 52.935
# Patient 63 discharged at 52.935
# Patient 74 (ComplexNeuro) gets a bed at 52.935
# Patient 167 ComplexNeuro arrival at: 53.464
# Patient 68 departs at 53.638; Length of stay: 5.065 days; Time in system: 33.692 days
# Patient 68 discharged at 53.638
# Patient 75 (Stroke) gets a bed at 53.638
# Patient 168 STROKE arrival at: 54.018
# Patient 169 ComplexNeuro arrival at: 54.322
# Patient 67 departs at 54.841; Length of stay: 6.621 days; Time in system: 35.201 days
# Patient 67 discharged at 54.841
# Patient 76 (Stroke) gets a bed at 54.841
# Patient 170 Other arrival at: 54.934
# Patient 171 STROKE arrival at: 55.079
# Patient 65 departs at 55.468; Length of stay: 7.981 days; Time in system: 35.889 days
# Patient 65 discharged at 55.468
# Patient 77 (Other) gets a bed at 55.468
# Patient 69 departs at 55.721; Length of stay: 5.934 days; Time in system: 35.590 days
# Patient 69 transferred to ESD at 55.721
# Patient 69 discharged at 55.721
# Patient 78 (Stroke) gets a bed at 55.721
# Patient 172 Other arrival at: 55.795
# Patient 66 departs at 56.009; Length of stay: 8.232 days; Time in system: 36.420 days
# Patient 66 discharged at 56.009
# Patient 79 (Stroke) gets a bed at 56.009
# Patient 173 Other arrival at: 56.653
# Patient 174 ComplexNeuro arrival at: 56.850
# Patient 175 Other arrival at: 57.201
# Patient 176 ComplexNeuro arrival at: 57.378
# Patient 177 STROKE arrival at: 57.535
# Patient 178 STROKE arrival at: 57.717
# Patient 179 TIA arrival at: 58.715
# Patient 180 STROKE arrival at: 58.876
# Patient 72 departs at 59.459; Length of stay: 6.894 days; Time in system: 38.697 days
# Patient 72 discharged at 59.459
# Patient 80 (Other) gets a bed at 59.459
# Patient 70 departs at 59.499; Length of stay: 8.314 days; Time in system: 39.202 days
# Patient 70 discharged at 59.499
# Patient 81 (Stroke) gets a bed at 59.499
# Patient 181 STROKE arrival at: 59.748
# Patient 71 departs at 59.764; Length of stay: 7.265 days; Time in system: 39.050 days
# Patient 71 discharged at 59.764
# Patient 82 (ComplexNeuro) gets a bed at 59.764
# Patient 73 departs at 59.921; Length of stay: 7.073 days; Time in system: 38.632 days
# Patient 73 discharged at 59.921
# Patient 83 (TIA) gets a bed at 59.921
# Patient 182 STROKE arrival at: 59.938
# Patient 183 STROKE arrival at: 60.394
# Patient 184 ComplexNeuro arrival at: 60.536
# Patient 185 Other arrival at: 60.608
# Patient 186 ComplexNeuro arrival at: 60.618
# Patient 187 STROKE arrival at: 60.657
# Patient 188 STROKE arrival at: 61.030
# Patient 189 STROKE arrival at: 61.198
# Patient 74 departs at 61.303; Length of stay: 8.368 days; Time in system: 39.991 days
# Patient 74 discharged at 61.303
# Patient 84 (ComplexNeuro) gets a bed at 61.303
# Patient 190 STROKE arrival at: 61.424
# Patient 191 STROKE arrival at: 61.796
# Patient 75 departs at 62.055; Length of stay: 8.418 days; Time in system: 40.509 days
# Patient 75 discharged at 62.055
# Patient 85 (Stroke) gets a bed at 62.055
# Patient 192 Other arrival at: 62.320
# Patient 193 STROKE arrival at: 62.957
# Patient 77 departs at 63.120; Length of stay: 7.652 days; Time in system: 41.116 days
# Patient 77 discharged at 63.120
# Patient 86 (Stroke) gets a bed at 63.120
# Patient 79 departs at 63.210; Length of stay: 7.201 days; Time in system: 40.363 days
# Patient 79 discharged at 63.210
# Patient 87 (Stroke) gets a bed at 63.210
# Patient 194 STROKE arrival at: 63.231
# Patient 195 STROKE arrival at: 63.454
# Patient 76 departs at 63.748; Length of stay: 8.907 days; Time in system: 41.781 days
# Patient 76 transferred to ESD at 63.748
# Patient 76 discharged at 63.748
# Patient 88 (Stroke) gets a bed at 63.748
# Patient 196 STROKE arrival at: 64.052
# Patient 78 departs at 65.036; Length of stay: 9.314 days; Time in system: 42.982 days
# Patient 78 discharged at 65.036
# Patient 89 (Stroke) gets a bed at 65.036
# Patient 197 ComplexNeuro arrival at: 65.080
# Patient 83 departs at 65.677; Length of stay: 5.756 days; Time in system: 41.802 days
# Patient 83 discharged at 65.677
# Patient 90 (Stroke) gets a bed at 65.677
# Patient 198 STROKE arrival at: 65.902
# Patient 199 ComplexNeuro arrival at: 65.925
# Patient 200 STROKE arrival at: 66.045
# Patient 81 departs at 66.066; Length of stay: 6.566 days; Time in system: 42.651 days
# Patient 81 discharged at 66.066
# Patient 91 (Stroke) gets a bed at 66.066
# Patient 201 ComplexNeuro arrival at: 66.123
# Patient 202 STROKE arrival at: 66.250
# Patient 203 TIA arrival at: 66.432
# Patient 204 ComplexNeuro arrival at: 66.953
# Patient 205 STROKE arrival at: 67.308
# Patient 82 departs at 67.317; Length of stay: 7.553 days; Time in system: 43.690 days
# Patient 82 transferred to ESD at 67.317
# Patient 82 discharged at 67.317
# Patient 92 (Stroke) gets a bed at 67.317
# Patient 206 ComplexNeuro arrival at: 67.480
# Patient 207 ComplexNeuro arrival at: 67.509
# Patient 208 STROKE arrival at: 67.678
# Patient 209 STROKE arrival at: 67.826
# Patient 210 STROKE arrival at: 67.853
# Patient 211 STROKE arrival at: 67.938
# Patient 80 departs at 68.226; Length of stay: 8.767 days; Time in system: 45.313 days
# Patient 80 discharged at 68.226
# Patient 93 (Stroke) gets a bed at 68.226
# Patient 212 STROKE arrival at: 68.306
# Patient 213 Other arrival at: 68.340
# Patient 84 departs at 68.419; Length of stay: 7.116 days; Time in system: 44.399 days
# Patient 84 discharged at 68.419
# Patient 94 (Stroke) gets a bed at 68.419
# Patient 87 departs at 68.873; Length of stay: 5.663 days; Time in system: 44.065 days
# Patient 87 discharged at 68.873
# Patient 95 (Stroke) gets a bed at 68.873
# Patient 214 STROKE arrival at: 69.036
# Patient 85 departs at 69.115; Length of stay: 7.059 days; Time in system: 44.643 days
# Patient 85 discharged at 69.115
# Patient 96 (Other) gets a bed at 69.115
# Patient 215 ComplexNeuro arrival at: 69.324
# Patient 216 STROKE arrival at: 69.389
# Patient 217 STROKE arrival at: 69.444
# Patient 218 STROKE arrival at: 69.472
# Patient 219 Other arrival at: 70.137
# Patient 220 TIA arrival at: 70.264
# Patient 221 STROKE arrival at: 70.441
# Patient 222 TIA arrival at: 70.674
# Patient 86 departs at 70.855; Length of stay: 7.735 days; Time in system: 46.094 days
# Patient 86 discharged at 70.855
# Patient 97 (Stroke) gets a bed at 70.855
# Patient 88 departs at 71.803; Length of stay: 8.055 days; Time in system: 46.796 days
# Patient 88 discharged at 71.803
# Patient 98 (Stroke) gets a bed at 71.803
# Patient 223 STROKE arrival at: 72.227
# Patient 90 departs at 72.519; Length of stay: 6.842 days; Time in system: 47.347 days
# Patient 90 discharged at 72.519
# Patient 99 (Stroke) gets a bed at 72.519
# Patient 89 departs at 72.590; Length of stay: 7.554 days; Time in system: 47.443 days
# Patient 89 discharged at 72.590
# Patient 100 (Other) gets a bed at 72.590
# Patient 224 STROKE arrival at: 72.650
# Patient 225 STROKE arrival at: 72.719
# Patient 91 departs at 73.108; Length of stay: 7.042 days; Time in system: 47.735 days
# Patient 91 discharged at 73.108
# Patient 101 (Other) gets a bed at 73.108
# Patient 226 Other arrival at: 73.528
# Patient 92 departs at 73.622; Length of stay: 6.305 days; Time in system: 48.190 days
# Patient 92 discharged at 73.622
# Patient 102 (TIA) gets a bed at 73.622
# Patient 227 ComplexNeuro arrival at: 73.623
# Patient 228 Other arrival at: 74.473
# Patient 229 STROKE arrival at: 74.662
# Patient 230 ComplexNeuro arrival at: 74.685
# Patient 231 STROKE arrival at: 74.689
# Patient 232 STROKE arrival at: 74.773
# Patient 94 departs at 74.877; Length of stay: 6.458 days; Time in system: 47.250 days
# Patient 94 discharged at 74.877
# Patient 103 (Stroke) gets a bed at 74.877
# Patient 233 Other arrival at: 75.066
# Patient 234 STROKE arrival at: 75.582
# Patient 235 ComplexNeuro arrival at: 75.705
# Patient 236 ComplexNeuro arrival at: 75.942
# Patient 95 departs at 75.951; Length of stay: 7.078 days; Time in system: 47.983 days
# Patient 95 discharged at 75.951
# Patient 104 (Stroke) gets a bed at 75.951
# Patient 93 departs at 76.166; Length of stay: 7.940 days; Time in system: 49.215 days
# Patient 93 transferred to ESD at 76.166
# Patient 93 discharged at 76.166
# Patient 105 (ComplexNeuro) gets a bed at 76.166
# Patient 97 departs at 76.998; Length of stay: 6.143 days; Time in system: 48.553 days
# Patient 97 discharged at 76.998
# Patient 106 (Stroke) gets a bed at 76.998
# Patient 96 departs at 77.254; Length of stay: 8.139 days; Time in system: 49.153 days
# Patient 96 discharged at 77.254
# Patient 107 (Stroke) gets a bed at 77.254
# Patient 237 STROKE arrival at: 77.259
# Patient 238 Other arrival at: 77.417
# Patient 239 STROKE arrival at: 77.551
# Patient 240 ComplexNeuro arrival at: 78.118
# Patient 241 Other arrival at: 78.305
# Patient 242 Other arrival at: 78.678
# Patient 243 Other arrival at: 78.698
# Patient 98 departs at 78.717; Length of stay: 6.914 days; Time in system: 49.838 days
# Patient 98 discharged at 78.717
# Patient 108 (TIA) gets a bed at 78.717
# Patient 244 STROKE arrival at: 78.732
# Patient 245 ComplexNeuro arrival at: 78.745
# Patient 101 departs at 78.869; Length of stay: 5.761 days; Time in system: 49.455 days
# Patient 101 discharged at 78.869
# Patient 109 (ComplexNeuro) gets a bed at 78.869
# Patient 246 STROKE arrival at: 79.076
# Patient 102 departs at 79.661; Length of stay: 6.039 days; Time in system: 49.834 days
# Patient 102 discharged at 79.661
# Patient 110 (Stroke) gets a bed at 79.661
# Patient 100 departs at 80.024; Length of stay: 7.434 days; Time in system: 50.724 days
# Patient 100 discharged at 80.024
# Patient 111 (Stroke) gets a bed at 80.024
# Patient 247 ComplexNeuro arrival at: 80.157
# Patient 248 ComplexNeuro arrival at: 80.213
# Patient 249 ComplexNeuro arrival at: 80.222
# Patient 250 STROKE arrival at: 81.012
# Patient 103 departs at 81.035; Length of stay: 6.158 days; Time in system: 50.808 days
# Patient 103 discharged at 81.035
# Patient 112 (Stroke) gets a bed at 81.035
# Patient 99 departs at 81.117; Length of stay: 8.598 days; Time in system: 52.083 days
# Patient 99 discharged at 81.117
# Patient 113 (TIA) gets a bed at 81.117
# Patient 251 STROKE arrival at: 81.207
# Patient 252 ComplexNeuro arrival at: 81.338
# Patient 253 STROKE arrival at: 81.568
# Patient 254 TIA arrival at: 81.696
# Patient 255 STROKE arrival at: 82.142
# Patient 256 STROKE arrival at: 82.202
# Patient 104 departs at 82.579; Length of stay: 6.628 days; Time in system: 52.245 days
# Patient 104 discharged at 82.579
# Patient 114 (Other) gets a bed at 82.579
# Patient 257 STROKE arrival at: 82.768
# Patient 258 Other arrival at: 82.884
# Patient 107 departs at 82.893; Length of stay: 5.640 days; Time in system: 50.750 days
# Patient 107 discharged at 82.893
# Patient 115 (Stroke) gets a bed at 82.893
# Patient 259 STROKE arrival at: 83.046
# Patient 260 STROKE arrival at: 83.080
# Patient 261 STROKE arrival at: 83.504
# Patient 262 Other arrival at: 83.813
# Patient 106 departs at 83.930; Length of stay: 6.932 days; Time in system: 52.052 days
# Patient 106 discharged at 83.930
# Patient 116 (Stroke) gets a bed at 83.930
# Patient 263 STROKE arrival at: 84.985
# Patient 264 Other arrival at: 85.160
# Patient 105 departs at 85.345; Length of stay: 9.179 days; Time in system: 53.743 days
# Patient 105 discharged at 85.345
# Patient 117 (Stroke) gets a bed at 85.345
# Patient 265 STROKE arrival at: 85.682
# Patient 266 Other arrival at: 85.853
# Patient 108 departs at 86.503; Length of stay: 7.786 days; Time in system: 53.133 days
# Patient 108 discharged at 86.503
# Patient 118 (Other) gets a bed at 86.503
# Patient 267 STROKE arrival at: 86.516
# Patient 268 STROKE arrival at: 86.717
# Patient 109 departs at 86.822; Length of stay: 7.953 days; Time in system: 53.158 days
# Patient 109 discharged at 86.822
# Patient 119 (Stroke) gets a bed at 86.822
# Patient 113 departs at 86.880; Length of stay: 5.763 days; Time in system: 48.846 days
# Patient 113 discharged at 86.880
# Patient 120 (Stroke) gets a bed at 86.880
# Patient 111 departs at 87.620; Length of stay: 7.596 days; Time in system: 50.974 days
# Patient 111 discharged at 87.620
# Patient 121 (ComplexNeuro) gets a bed at 87.620
# Patient 112 departs at 87.745; Length of stay: 6.710 days; Time in system: 49.847 days
# Patient 112 discharged at 87.745
# Patient 122 (Stroke) gets a bed at 87.745
# Patient 110 departs at 87.818; Length of stay: 8.157 days; Time in system: 53.146 days
# Patient 110 discharged at 87.818
# Patient 123 (Stroke) gets a bed at 87.818
# Patient 115 departs at 88.436; Length of stay: 5.542 days; Time in system: 50.186 days
# Patient 115 discharged at 88.436
# Patient 124 (Stroke) gets a bed at 88.436
# Patient 269 Other arrival at: 88.917
# Patient 114 departs at 88.927; Length of stay: 6.349 days; Time in system: 50.844 days
# Patient 114 discharged at 88.927
# Patient 125 (Stroke) gets a bed at 88.927
# Patient 270 STROKE arrival at: 89.767
# Patient 271 STROKE arrival at: 90.059
# Patient 272 STROKE arrival at: 90.205
# Patient 273 ComplexNeuro arrival at: 90.540
# Patient 116 departs at 90.857; Length of stay: 6.927 days; Time in system: 52.553 days
# Patient 116 discharged at 90.857
# Patient 126 (Other) gets a bed at 90.857
# Patient 274 STROKE arrival at: 90.861
# Patient 275 Other arrival at: 90.986
# Patient 276 STROKE arrival at: 91.014
# Patient 277 STROKE arrival at: 91.243
# Patient 278 Other arrival at: 91.376
# Patient 117 departs at 91.862; Length of stay: 6.517 days; Time in system: 53.253 days
# Patient 117 discharged at 91.862
# Patient 127 (Stroke) gets a bed at 91.862
# Patient 279 Other arrival at: 92.154
# Patient 118 departs at 92.787; Length of stay: 6.284 days; Time in system: 53.916 days
# Patient 118 transferred to ESD at 92.787
# Patient 118 discharged at 92.787
# Patient 128 (Other) gets a bed at 92.787
# Patient 280 STROKE arrival at: 92.854
# Patient 281 STROKE arrival at: 93.129
# Patient 119 departs at 93.175; Length of stay: 6.353 days; Time in system: 53.820 days
# Patient 119 discharged at 93.175
# Patient 129 (ComplexNeuro) gets a bed at 93.175
# Patient 282 ComplexNeuro arrival at: 93.398
# Patient 283 STROKE arrival at: 93.475
# Patient 284 STROKE arrival at: 94.007
# Patient 285 STROKE arrival at: 94.033
# Patient 286 ComplexNeuro arrival at: 94.282
# Patient 121 departs at 94.527; Length of stay: 6.907 days; Time in system: 54.662 days
# Patient 121 discharged at 94.527
# Patient 130 (Other) gets a bed at 94.527
# Patient 120 departs at 94.688; Length of stay: 7.808 days; Time in system: 55.237 days
# Patient 120 discharged at 94.688
# Patient 131 (Stroke) gets a bed at 94.688
# Patient 287 STROKE arrival at: 94.906
# Patient 125 departs at 95.108; Length of stay: 6.180 days; Time in system: 53.223 days
# Patient 125 transferred to ESD at 95.108
# Patient 125 discharged at 95.108
# Patient 132 (ComplexNeuro) gets a bed at 95.108
# Patient 288 STROKE arrival at: 95.336
# Patient 123 departs at 95.353; Length of stay: 7.535 days; Time in system: 53.791 days
# Patient 123 discharged at 95.353
# Patient 133 (TIA) gets a bed at 95.353
# Patient 289 Other arrival at: 95.445
# Patient 124 departs at 95.701; Length of stay: 7.265 days; Time in system: 54.079 days
# Patient 124 discharged at 95.701
# Patient 134 (Other) gets a bed at 95.701
# Patient 122 departs at 95.759; Length of stay: 8.014 days; Time in system: 54.595 days
# Patient 122 discharged at 95.759
# Patient 135 (Other) gets a bed at 95.759
# Patient 290 STROKE arrival at: 96.254
# Patient 291 STROKE arrival at: 96.312
# Patient 292 ComplexNeuro arrival at: 96.456
# Patient 293 STROKE arrival at: 96.677
# Patient 294 STROKE arrival at: 96.680
# Patient 295 STROKE arrival at: 97.347
# Patient 296 ComplexNeuro arrival at: 97.694
# Patient 297 Other arrival at: 98.663
# Patient 298 STROKE arrival at: 98.955
# Patient 299 ComplexNeuro arrival at: 99.229
# Patient 300 STROKE arrival at: 99.238
# Patient 301 STROKE arrival at: 99.318
# Patient 302 STROKE arrival at: 99.461
# Patient 303 ComplexNeuro arrival at: 99.476
# Patient 304 ComplexNeuro arrival at: 99.791
# Patient 126 departs at 99.858; Length of stay: 9.001 days; Time in system: 57.947 days
# Patient 126 discharged at 99.858
# Patient 136 (Stroke) gets a bed at 99.858
# Patient 128 departs at 100.114; Length of stay: 7.327 days; Time in system: 57.206 days
# Patient 128 discharged at 100.114
# Patient 137 (Stroke) gets a bed at 100.114
# Patient 129 departs at 100.364; Length of stay: 7.189 days; Time in system: 57.048 days
# Patient 129 discharged at 100.364
# Patient 138 (Stroke) gets a bed at 100.364
# Patient 127 departs at 100.387; Length of stay: 8.525 days; Time in system: 57.655 days
# Patient 127 discharged at 100.387
# Patient 139 (Stroke) gets a bed at 100.387
# Patient 305 STROKE arrival at: 100.689
# Patient 133 departs at 100.720; Length of stay: 5.367 days; Time in system: 56.886 days
# Patient 133 discharged at 100.720
# Patient 140 (Stroke) gets a bed at 100.720
# Patient 306 Other arrival at: 100.823
# Patient 131 departs at 100.910; Length of stay: 6.222 days; Time in system: 57.193 days
# Patient 131 discharged at 100.910
# Patient 141 (Stroke) gets a bed at 100.910
# Patient 307 Other arrival at: 100.929
# Patient 308 STROKE arrival at: 101.162
# Patient 135 departs at 101.489; Length of stay: 5.730 days; Time in system: 56.834 days
# Patient 135 transferred to ESD at 101.489
# Patient 135 discharged at 101.489
# Patient 142 (ComplexNeuro) gets a bed at 101.489
# Patient 309 STROKE arrival at: 101.830
# Patient 134 departs at 102.054; Length of stay: 6.353 days; Time in system: 57.622 days
# Patient 134 discharged at 102.054
# Patient 143 (Stroke) gets a bed at 102.054
# Patient 130 departs at 102.210; Length of stay: 7.682 days; Time in system: 58.600 days
# Patient 130 discharged at 102.210
# Patient 144 (Stroke) gets a bed at 102.210
# Patient 310 STROKE arrival at: 102.587
# Patient 311 STROKE arrival at: 103.053
# Patient 312 Other arrival at: 103.696
# Patient 313 STROKE arrival at: 103.897
# Patient 314 Other arrival at: 103.988
# Patient 132 departs at 104.361; Length of stay: 9.253 days; Time in system: 60.595 days
# Patient 132 discharged at 104.361
# Patient 145 (Stroke) gets a bed at 104.361
# Patient 315 ComplexNeuro arrival at: 104.596
# Patient 139 departs at 105.018; Length of stay: 4.631 days; Time in system: 58.397 days
# Patient 139 discharged at 105.018
# Patient 146 (ComplexNeuro) gets a bed at 105.018
# Patient 316 Other arrival at: 105.557
# Patient 317 STROKE arrival at: 105.758
# Patient 318 STROKE arrival at: 106.553
# Patient 319 STROKE arrival at: 106.662
# Patient 136 departs at 106.734; Length of stay: 6.876 days; Time in system: 61.785 days
# Patient 136 discharged at 106.734
# Patient 147 (Stroke) gets a bed at 106.734
# Patient 320 ComplexNeuro arrival at: 106.840
# Patient 321 ComplexNeuro arrival at: 107.021
# Patient 322 Other arrival at: 107.059
# Patient 323 STROKE arrival at: 107.285
# Patient 324 Other arrival at: 107.394
# Patient 325 Other arrival at: 107.721
# Patient 140 departs at 107.887; Length of stay: 7.167 days; Time in system: 61.105 days
# Patient 140 discharged at 107.887
# Patient 148 (Other) gets a bed at 107.887
# Patient 138 departs at 107.957; Length of stay: 7.593 days; Time in system: 61.682 days
# Patient 138 discharged at 107.957
# Patient 149 (Stroke) gets a bed at 107.957
# Patient 326 Other arrival at: 107.969
# Patient 137 departs at 108.200; Length of stay: 8.085 days; Time in system: 62.347 days
# Patient 137 discharged at 108.200
# Patient 150 (Stroke) gets a bed at 108.200
# Patient 327 STROKE arrival at: 108.301
# Patient 328 ComplexNeuro arrival at: 108.301
# Patient 329 STROKE arrival at: 108.346
# Patient 330 ComplexNeuro arrival at: 108.636
# Patient 141 departs at 109.588; Length of stay: 8.678 days; Time in system: 62.634 days
# Patient 141 discharged at 109.588
# Patient 151 (Other) gets a bed at 109.588
# Patient 331 STROKE arrival at: 109.600
# Patient 143 departs at 109.682; Length of stay: 7.628 days; Time in system: 62.588 days
# Patient 143 discharged at 109.682
# Patient 152 (ComplexNeuro) gets a bed at 109.682
# Patient 332 STROKE arrival at: 109.768
# Patient 142 departs at 109.831; Length of stay: 8.342 days; Time in system: 62.822 days
# Patient 142 discharged at 109.831
# Patient 153 (Stroke) gets a bed at 109.831
# Patient 333 ComplexNeuro arrival at: 110.533
# Patient 144 departs at 110.750; Length of stay: 8.540 days; Time in system: 63.590 days
# Patient 144 discharged at 110.750
# Patient 154 (Stroke) gets a bed at 110.750
# Patient 334 STROKE arrival at: 111.027
# Patient 335 ComplexNeuro arrival at: 111.080
# Patient 336 Other arrival at: 111.221
# Patient 337 STROKE arrival at: 111.229
# Patient 338 STROKE arrival at: 111.367
# Patient 339 Other arrival at: 111.379
# Patient 340 Other arrival at: 111.440
# Patient 145 departs at 111.630; Length of stay: 7.269 days; Time in system: 64.201 days
# Patient 145 discharged at 111.630
# Patient 155 (ComplexNeuro) gets a bed at 111.630
# Patient 341 ComplexNeuro arrival at: 111.657
# Patient 342 STROKE arrival at: 111.696
# Patient 343 Other arrival at: 111.709
# Patient 146 departs at 111.712; Length of stay: 6.694 days; Time in system: 63.812 days
# Patient 146 discharged at 111.712
# Patient 156 (Stroke) gets a bed at 111.712
# Patient 344 STROKE arrival at: 111.714
# Patient 345 STROKE arrival at: 112.198
# Patient 147 departs at 112.330; Length of stay: 5.596 days; Time in system: 64.362 days
# Patient 147 discharged at 112.330
# Patient 157 (Stroke) gets a bed at 112.330
# Patient 346 STROKE arrival at: 112.507
# Patient 347 STROKE arrival at: 113.040
# Patient 348 Other arrival at: 113.193
# Patient 349 Other arrival at: 113.728
# Patient 350 Other arrival at: 113.796
# Patient 149 departs at 114.115; Length of stay: 6.158 days; Time in system: 65.683 days
# Patient 149 transferred to ESD at 114.115
# Patient 149 discharged at 114.115
# Patient 158 (Stroke) gets a bed at 114.115
# Patient 148 departs at 115.045; Length of stay: 7.158 days; Time in system: 67.068 days
# Patient 148 discharged at 115.045
# Patient 159 (Stroke) gets a bed at 115.045
# Patient 351 STROKE arrival at: 115.521
# Patient 150 departs at 115.724; Length of stay: 7.524 days; Time in system: 66.504 days
# Patient 150 discharged at 115.724
# Patient 160 (ComplexNeuro) gets a bed at 115.724
# Patient 352 STROKE arrival at: 115.867
# Patient 353 STROKE arrival at: 116.105
# Patient 354 STROKE arrival at: 116.114
# Patient 153 departs at 116.165; Length of stay: 6.334 days; Time in system: 66.720 days
# Patient 153 discharged at 116.165
# Patient 161 (Stroke) gets a bed at 116.165
# Patient 355 ComplexNeuro arrival at: 116.527
# Patient 356 STROKE arrival at: 116.640
# Patient 152 departs at 116.737; Length of stay: 7.054 days; Time in system: 67.304 days
# Patient 152 discharged at 116.737
# Patient 162 (Stroke) gets a bed at 116.737
# Patient 357 STROKE arrival at: 116.821
# Patient 358 STROKE arrival at: 116.828
# Patient 359 STROKE arrival at: 116.956
# Patient 360 ComplexNeuro arrival at: 116.971
# Patient 154 departs at 117.387; Length of stay: 6.637 days; Time in system: 67.833 days
# Patient 154 discharged at 117.387
# Patient 163 (Stroke) gets a bed at 117.387
# Patient 361 STROKE arrival at: 117.777
# Patient 362 TIA arrival at: 118.725
# Patient 156 departs at 118.914; Length of stay: 7.202 days; Time in system: 67.810 days
# Patient 156 transferred to ESD at 118.914
# Patient 156 discharged at 118.914
# Patient 164 (ComplexNeuro) gets a bed at 118.914
# Patient 363 STROKE arrival at: 118.998
# Patient 151 departs at 119.032; Length of stay: 9.444 days; Time in system: 69.698 days
# Patient 151 discharged at 119.032
# Patient 165 (Stroke) gets a bed at 119.032
# Patient 155 departs at 119.240; Length of stay: 7.610 days; Time in system: 68.163 days
# Patient 155 discharged at 119.240
# Patient 166 (Other) gets a bed at 119.240
# Patient 364 STROKE arrival at: 119.302
# Patient 365 Other arrival at: 119.476
# Patient 366 STROKE arrival at: 119.650
# Patient 157 departs at 119.675; Length of stay: 7.344 days; Time in system: 68.176 days
# Patient 157 discharged at 119.675
# Patient 167 (ComplexNeuro) gets a bed at 119.675
# Patient 367 ComplexNeuro arrival at: 119.911
# Patient 368 Other arrival at: 119.980
# Patient 369 ComplexNeuro arrival at: 120.055
# Patient 370 Other arrival at: 120.649
# Patient 371 ComplexNeuro arrival at: 120.717
# Patient 372 TIA arrival at: 121.098
# Patient 373 STROKE arrival at: 121.733
# Patient 158 departs at 121.742; Length of stay: 7.627 days; Time in system: 70.002 days
# Patient 158 discharged at 121.742
# Patient 168 (Stroke) gets a bed at 121.742
# Patient 374 STROKE arrival at: 122.442
# Patient 159 departs at 122.497; Length of stay: 7.452 days; Time in system: 70.750 days
# Patient 159 discharged at 122.497
# Patient 169 (ComplexNeuro) gets a bed at 122.497
# Patient 375 STROKE arrival at: 122.650
# Patient 162 departs at 122.788; Length of stay: 6.052 days; Time in system: 70.585 days
# Patient 162 discharged at 122.788
# Patient 170 (Other) gets a bed at 122.788
# Patient 376 Other arrival at: 122.821
# Patient 377 ComplexNeuro arrival at: 122.873
# Patient 378 Other arrival at: 122.918
# Patient 160 departs at 122.959; Length of stay: 7.234 days; Time in system: 71.199 days
# Patient 160 transferred to ESD at 122.959
# Patient 160 discharged at 122.959
# Patient 171 (Stroke) gets a bed at 122.959
# Patient 163 departs at 123.000; Length of stay: 5.613 days; Time in system: 70.623 days
# Patient 163 discharged at 123.000
# Patient 172 (Other) gets a bed at 123.000
# Patient 379 STROKE arrival at: 123.079
# Patient 380 Other arrival at: 123.474
# Patient 381 STROKE arrival at: 123.479
# Patient 382 STROKE arrival at: 123.782
# Patient 161 departs at 123.858; Length of stay: 7.693 days; Time in system: 71.746 days
# Patient 161 discharged at 123.858
# Patient 173 (Other) gets a bed at 123.858
# Patient 383 ComplexNeuro arrival at: 124.338
# Patient 384 ComplexNeuro arrival at: 124.442
# Patient 385 Other arrival at: 124.481
# Patient 386 STROKE arrival at: 124.518
# Patient 387 STROKE arrival at: 125.035
# Patient 388 STROKE arrival at: 125.297
# Patient 389 Other arrival at: 125.384
# Patient 390 Other arrival at: 125.398
# Patient 391 Other arrival at: 125.488
# Patient 392 Other arrival at: 125.533
# Patient 393 ComplexNeuro arrival at: 125.995
# Patient 394 STROKE arrival at: 126.074
# Patient 395 ComplexNeuro arrival at: 126.232
# Patient 396 Other arrival at: 126.667
# Patient 397 Other arrival at: 126.668
# Patient 398 STROKE arrival at: 126.837
# Patient 167 departs at 126.863; Length of stay: 7.188 days; Time in system: 73.399 days
# Patient 167 discharged at 126.863
# Patient 174 (ComplexNeuro) gets a bed at 126.863
# Patient 399 Other arrival at: 126.931
# Patient 166 departs at 127.394; Length of stay: 8.153 days; Time in system: 74.557 days
# Patient 166 discharged at 127.394
# Patient 175 (Other) gets a bed at 127.394
# Patient 400 STROKE arrival at: 127.459
# Patient 401 ComplexNeuro arrival at: 127.822
# Patient 402 ComplexNeuro arrival at: 127.895
# Patient 164 departs at 127.913; Length of stay: 8.999 days; Time in system: 75.126 days
# Patient 164 transferred to ESD at 127.913
# Patient 164 discharged at 127.913
# Patient 176 (ComplexNeuro) gets a bed at 127.913
# Patient 403 ComplexNeuro arrival at: 127.932
# Patient 404 STROKE arrival at: 128.091
# Patient 405 STROKE arrival at: 128.132
# Patient 406 TIA arrival at: 128.435
# Patient 407 ComplexNeuro arrival at: 128.454
# Patient 165 departs at 128.552; Length of stay: 9.521 days; Time in system: 75.745 days
# Patient 165 transferred to ESD at 128.552
# Patient 165 discharged at 128.552
# Patient 177 (Stroke) gets a bed at 128.552
# Patient 169 departs at 128.902; Length of stay: 6.404 days; Time in system: 74.579 days
# Patient 169 discharged at 128.902
# Patient 178 (Stroke) gets a bed at 128.902
# Patient 408 STROKE arrival at: 129.137
# Patient 171 departs at 129.169; Length of stay: 6.211 days; Time in system: 74.091 days
# Patient 171 discharged at 129.169
# Patient 179 (TIA) gets a bed at 129.169
# Patient 409 ComplexNeuro arrival at: 129.207
# Patient 168 departs at 129.503; Length of stay: 7.761 days; Time in system: 75.485 days
# Patient 168 discharged at 129.503
# Patient 180 (Stroke) gets a bed at 129.503
# Patient 410 STROKE arrival at: 129.938
# Patient 172 departs at 130.242; Length of stay: 7.243 days; Time in system: 74.447 days
# Patient 172 discharged at 130.242
# Patient 181 (Stroke) gets a bed at 130.242
# Patient 411 STROKE arrival at: 130.465
# Patient 412 STROKE arrival at: 130.698
# Patient 413 STROKE arrival at: 130.752
# Patient 414 Other arrival at: 131.278
# Patient 415 ComplexNeuro arrival at: 131.519
# Patient 416 STROKE arrival at: 131.551
# Patient 417 TIA arrival at: 131.939
# Patient 418 STROKE arrival at: 131.942
# Patient 173 departs at 132.081; Length of stay: 8.223 days; Time in system: 75.428 days
# Patient 173 discharged at 132.081
# Patient 182 (Stroke) gets a bed at 132.081
# Patient 170 departs at 132.380; Length of stay: 9.592 days; Time in system: 77.446 days
# Patient 170 discharged at 132.380
# Patient 183 (Stroke) gets a bed at 132.380
# Patient 419 STROKE arrival at: 133.183
# Patient 420 Other arrival at: 133.352
# Patient 421 STROKE arrival at: 133.662
# Patient 174 departs at 133.843; Length of stay: 6.980 days; Time in system: 76.992 days
# Patient 174 discharged at 133.843
# Patient 184 (ComplexNeuro) gets a bed at 133.843
# Patient 175 departs at 133.888; Length of stay: 6.495 days; Time in system: 76.688 days
# Patient 175 discharged at 133.888
# Patient 185 (Other) gets a bed at 133.888
# Patient 422 STROKE arrival at: 134.140
# Patient 423 Other arrival at: 134.249
# Patient 176 departs at 134.682; Length of stay: 6.769 days; Time in system: 77.304 days
# Patient 176 discharged at 134.682
# Patient 186 (ComplexNeuro) gets a bed at 134.682
# Patient 177 departs at 135.704; Length of stay: 7.151 days; Time in system: 78.169 days
# Patient 177 discharged at 135.704
# Patient 187 (Stroke) gets a bed at 135.704
# Patient 424 STROKE arrival at: 136.746
# Patient 425 STROKE arrival at: 136.818
# Patient 181 departs at 136.831; Length of stay: 6.589 days; Time in system: 77.083 days
# Patient 181 discharged at 136.831
# Patient 188 (Stroke) gets a bed at 136.831
# Patient 426 STROKE arrival at: 136.863
# Patient 179 departs at 136.977; Length of stay: 7.807 days; Time in system: 78.262 days
# Patient 179 discharged at 136.977
# Patient 189 (Stroke) gets a bed at 136.977
# Patient 427 ComplexNeuro arrival at: 137.336
# Patient 428 ComplexNeuro arrival at: 137.503
# Patient 178 departs at 137.588; Length of stay: 8.686 days; Time in system: 79.871 days
# Patient 178 discharged at 137.588
# Patient 190 (Stroke) gets a bed at 137.588
# Patient 180 departs at 138.508; Length of stay: 9.005 days; Time in system: 79.632 days
# Patient 180 discharged at 138.508
# Patient 191 (Stroke) gets a bed at 138.508
# Patient 429 Other arrival at: 138.908
# Patient 430 STROKE arrival at: 139.092
# Patient 431 STROKE arrival at: 139.304
# Patient 183 departs at 139.631; Length of stay: 7.251 days; Time in system: 79.237 days
# Patient 183 discharged at 139.631
# Patient 192 (Other) gets a bed at 139.631
# Patient 182 departs at 139.646; Length of stay: 7.564 days; Time in system: 79.708 days
# Patient 182 discharged at 139.646
# Patient 193 (Stroke) gets a bed at 139.646
# Patient 432 STROKE arrival at: 139.866
# Patient 433 STROKE arrival at: 140.031
# Patient 184 departs at 140.145; Length of stay: 6.302 days; Time in system: 79.609 days
# Patient 184 discharged at 140.145
# Patient 194 (Stroke) gets a bed at 140.145
# Patient 185 departs at 142.004; Length of stay: 8.115 days; Time in system: 81.396 days
# Patient 185 transferred to ESD at 142.004
# Patient 185 discharged at 142.004
# Patient 195 (Stroke) gets a bed at 142.004
# ...
# Patient 1873 discharged at 1400.937
# Patient 1887 (Stroke) gets a bed at 1400.937
# Patient 4291 Other arrival at: 1401.336
# Patient 4292 STROKE arrival at: 1401.657
# Patient 4293 STROKE arrival at: 1401.916
# Patient 4294 Other arrival at: 1401.933
# Patient 4295 STROKE arrival at: 1402.241
# Patient 4296 STROKE arrival at: 1402.296
# Patient 4297 STROKE arrival at: 1402.462
# Patient 4298 Other arrival at: 1402.845
# Patient 1881 departs at 1403.150; Length of stay: 6.235 days; Time in system: 785.674 days
# Patient 1881 transferred to ESD at 1403.150
# Patient 1881 discharged at 1403.150
# Patient 1888 (Other) gets a bed at 1403.150
# Patient 1879 departs at 1403.293; Length of stay: 6.554 days; Time in system: 785.962 days
# Patient 1879 discharged at 1403.293
# Patient 1889 (Stroke) gets a bed at 1403.293
# Patient 4299 STROKE arrival at: 1403.567
# Patient 4300 STROKE arrival at: 1403.693
# Patient 4301 STROKE arrival at: 1404.002
# Patient 1880 departs at 1404.103; Length of stay: 7.322 days; Time in system: 786.647 days
# Patient 1880 discharged at 1404.103
# Patient 1890 (Stroke) gets a bed at 1404.103
# Patient 4302 Other arrival at: 1404.699
# Patient 1885 departs at 1405.192; Length of stay: 6.461 days; Time in system: 786.680 days
# Patient 1885 discharged at 1405.192
# Patient 1891 (Stroke) gets a bed at 1405.192
# Patient 1878 departs at 1405.545; Length of stay: 9.094 days; Time in system: 788.283 days
# Patient 1878 discharged at 1405.545
# Patient 1892 (Stroke) gets a bed at 1405.545
# Patient 1882 departs at 1405.623; Length of stay: 7.213 days; Time in system: 787.483 days
# Patient 1882 transferred to ESD at 1405.623
# Patient 1882 discharged at 1405.623
# Patient 1893 (Other) gets a bed at 1405.623
# Patient 1883 departs at 1405.632; Length of stay: 7.013 days; Time in system: 787.359 days
# Patient 1883 discharged at 1405.632
# Patient 1894 (TIA) gets a bed at 1405.632
# Patient 4303 STROKE arrival at: 1405.825
# Patient 4304 STROKE arrival at: 1405.971
# Patient 4305 Other arrival at: 1406.432
# Patient 4306 STROKE arrival at: 1406.732
# Patient 1884 departs at 1406.920; Length of stay: 8.239 days; Time in system: 788.518 days
# Patient 1884 transferred to ESD at 1406.920
# Patient 1884 discharged at 1406.920
# Patient 1895 (ComplexNeuro) gets a bed at 1406.920
# Patient 4307 STROKE arrival at: 1407.404
# Patient 4308 STROKE arrival at: 1407.758
# Patient 4309 ComplexNeuro arrival at: 1408.383
# Patient 4310 TIA arrival at: 1408.432
# Patient 4311 STROKE arrival at: 1408.535
# Patient 1886 departs at 1408.910; Length of stay: 8.960 days; Time in system: 790.005 days
# Patient 1886 discharged at 1408.910
# Patient 1896 (ComplexNeuro) gets a bed at 1408.910
# Patient 4312 Other arrival at: 1409.312
# Patient 1888 departs at 1409.377; Length of stay: 6.228 days; Time in system: 790.150 days
# Patient 1888 transferred to ESD at 1409.377
# Patient 1888 discharged at 1409.377
# Patient 1897 (ComplexNeuro) gets a bed at 1409.377
# Patient 1887 departs at 1409.636; Length of stay: 8.699 days; Time in system: 790.578 days
# Patient 1887 discharged at 1409.636
# Patient 1898 (Stroke) gets a bed at 1409.636
# Patient 4313 ComplexNeuro arrival at: 1409.918
# Patient 4314 Other arrival at: 1410.341
# Patient 1889 departs at 1410.764; Length of stay: 7.471 days; Time in system: 791.012 days
# Patient 1889 discharged at 1410.764
# Patient 1899 (Stroke) gets a bed at 1410.764
# Patient 4315 STROKE arrival at: 1410.880
# Patient 4316 ComplexNeuro arrival at: 1411.218
# Patient 1890 departs at 1411.566; Length of stay: 7.463 days; Time in system: 790.627 days
# Patient 1890 discharged at 1411.566
# Patient 1900 (Other) gets a bed at 1411.566
# Patient 1892 departs at 1412.021; Length of stay: 6.476 days; Time in system: 790.779 days
# Patient 1892 transferred to ESD at 1412.021
# Patient 1892 discharged at 1412.021
# Patient 1901 (Other) gets a bed at 1412.021
# Patient 4317 Other arrival at: 1412.397
# Patient 4318 STROKE arrival at: 1412.534
# Patient 4319 STROKE arrival at: 1412.595
# Patient 4320 TIA arrival at: 1412.885
# Patient 4321 Other arrival at: 1413.114
# Patient 4322 ComplexNeuro arrival at: 1413.312
# Patient 4323 STROKE arrival at: 1413.365
# Patient 4324 Other arrival at: 1413.478
# Patient 4325 STROKE arrival at: 1413.707
# Patient 4326 Other arrival at: 1413.866
# Patient 1893 departs at 1414.210; Length of stay: 8.588 days; Time in system: 792.821 days
# Patient 1893 discharged at 1414.210
# Patient 1902 (Other) gets a bed at 1414.210
# Patient 1894 departs at 1414.224; Length of stay: 8.592 days; Time in system: 792.825 days
# Patient 1894 discharged at 1414.224
# Patient 1903 (Stroke) gets a bed at 1414.224
# Patient 4327 Other arrival at: 1414.383
# Patient 4328 STROKE arrival at: 1414.452
# Patient 4329 STROKE arrival at: 1414.600
# Patient 4330 ComplexNeuro arrival at: 1414.762
# Patient 4331 ComplexNeuro arrival at: 1414.786
# Patient 4332 STROKE arrival at: 1414.900
# Patient 1895 departs at 1415.008; Length of stay: 8.089 days; Time in system: 793.522 days
# Patient 1895 discharged at 1415.008
# Patient 1904 (Stroke) gets a bed at 1415.008
# Patient 4333 STROKE arrival at: 1415.368
# Patient 4334 Other arrival at: 1415.377
# Patient 4335 STROKE arrival at: 1415.432
# Patient 4336 Other arrival at: 1415.546
# Patient 1897 departs at 1415.842; Length of stay: 6.465 days; Time in system: 793.384 days
# Patient 1897 discharged at 1415.842
# Patient 1905 (Stroke) gets a bed at 1415.842
# Patient 4337 STROKE arrival at: 1415.858
# Patient 4338 STROKE arrival at: 1415.960
# Patient 4339 ComplexNeuro arrival at: 1416.372
# Patient 4340 STROKE arrival at: 1416.462
# Patient 4341 STROKE arrival at: 1416.721
# Patient 4342 STROKE arrival at: 1416.953
# Patient 1891 departs at 1417.048; Length of stay: 11.857 days; Time in system: 795.899 days
# Patient 1891 discharged at 1417.048
# Patient 1906 (Stroke) gets a bed at 1417.048
# Patient 4343 TIA arrival at: 1417.227
# Patient 4344 STROKE arrival at: 1417.703
# Patient 1900 departs at 1417.740; Length of stay: 6.175 days; Time in system: 794.868 days
# Patient 1900 transferred to ESD at 1417.740
# Patient 1900 discharged at 1417.740
# Patient 1907 (Stroke) gets a bed at 1417.740
# Patient 1898 departs at 1417.743; Length of stay: 8.107 days; Time in system: 795.260 days
# Patient 1898 discharged at 1417.743
# Patient 1908 (Other) gets a bed at 1417.743
# Patient 4345 STROKE arrival at: 1417.828
# Patient 4346 STROKE arrival at: 1417.910
# Patient 1899 departs at 1418.050; Length of stay: 7.286 days; Time in system: 795.195 days
# Patient 1899 discharged at 1418.050
# Patient 1909 (Other) gets a bed at 1418.050
# Patient 1896 departs at 1418.681; Length of stay: 9.772 days; Time in system: 797.112 days
# Patient 1896 discharged at 1418.681
# Patient 1910 (Other) gets a bed at 1418.681
# Patient 4347 STROKE arrival at: 1419.089
# Patient 4348 ComplexNeuro arrival at: 1419.101
# Patient 1901 departs at 1419.332; Length of stay: 7.311 days; Time in system: 795.999 days
# Patient 1901 transferred to ESD at 1419.332
# Patient 1901 discharged at 1419.332
# Patient 1911 (Other) gets a bed at 1419.332
# Patient 4349 Other arrival at: 1419.875
# Patient 4350 ComplexNeuro arrival at: 1419.897
# Patient 4351 STROKE arrival at: 1420.384
# Patient 1903 departs at 1420.694; Length of stay: 6.469 days; Time in system: 796.923 days
# Patient 1903 transferred to ESD at 1420.694
# Patient 1903 discharged at 1420.694
# Patient 1912 (Stroke) gets a bed at 1420.694
# Patient 4352 ComplexNeuro arrival at: 1420.729
# Patient 4353 STROKE arrival at: 1421.705
# Patient 1902 departs at 1421.763; Length of stay: 7.553 days; Time in system: 798.139 days
# Patient 1902 discharged at 1421.763
# Patient 1913 (ComplexNeuro) gets a bed at 1421.763
# Patient 4354 Other arrival at: 1422.759
# Patient 4355 ComplexNeuro arrival at: 1422.842
# Patient 4356 ComplexNeuro arrival at: 1423.152
# Patient 1905 departs at 1423.426; Length of stay: 7.583 days; Time in system: 799.119 days
# Patient 1905 discharged at 1423.426
# Patient 1914 (Stroke) gets a bed at 1423.426
# Patient 4357 Other arrival at: 1423.472
# Patient 4358 TIA arrival at: 1423.481
# Patient 4359 ComplexNeuro arrival at: 1424.357
# Patient 4360 STROKE arrival at: 1424.406
# Patient 4361 TIA arrival at: 1424.554
# Patient 4362 ComplexNeuro arrival at: 1425.021
# Patient 1909 departs at 1425.174; Length of stay: 7.124 days; Time in system: 798.703 days
# Patient 1909 transferred to ESD at 1425.174
# Patient 1909 discharged at 1425.174
# Patient 1915 (Other) gets a bed at 1425.174
# Patient 4363 STROKE arrival at: 1425.291
# Patient 1904 departs at 1425.349; Length of stay: 10.340 days; Time in system: 801.139 days
# Patient 1904 discharged at 1425.349
# Patient 1916 (Stroke) gets a bed at 1425.349
# Patient 4364 Other arrival at: 1425.554
# Patient 4365 Other arrival at: 1425.853
# Patient 4366 STROKE arrival at: 1425.923
# Patient 4367 Other arrival at: 1426.319
# Patient 1907 departs at 1426.348; Length of stay: 8.607 days; Time in system: 801.447 days
# Patient 1907 discharged at 1426.348
# Patient 1917 (TIA) gets a bed at 1426.348
# Patient 1906 departs at 1426.362; Length of stay: 9.314 days; Time in system: 801.615 days
# Patient 1906 discharged at 1426.362
# Patient 1918 (Stroke) gets a bed at 1426.362
# Patient 1911 departs at 1426.581; Length of stay: 7.249 days; Time in system: 799.591 days
# Patient 1911 discharged at 1426.581
# Patient 1919 (Stroke) gets a bed at 1426.581
# Patient 4368 ComplexNeuro arrival at: 1426.706
# Patient 1908 departs at 1426.726; Length of stay: 8.983 days; Time in system: 801.305 days
# Patient 1908 discharged at 1426.726
# Patient 1920 (Stroke) gets a bed at 1426.726
# Patient 1910 departs at 1426.754; Length of stay: 8.073 days; Time in system: 800.225 days
# Patient 1910 discharged at 1426.754
# Patient 1921 (Stroke) gets a bed at 1426.754
# Patient 4369 STROKE arrival at: 1426.764
# Patient 4370 ComplexNeuro arrival at: 1426.920
# Patient 4371 ComplexNeuro arrival at: 1427.607
# Patient 4372 STROKE arrival at: 1427.640
# Patient 1912 departs at 1427.813; Length of stay: 7.120 days; Time in system: 800.810 days
# Patient 1912 discharged at 1427.813
# Patient 1922 (Stroke) gets a bed at 1427.813
# Patient 4373 Other arrival at: 1428.001
# Patient 4374 ComplexNeuro arrival at: 1428.025
# Patient 1913 departs at 1428.682; Length of stay: 6.919 days; Time in system: 801.586 days
# Patient 1913 discharged at 1428.682
# Patient 1923 (Stroke) gets a bed at 1428.682
# Patient 4375 ComplexNeuro arrival at: 1428.692
# Patient 4376 STROKE arrival at: 1429.277
# Patient 4377 ComplexNeuro arrival at: 1429.937
# Patient 4378 ComplexNeuro arrival at: 1430.083
# Patient 1914 departs at 1430.329; Length of stay: 6.903 days; Time in system: 803.067 days
# Patient 1914 transferred to ESD at 1430.329
# Patient 1914 discharged at 1430.329
# Patient 1924 (Stroke) gets a bed at 1430.329
# Patient 4379 STROKE arrival at: 1430.411
# Patient 4380 STROKE arrival at: 1430.817
# Patient 1915 departs at 1431.180; Length of stay: 6.006 days; Time in system: 802.796 days
# Patient 1915 discharged at 1431.180
# Patient 1925 (TIA) gets a bed at 1431.180
# Patient 1916 departs at 1431.320; Length of stay: 5.971 days; Time in system: 802.253 days
# Patient 1916 discharged at 1431.320
# Patient 1926 (Stroke) gets a bed at 1431.320
# Patient 4381 ComplexNeuro arrival at: 1431.334
# Patient 4382 ComplexNeuro arrival at: 1431.956
# Patient 4383 STROKE arrival at: 1432.033
# Patient 1918 departs at 1432.479; Length of stay: 6.116 days; Time in system: 802.406 days
# Patient 1918 discharged at 1432.479
# Patient 1927 (ComplexNeuro) gets a bed at 1432.479
# Patient 4384 STROKE arrival at: 1432.593
# Patient 4385 Other arrival at: 1432.794
# Patient 4386 Other arrival at: 1432.850
# Patient 1919 departs at 1433.000; Length of stay: 6.419 days; Time in system: 802.217 days
# Patient 1919 discharged at 1433.000
# Patient 1928 (Stroke) gets a bed at 1433.000
# Patient 4387 Other arrival at: 1433.179
# Patient 4388 STROKE arrival at: 1433.259
# Patient 1920 departs at 1433.461; Length of stay: 6.735 days; Time in system: 802.455 days
# Patient 1920 discharged at 1433.461
# Patient 1929 (Other) gets a bed at 1433.461
# Patient 1917 departs at 1433.501; Length of stay: 7.153 days; Time in system: 804.025 days
# Patient 1917 discharged at 1433.501
# Patient 1930 (Stroke) gets a bed at 1433.501
# Patient 4389 STROKE arrival at: 1434.167
# Patient 4390 Other arrival at: 1434.215
# Patient 4391 STROKE arrival at: 1434.390
# Patient 4392 TIA arrival at: 1434.464
# Patient 4393 Other arrival at: 1434.504
# Patient 1923 departs at 1434.600; Length of stay: 5.918 days; Time in system: 802.630 days
# Patient 1923 discharged at 1434.600
# Patient 1931 (Stroke) gets a bed at 1434.600
# Patient 4394 STROKE arrival at: 1434.982
# Patient 1921 departs at 1435.085; Length of stay: 8.331 days; Time in system: 803.999 days
# Patient 1921 discharged at 1435.085
# Patient 1932 (Stroke) gets a bed at 1435.085
# Patient 4395 STROKE arrival at: 1435.216
# Patient 4396 ComplexNeuro arrival at: 1435.276
# Patient 4397 STROKE arrival at: 1435.522
# Patient 4398 TIA arrival at: 1435.692
# Patient 4399 STROKE arrival at: 1436.433
# Patient 4400 STROKE arrival at: 1437.066
# Patient 1922 departs at 1437.402; Length of stay: 9.589 days; Time in system: 805.787 days
# Patient 1922 transferred to ESD at 1437.402
# Patient 1922 discharged at 1437.402
# Patient 1933 (Stroke) gets a bed at 1437.402
# Patient 4401 STROKE arrival at: 1437.641
# Patient 1925 departs at 1437.803; Length of stay: 6.623 days; Time in system: 804.997 days
# Patient 1925 transferred to ESD at 1437.803
# Patient 1925 discharged at 1437.803
# Patient 1934 (ComplexNeuro) gets a bed at 1437.803
# Patient 1927 departs at 1438.354; Length of stay: 5.875 days; Time in system: 804.546 days
# Patient 1927 discharged at 1438.354
# Patient 1935 (Other) gets a bed at 1438.354
# Patient 4402 STROKE arrival at: 1438.564
# Patient 4403 TIA arrival at: 1438.580
# Patient 4404 ComplexNeuro arrival at: 1438.591
# Patient 1926 departs at 1438.834; Length of stay: 7.514 days; Time in system: 805.625 days
# Patient 1926 discharged at 1438.834
# Patient 1936 (Stroke) gets a bed at 1438.834
# Patient 4405 STROKE arrival at: 1438.956
# Patient 4406 TIA arrival at: 1438.980
# Patient 1929 departs at 1439.149; Length of stay: 5.688 days; Time in system: 804.187 days
# Patient 1929 discharged at 1439.149
# Patient 1937 (Stroke) gets a bed at 1439.149
# Patient 1930 departs at 1439.373; Length of stay: 5.872 days; Time in system: 804.324 days
# Patient 1930 discharged at 1439.373
# Patient 1938 (Stroke) gets a bed at 1439.373
# Patient 4407 ComplexNeuro arrival at: 1439.468
# Patient 4408 Other arrival at: 1439.736
# Patient 4409 Other arrival at: 1439.818
# Patient 1924 departs at 1440.502; Length of stay: 10.173 days; Time in system: 808.136 days
# Patient 1924 transferred to ESD at 1440.502
# Patient 1924 discharged at 1440.502
# Patient 1939 (Stroke) gets a bed at 1440.502
# Patient 4410 ComplexNeuro arrival at: 1440.799
# Patient 4411 STROKE arrival at: 1440.801
# Patient 4412 ComplexNeuro arrival at: 1441.345
# Patient 1931 departs at 1441.712; Length of stay: 7.112 days; Time in system: 805.860 days
# Patient 1931 discharged at 1441.712
# Patient 1940 (Stroke) gets a bed at 1441.712
# Patient 1928 departs at 1441.787; Length of stay: 8.787 days; Time in system: 807.371 days
# Patient 1928 discharged at 1441.787
# Patient 1941 (Other) gets a bed at 1441.787
# Patient 4413 Other arrival at: 1443.365
# Patient 4414 ComplexNeuro arrival at: 1443.902
# Patient 1932 departs at 1443.947; Length of stay: 8.862 days; Time in system: 807.771 days
# Patient 1932 discharged at 1443.947
# Patient 1942 (Other) gets a bed at 1443.947
# Patient 4415 STROKE arrival at: 1443.952
# Patient 4416 ComplexNeuro arrival at: 1444.044
# Patient 4417 STROKE arrival at: 1444.155
# Patient 1933 departs at 1444.714; Length of stay: 7.312 days; Time in system: 807.795 days
# Patient 1933 transferred to ESD at 1444.714
# Patient 1933 discharged at 1444.714
# Patient 1943 (Stroke) gets a bed at 1444.714
# Patient 1934 departs at 1444.934; Length of stay: 7.132 days; Time in system: 807.956 days
# Patient 1934 discharged at 1444.934
# Patient 1944 (TIA) gets a bed at 1444.934
# end of run. simulation clock time = 1445
# {'n_stroke': 0, 'n_tia': 0, 'n_cn': 0, 'n_other': 0}

# %% [markdown]
# ## Running metrics

# %%
# check between minutes and days

# %%
discharged_patients = [p for p in model.patients if hasattr(p, 'length_of_stay') and p.length_of_stay > 0]

mean_length_of_stay = np.mean([p.length_of_stay for p in discharged_patients])

print(f"Mean Length of Stay: {mean_length_of_stay:.2f} days")
# Out:
# Mean Length of Stay: 7.44 days

# %%
# Ensure there are patients in the system
if model.patients:

    # Group patients by their type (e.g., "Stroke", "TIA", etc.)
    patient_types = set(p.patient_type for p in model.patients)  # Get unique patient types
    for patient_type in patient_types:
        # Filter patients by type
        patients_by_type = [p for p in model.patients if p.patient_type == patient_type]

        # 1. Mean time in system (from arrival to discharge)
        mean_time_in_system = np.mean([p.time_in_system for p in patients_by_type])

        # 2. Mean length of stay (from bed assignment to discharge)
        discharged_patients = [p for p in patients_by_type if hasattr(p, 'length_of_stay') and p.length_of_stay > 0]
        mean_length_of_stay = np.mean([p.length_of_stay for p in discharged_patients]) if discharged_patients else 0

        # 3. Proportion of patients who met the 4-hour target
        four_hours = np.mean([p.four_hour_target for p in patients_by_type])

        # 4. Mean time to bed (arrival → bed assignment)
        mean_time_to_bed = np.mean([p.time_to_bed for p in patients_by_type])

        # 5. Mean time to ESD transfer (bed → ESD transfer, only for transferred patients)
        patients_with_esd = [p for p in patients_by_type if p.time_to_esd > 0]
        mean_time_to_esd = np.mean([p.time_to_esd - p.time_to_bed for p in patients_with_esd]) if patients_with_esd else 0

        # Print results for this patient type
        print(f'\nResults for {patient_type} Patients\n------------------')
        print(f'Mean Time in System (days): {mean_time_in_system:.2f}')
        print(f'Mean Length of Stay (days): {mean_length_of_stay:.2f}')  # ✅ Corrected Calculation
        print(f'Mean Time to Bed (days): {mean_time_to_bed:.2f}')
        print(f'Mean Time to ESD (days): {mean_time_to_esd:.2f}' if patients_with_esd else "No ESD transfers")
        print(f'Proportion Discharged Before 4 Hours: {four_hours:.2f}')
else:
    print("No patients recorded in this simulation run.")
# Out:
# Results for TIA Patients
# ------------------
# Mean Time in System (days): 182.10
# Mean Length of Stay (days): 7.42
# Mean Time to Bed (days): 181.83
# Mean Time to ESD (days): 403.99
# Proportion Discharged Before 4 Hours: 0.08
#
# Results for ComplexNeuro Patients
# ------------------
# Mean Time in System (days): 181.20
# Mean Length of Stay (days): 7.43
# Mean Time to Bed (days): 177.95
# Mean Time to ESD (days): 319.69
# Proportion Discharged Before 4 Hours: 0.12
#
# Results for Stroke Patients
# ------------------
# Mean Time in System (days): 180.65
# Mean Length of Stay (days): 7.45
# Mean Time to Bed (days): 179.38
# Mean Time to ESD (days): 342.57
# Proportion Discharged Before 4 Hours: 0.14
#
# Results for Other Patients
# ------------------
# Mean Time in System (days): 170.95
# Mean Length of Stay (days): 7.42
# Mean Time to Bed (days): 170.32
# Mean Time to ESD (days): 352.73
# Proportion Discharged Before 4 Hours: 0.12
