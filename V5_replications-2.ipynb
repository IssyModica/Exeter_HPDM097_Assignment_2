# %% [markdown]
# # simulating the stroke unit

# %%
import numpy as np
import pandas as pd
import random 
import itertools
import math
import matplotlib.pyplot as plt

# %%
import simpy
simpy.__version__
# Out:
# '4.1.1'

# %% [markdown]
# # distribution classes
#
# distribution classes used
# - exponential for IAT (inter arrival time)
# - lognormal for length of stay

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

class Bernoulli:
    '''
    Convenience class for the Bernoulli distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, p, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        p: float
            probability of drawing a 1
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.p = p
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.binomial(n=1, p=self.p, size=size)

# %% [markdown]
# # utility function

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %% [markdown]
# # model parameters

# %%
# resource counts
N_BEDS = 10

# time between arrivals in days (exponential)
MEAN_IAT_STROKE = 1.2
MEAN_IAT_TIA = 9.3
MEAN_IAT_CN = 3.6
MEAN_IAT_OTHER = 3.2

# acute stroke unit length of stay in days (lognormal)
# acute stroke unit length of stay (lognormal distribution) for each patient type
STAY_PARAMS = {
    "Stroke": (7.4, 8.6),         # Mean = 7.4, SD = 8.6
    "TIA": (1.8, 2.3),            # Mean = 1.8, SD = 2.3
    "ComplexNeuro": (4.0, 5.0),   # Mean = 4.0, SD = 5.0
    "Other": (3.8, 5.2)           # Mean = 3.8, SD = 5.2
}
# transfer (bernoulli)
PROB_ESD = 0.13

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = True

if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %%
class Scenario:
    '''
    Parameter container class for acute stroke unit model.
    '''
    def __init__(self, 
                 iat_stroke = MEAN_IAT_STROKE,
                 iat_tia = MEAN_IAT_TIA,
                 iat_cn = MEAN_IAT_CN,
                 iat_other = MEAN_IAT_OTHER, 
                 name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        
        # optional name
        self.name = name
        
        # beds
        self.unit_beds = N_BEDS

        #store the parameters 
        self.iat_stroke = iat_stroke
        self.iat_tia = iat_tia
        self.iat_cn = iat_cn
        self.iat_other = iat_other

        #initialise results to zero
        self.init_results_variables()
        #Initialise patient arrival distribution
        self.init_sampling()
        self.patients = []
        
        # Length of stay distribution (lognormal) for each patient type using STAY_PARAMS
        self.length_of_stay_dist = {
            patient_type: Lognormal(mean, std, random_seed=SEEDS[4])  
            for patient_type, (mean, std) in STAY_PARAMS.items()
        }

        # ESD transfer: prob that patient goes to ESD.
        self.esd_transfer = Bernoulli(PROB_ESD, random_seed=SEEDS[5])
        
    def init_sampling(self):
    # inter-arrival distribution for different patient types
        self.arrival_dist = {
            "Stroke": Exponential(MEAN_IAT_STROKE, random_seed=SEEDS[0]),
            "TIA": Exponential(MEAN_IAT_TIA, random_seed=SEEDS[1]),
            "ComplexNeuro": Exponential(MEAN_IAT_CN, random_seed=SEEDS[2]),
            "Other": Exponential(MEAN_IAT_OTHER, random_seed=SEEDS[3]),
        }

    def init_results_variables(self):
        self.results = {}
        self.results["n_stroke"] = 0
        self.results["n_tia"] = 0
        self.results["n_cn"] = 0
        self.results["n_other"] = 0

# %% [markdown]
# # build the model

# %% [markdown]
# ## model the unit
# ## Arrival Generator per patient_type
# Function which creates an arrival generator per patient type. Therefore, 4 functions for each patient entering the Acute Stroke Unit.
#
# !!! Note to self: code redundancy can be fixed by creating one arrival generator but this is better to do after making sure the model runs properly.

# %%
class AcuteStrokeUnit:  
    '''
    Model of an acute stroke unit
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []

        # 🔹 Add a shared patient ID counter
        self.patient_id_counter = 0  

        # Start the arrival processes for different patient types
        env.process(self.stroke_arrivals_generator())
        env.process(self.tia_arrivals_generator())
        env.process(self.complexneuro_arrivals_generator())
        env.process(self.other_arrivals_generator())

        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''
        args.unit_beds = simpy.Resource(self.env, 
                                          capacity=args.unit_beds)  

    def start_patient_arrivals(self):
        '''Start arrival processes for all patient types'''
        self.env.process(self.stroke_arrivals_generator())
        self.env.process(self.tia_arrivals_generator())
        self.env.process(self.complexneuro_arrivals_generator())
        self.env.process(self.other_arrivals_generator())

    def stroke_arrivals_generator(self):
        """Arrival process for stroke patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["Stroke"].sample()
            yield self.env.timeout(inter_arrival_time)

            # 🔹 Increment global counter
            self.patient_id_counter += 1  
        
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="Stroke")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
            trace(f'Patient {self.patient_id_counter} STROKE arrival at: {self.env.now:.3f}')
            
    def tia_arrivals_generator(self):
        """Arrival process for TIA patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["TIA"].sample()
            yield self.env.timeout(inter_arrival_time)
    
            self.patient_id_counter += 1  
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="TIA")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
    
            trace(f'Patient {self.patient_id_counter} TIA arrival at: {self.env.now:.3f}')

    def complexneuro_arrivals_generator(self):
        """Arrival process for ComplexNeuro patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["ComplexNeuro"].sample()
            yield self.env.timeout(inter_arrival_time)
    
            self.patient_id_counter += 1  
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="ComplexNeuro")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
    
            trace(f'Patient {self.patient_id_counter} ComplexNeuro arrival at: {self.env.now:.3f}')
    
    def other_arrivals_generator(self):
        """Arrival process for Other patients."""
        while True:
            inter_arrival_time = self.args.arrival_dist["Other"].sample()
            yield self.env.timeout(inter_arrival_time)
    
            self.patient_id_counter += 1  
            new_patient = AcutePatient(self.patient_id_counter, self.env, self.args, patient_type="Other")
            self.patients.append(new_patient)
            self.env.process(new_patient.assessment())
    
            trace(f'Patient {self.patient_id_counter} Other arrival at: {self.env.now:.3f}')

    def run_summary_frame(self):  # 👈 ADD THIS HERE
            ''' Generate a summary of patient statistics. '''
            if not self.patients:
                return None  # No patients processed
            
            import pandas as pd
    
            # Collecting basic statistics
            data = {
                "Patient Type": [p.patient_type for p in self.patients],
                "Length of Stay": [p.length_of_stay for p in self.patients],
                "Time in System": [p.time_in_system for p in self.patients],
                "Time to Bed": [p.time_to_bed for p in self.patients]
            }
    
            return pd.DataFrame(data)  # Return as a DataFrame

# %% [markdown]
# ## model the patient

# %%
class AcutePatient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args, patient_type):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env
        self.patient_type = patient_type  # Track patient category
        
        # Get length of stay distribution from Scenario
        self.length_of_stay_dist = args.length_of_stay_dist[patient_type]

        # stroke unit parameters
        self.unit_beds = args.unit_beds
        
        # esd transfer: prob that patient is transfered to ESD.
        self.esd_transfer = args.esd_transfer
                
        # individual patient metrics
        self.time_to_bed = 0.0
        self.length_of_stay = 0.0
        self.time_to_esd = 0.0
        self.time_in_system = 0.0
        self.four_hour_target = 0.0
    
    def assessment(self):
        '''
        simulates the process for acute stroke unit
        
        1. Patient enters the system and requests a bed
        2. Wait for bed availability and simulate length of stay
        3. Calculate time in system, ESD transfer, and if the 4-hour target is met
        
        '''
        # record the time that patient entered the system
        arrival_time = self.env.now
    
        # Request a bed from the stroke unit
        with self.unit_beds.request() as req:
            yield req
            
            # Record when the patient actually gets a bed
            bed_time = self.env.now  # Record when the patient gets the bed
            trace(f'Patient {self.identifier} ({self.patient_type}) gets a bed at {self.env.now:.3f}')
            
            # Calculate time to bed (how long the patient waited for a bed)
            self.time_to_bed = self.env.now - arrival_time
            
           # Simulate the patient's length of stay in the acute unit
            length_of_stay = self.length_of_stay_dist.sample()
            
            discharge_time = bed_time + length_of_stay  # When they leave
            
            # Simulate the time the patient spends in the unit
            yield self.env.timeout(length_of_stay)
            
            # Now the patient is leaving
            self.time_in_system = self.env.now - arrival_time  # Total time from arrival to departure
            self.length_of_stay = self.env.now - bed_time  # New length of stay calculation            
            
            # Log the patient's departure and the total time in the system
            trace(f'Patient {self.identifier} departs at {self.env.now:.3f}; '
              f'Length of stay: {self.length_of_stay:.3f} days; '
              f'Time in system: {self.time_in_system:.3f} days')
            
            # Check if the patient met the 4-hour target (240 minutes)
            if self.time_in_system <= (4 * 60):  # 4 hours = 240 minutes
                self.four_hour_target = 1  # Patient met the target
            else:
                self.four_hour_target = 0  # Patient exceeded the target
            
            # Check if the patient is transferred to the ESD (Early Supported Discharge)
            if self.esd_transfer.sample():
                self.time_to_esd = self.env.now
                trace(f'Patient {self.identifier} transferred to ESD at {self.env.now:.3f}')
            
            # Final discharge time log
            trace(f'Patient {self.identifier} discharged at {self.env.now:.3f}')

# %% [markdown]
# # script to run the model

# %%
# run length in minutes
RUN_LENGTH = 100

# Define trace as on/off
#TRACE = False
TRACE = True 

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()
# reset all results variables to zero and empty
default_args.init_results_variables()

# create the model
model = AcuteStrokeUnit(env, default_args)

# we pass all arrival generators to simpy 
env.process(model.stroke_arrivals_generator())  # Calling as a method of the model instance
env.process(model.tia_arrivals_generator())    # Calling as a method of the model instance
env.process(model.complexneuro_arrivals_generator())  # Calling as a method of the model instance
env.process(model.other_arrivals_generator())  # Calling as a method of the model instance



env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')
scenario = Scenario()  # Create an instance
print(scenario.results)  # Access and print the results dictionary
# Out:
# Patient 1 Other arrival at: 1.333
# Patient 1 (Other) gets a bed at 1.333
# Patient 2 Other arrival at: 1.569
# Patient 2 (Other) gets a bed at 1.569
# Patient 3 Other arrival at: 2.721
# Patient 3 (Other) gets a bed at 2.721
# Patient 4 STROKE arrival at: 2.803
# Patient 4 (Stroke) gets a bed at 2.803
# Patient 1 departs at 2.826; Length of stay: 1.494 days; Time in system: 1.494 days
# Patient 1 discharged at 2.826
# Patient 5 STROKE arrival at: 2.885
# Patient 5 (Stroke) gets a bed at 2.885
# Patient 6 STROKE arrival at: 3.221
# Patient 6 (Stroke) gets a bed at 3.221
# Patient 7 STROKE arrival at: 3.325
# Patient 7 (Stroke) gets a bed at 3.325
# Patient 8 Other arrival at: 3.388
# Patient 8 (Other) gets a bed at 3.388
# Patient 9 ComplexNeuro arrival at: 4.199
# Patient 9 (ComplexNeuro) gets a bed at 4.199
# Patient 8 departs at 4.373; Length of stay: 0.986 days; Time in system: 0.986 days
# Patient 8 discharged at 4.373
# Patient 10 ComplexNeuro arrival at: 4.530
# Patient 10 (ComplexNeuro) gets a bed at 4.530
# Patient 2 departs at 4.540; Length of stay: 2.970 days; Time in system: 2.970 days
# Patient 2 discharged at 4.540
# Patient 11 Other arrival at: 4.931
# Patient 11 (Other) gets a bed at 4.931
# Patient 12 STROKE arrival at: 5.068
# Patient 12 (Stroke) gets a bed at 5.068
# Patient 13 Other arrival at: 5.160
# Patient 13 (Other) gets a bed at 5.160
# Patient 14 Other arrival at: 5.294
# Patient 15 TIA arrival at: 5.377
# Patient 7 departs at 5.628; Length of stay: 2.304 days; Time in system: 2.304 days
# Patient 7 discharged at 5.628
# Patient 14 (Other) gets a bed at 5.628
# Patient 3 departs at 5.664; Length of stay: 2.944 days; Time in system: 2.944 days
# Patient 3 discharged at 5.664
# Patient 15 (TIA) gets a bed at 5.664
# Patient 16 STROKE arrival at: 5.665
# Patient 9 departs at 5.902; Length of stay: 1.703 days; Time in system: 1.703 days
# Patient 9 transferred to ESD at 5.902
# Patient 9 discharged at 5.902
# Patient 16 (Stroke) gets a bed at 5.902
# Patient 4 departs at 6.153; Length of stay: 3.349 days; Time in system: 3.349 days
# Patient 4 discharged at 6.153
# Patient 11 departs at 6.193; Length of stay: 1.262 days; Time in system: 1.262 days
# Patient 11 discharged at 6.193
# Patient 17 Other arrival at: 6.208
# Patient 17 (Other) gets a bed at 6.208
# Patient 18 Other arrival at: 6.338
# Patient 18 (Other) gets a bed at 6.338
# Patient 15 departs at 6.416; Length of stay: 0.752 days; Time in system: 1.039 days
# Patient 15 transferred to ESD at 6.416
# Patient 15 discharged at 6.416
# Patient 19 STROKE arrival at: 6.760
# Patient 19 (Stroke) gets a bed at 6.760
# Patient 14 departs at 6.792; Length of stay: 1.163 days; Time in system: 1.498 days
# Patient 14 discharged at 6.792
# Patient 20 STROKE arrival at: 6.855
# Patient 20 (Stroke) gets a bed at 6.855
# Patient 21 ComplexNeuro arrival at: 6.935
# Patient 22 ComplexNeuro arrival at: 7.757
# Patient 10 departs at 7.789; Length of stay: 3.259 days; Time in system: 3.259 days
# Patient 10 discharged at 7.789
# Patient 21 (ComplexNeuro) gets a bed at 7.789
# Patient 23 ComplexNeuro arrival at: 7.908
# Patient 12 departs at 7.945; Length of stay: 2.878 days; Time in system: 2.878 days
# Patient 12 discharged at 7.945
# Patient 22 (ComplexNeuro) gets a bed at 7.945
# Patient 24 STROKE arrival at: 8.111
# Patient 25 STROKE arrival at: 8.195
# Patient 26 ComplexNeuro arrival at: 9.065
# Patient 22 departs at 9.095; Length of stay: 1.150 days; Time in system: 1.338 days
# Patient 22 discharged at 9.095
# Patient 23 (ComplexNeuro) gets a bed at 9.095
# Patient 5 departs at 9.102; Length of stay: 6.217 days; Time in system: 6.217 days
# Patient 5 discharged at 9.102
# Patient 24 (Stroke) gets a bed at 9.102
# Patient 6 departs at 9.388; Length of stay: 6.167 days; Time in system: 6.167 days
# Patient 6 discharged at 9.388
# Patient 25 (Stroke) gets a bed at 9.388
# Patient 27 STROKE arrival at: 9.414
# Patient 19 departs at 9.434; Length of stay: 2.674 days; Time in system: 2.674 days
# Patient 19 discharged at 9.434
# Patient 26 (ComplexNeuro) gets a bed at 9.434
# Patient 28 STROKE arrival at: 9.502
# Patient 29 STROKE arrival at: 9.966
# Patient 30 Other arrival at: 10.153
# Patient 31 Other arrival at: 10.350
# Patient 18 departs at 10.487; Length of stay: 4.149 days; Time in system: 4.149 days
# Patient 18 discharged at 10.487
# Patient 27 (Stroke) gets a bed at 10.487
# Patient 23 departs at 10.548; Length of stay: 1.452 days; Time in system: 2.639 days
# Patient 23 discharged at 10.548
# Patient 28 (Stroke) gets a bed at 10.548
# Patient 13 departs at 10.835; Length of stay: 5.675 days; Time in system: 5.675 days
# Patient 13 discharged at 10.835
# Patient 29 (Stroke) gets a bed at 10.835
# Patient 21 departs at 11.020; Length of stay: 3.231 days; Time in system: 4.085 days
# Patient 21 discharged at 11.020
# Patient 30 (Other) gets a bed at 11.020
# Patient 32 STROKE arrival at: 11.444
# Patient 33 STROKE arrival at: 11.492
# Patient 34 STROKE arrival at: 11.602
# Patient 35 STROKE arrival at: 11.629
# Patient 36 STROKE arrival at: 11.980
# Patient 37 ComplexNeuro arrival at: 11.981
# Patient 17 departs at 12.221; Length of stay: 6.013 days; Time in system: 6.013 days
# Patient 17 discharged at 12.221
# Patient 31 (Other) gets a bed at 12.221
# Patient 38 STROKE arrival at: 12.476
# Patient 39 ComplexNeuro arrival at: 12.661
# Patient 40 STROKE arrival at: 12.710
# Patient 41 STROKE arrival at: 12.978
# Patient 42 ComplexNeuro arrival at: 13.071
# Patient 27 departs at 13.592; Length of stay: 3.105 days; Time in system: 4.178 days
# Patient 27 discharged at 13.592
# Patient 32 (Stroke) gets a bed at 13.592
# Patient 31 departs at 13.594; Length of stay: 1.373 days; Time in system: 3.244 days
# Patient 31 discharged at 13.594
# Patient 33 (Stroke) gets a bed at 13.594
# Patient 43 Other arrival at: 13.631
# Patient 44 STROKE arrival at: 13.972
# Patient 45 TIA arrival at: 14.271
# Patient 46 Other arrival at: 14.328
# Patient 47 Other arrival at: 14.820
# Patient 48 Other arrival at: 15.097
# Patient 49 STROKE arrival at: 15.184
# Patient 50 ComplexNeuro arrival at: 15.372
# Patient 26 departs at 15.440; Length of stay: 6.006 days; Time in system: 6.375 days
# Patient 26 discharged at 15.440
# Patient 34 (Stroke) gets a bed at 15.440
# Patient 51 STROKE arrival at: 15.445
# Patient 52 STROKE arrival at: 15.945
# Patient 53 STROKE arrival at: 15.971
# Patient 30 departs at 16.038; Length of stay: 5.018 days; Time in system: 5.885 days
# Patient 30 discharged at 16.038
# Patient 35 (Stroke) gets a bed at 16.038
# Patient 54 STROKE arrival at: 16.063
# Patient 55 STROKE arrival at: 16.279
# Patient 56 STROKE arrival at: 16.489
# Patient 29 departs at 16.576; Length of stay: 5.741 days; Time in system: 6.610 days
# Patient 29 discharged at 16.576
# Patient 36 (Stroke) gets a bed at 16.576
# Patient 32 departs at 16.660; Length of stay: 3.068 days; Time in system: 5.216 days
# Patient 32 discharged at 16.660
# Patient 37 (ComplexNeuro) gets a bed at 16.660
# Patient 57 STROKE arrival at: 16.956
# Patient 16 departs at 17.035; Length of stay: 11.133 days; Time in system: 11.370 days
# Patient 16 discharged at 17.035
# Patient 38 (Stroke) gets a bed at 17.035
# Patient 58 STROKE arrival at: 17.101
# Patient 24 departs at 17.500; Length of stay: 8.398 days; Time in system: 9.390 days
# Patient 24 discharged at 17.500
# Patient 39 (ComplexNeuro) gets a bed at 17.500
# Patient 59 STROKE arrival at: 17.952
# Patient 37 departs at 18.005; Length of stay: 1.345 days; Time in system: 6.024 days
# Patient 37 discharged at 18.005
# Patient 40 (Stroke) gets a bed at 18.005
# Patient 60 STROKE arrival at: 18.237
# Patient 61 STROKE arrival at: 18.473
# Patient 20 departs at 18.583; Length of stay: 11.728 days; Time in system: 11.728 days
# Patient 20 discharged at 18.583
# Patient 41 (Stroke) gets a bed at 18.583
# Patient 62 STROKE arrival at: 18.790
# Patient 38 departs at 18.933; Length of stay: 1.898 days; Time in system: 6.457 days
# Patient 38 discharged at 18.933
# Patient 42 (ComplexNeuro) gets a bed at 18.933
# Patient 34 departs at 19.083; Length of stay: 3.643 days; Time in system: 7.481 days
# Patient 34 transferred to ESD at 19.083
# Patient 34 discharged at 19.083
# Patient 43 (Other) gets a bed at 19.083
# Patient 63 STROKE arrival at: 19.203
# Patient 64 STROKE arrival at: 19.243
# Patient 25 departs at 19.354; Length of stay: 9.967 days; Time in system: 11.159 days
# Patient 25 discharged at 19.354
# Patient 44 (Stroke) gets a bed at 19.354
# Patient 65 ComplexNeuro arrival at: 19.579
# Patient 66 STROKE arrival at: 19.589
# Patient 67 Other arrival at: 19.640
# Patient 68 STROKE arrival at: 19.946
# Patient 69 Other arrival at: 20.131
# Patient 70 STROKE arrival at: 20.297
# Patient 40 departs at 20.496; Length of stay: 2.491 days; Time in system: 7.786 days
# Patient 40 discharged at 20.496
# Patient 45 (TIA) gets a bed at 20.496
# Patient 33 departs at 20.524; Length of stay: 6.930 days; Time in system: 9.032 days
# Patient 33 discharged at 20.524
# Patient 46 (Other) gets a bed at 20.524
# Patient 44 departs at 20.599; Length of stay: 1.245 days; Time in system: 6.627 days
# Patient 44 discharged at 20.599
# Patient 47 (Other) gets a bed at 20.599
# Patient 71 ComplexNeuro arrival at: 20.714
# Patient 72 Other arrival at: 20.762
# Patient 73 Other arrival at: 21.290
# Patient 74 ComplexNeuro arrival at: 21.312
# Patient 75 STROKE arrival at: 21.546
# Patient 45 departs at 21.949; Length of stay: 1.452 days; Time in system: 7.678 days
# Patient 45 transferred to ESD at 21.949
# Patient 45 discharged at 21.949
# Patient 48 (Other) gets a bed at 21.949
# Patient 47 departs at 21.955; Length of stay: 1.355 days; Time in system: 7.134 days
# Patient 47 discharged at 21.955
# Patient 49 (Stroke) gets a bed at 21.955
# Patient 76 STROKE arrival at: 21.966
# Patient 77 Other arrival at: 22.004
# Patient 78 STROKE arrival at: 22.054
# Patient 36 departs at 22.630; Length of stay: 6.054 days; Time in system: 10.650 days
# Patient 36 discharged at 22.630
# Patient 50 (ComplexNeuro) gets a bed at 22.630
# Patient 79 STROKE arrival at: 22.847
# Patient 80 Other arrival at: 22.914
# Patient 46 departs at 23.243; Length of stay: 2.719 days; Time in system: 8.915 days
# Patient 46 discharged at 23.243
# Patient 51 (Stroke) gets a bed at 23.243
# Patient 42 departs at 23.401; Length of stay: 4.468 days; Time in system: 10.330 days
# Patient 42 discharged at 23.401
# Patient 52 (Stroke) gets a bed at 23.401
# Patient 81 STROKE arrival at: 23.415
# Patient 82 ComplexNeuro arrival at: 23.627
# Patient 39 departs at 23.844; Length of stay: 6.343 days; Time in system: 11.182 days
# Patient 39 transferred to ESD at 23.844
# Patient 39 discharged at 23.844
# Patient 53 (Stroke) gets a bed at 23.844
# Patient 83 TIA arrival at: 23.875
# Patient 84 ComplexNeuro arrival at: 24.020
# Patient 28 departs at 24.280; Length of stay: 13.733 days; Time in system: 14.778 days
# Patient 28 discharged at 24.280
# Patient 54 (Stroke) gets a bed at 24.280
# Patient 85 STROKE arrival at: 24.472
# Patient 86 STROKE arrival at: 24.761
# Patient 87 STROKE arrival at: 24.808
# Patient 88 STROKE arrival at: 25.007
# Patient 51 departs at 25.085; Length of stay: 1.842 days; Time in system: 9.640 days
# Patient 51 discharged at 25.085
# Patient 55 (Stroke) gets a bed at 25.085
# Patient 89 STROKE arrival at: 25.147
# Patient 90 STROKE arrival at: 25.172
# Patient 35 departs at 25.174; Length of stay: 9.136 days; Time in system: 13.546 days
# Patient 35 transferred to ESD at 25.174
# Patient 35 discharged at 25.174
# Patient 56 (Stroke) gets a bed at 25.174
# Patient 48 departs at 25.300; Length of stay: 3.351 days; Time in system: 10.203 days
# Patient 48 discharged at 25.300
# Patient 57 (Stroke) gets a bed at 25.300
# Patient 91 STROKE arrival at: 25.373
# Patient 92 STROKE arrival at: 25.432
# Patient 43 departs at 26.248; Length of stay: 7.165 days; Time in system: 12.618 days
# Patient 43 discharged at 26.248
# Patient 58 (Stroke) gets a bed at 26.248
# Patient 52 departs at 26.730; Length of stay: 3.329 days; Time in system: 10.784 days
# Patient 52 discharged at 26.730
# Patient 59 (Stroke) gets a bed at 26.730
# Patient 49 departs at 26.843; Length of stay: 4.888 days; Time in system: 11.659 days
# Patient 49 discharged at 26.843
# Patient 60 (Stroke) gets a bed at 26.843
# Patient 93 STROKE arrival at: 26.951
# Patient 57 departs at 26.997; Length of stay: 1.697 days; Time in system: 10.041 days
# Patient 57 discharged at 26.997
# Patient 61 (Stroke) gets a bed at 26.997
# Patient 41 departs at 27.371; Length of stay: 8.788 days; Time in system: 14.393 days
# Patient 41 discharged at 27.371
# Patient 62 (Stroke) gets a bed at 27.371
# Patient 55 departs at 27.549; Length of stay: 2.464 days; Time in system: 11.270 days
# Patient 55 discharged at 27.549
# Patient 63 (Stroke) gets a bed at 27.549
# Patient 94 STROKE arrival at: 27.627
# Patient 95 STROKE arrival at: 27.968
# Patient 50 departs at 27.978; Length of stay: 5.347 days; Time in system: 12.606 days
# Patient 50 discharged at 27.978
# Patient 64 (Stroke) gets a bed at 27.978
# Patient 54 departs at 28.000; Length of stay: 3.719 days; Time in system: 11.936 days
# Patient 54 discharged at 28.000
# Patient 65 (ComplexNeuro) gets a bed at 28.000
# Patient 96 Other arrival at: 28.101
# Patient 60 departs at 28.373; Length of stay: 1.530 days; Time in system: 10.136 days
# Patient 60 discharged at 28.373
# Patient 66 (Stroke) gets a bed at 28.373
# Patient 97 STROKE arrival at: 28.445
# Patient 98 STROKE arrival at: 28.879
# Patient 99 STROKE arrival at: 29.034
# Patient 100 Other arrival at: 29.300
# Patient 62 departs at 29.346; Length of stay: 1.975 days; Time in system: 10.555 days
# Patient 62 discharged at 29.346
# Patient 67 (Other) gets a bed at 29.346
# Patient 101 Other arrival at: 29.414
# Patient 65 departs at 29.573; Length of stay: 1.573 days; Time in system: 9.994 days
# Patient 65 transferred to ESD at 29.573
# Patient 65 discharged at 29.573
# Patient 68 (Stroke) gets a bed at 29.573
# Patient 102 TIA arrival at: 29.827
# Patient 103 STROKE arrival at: 30.227
# Patient 104 STROKE arrival at: 30.334
# Patient 64 departs at 30.655; Length of stay: 2.677 days; Time in system: 11.412 days
# Patient 64 discharged at 30.655
# Patient 69 (Other) gets a bed at 30.655
# Patient 67 departs at 30.986; Length of stay: 1.640 days; Time in system: 11.346 days
# Patient 67 discharged at 30.986
# Patient 70 (Stroke) gets a bed at 30.986
# Patient 105 ComplexNeuro arrival at: 31.602
# Patient 53 departs at 31.734; Length of stay: 7.891 days; Time in system: 15.763 days
# Patient 53 discharged at 31.734
# Patient 71 (ComplexNeuro) gets a bed at 31.734
# Patient 106 STROKE arrival at: 31.878
# Patient 107 STROKE arrival at: 32.144
# Patient 58 departs at 32.954; Length of stay: 6.705 days; Time in system: 15.852 days
# Patient 58 discharged at 32.954
# Patient 72 (Other) gets a bed at 32.954
# Patient 70 departs at 33.185; Length of stay: 2.198 days; Time in system: 12.887 days
# Patient 70 discharged at 33.185
# Patient 73 (Other) gets a bed at 33.185
# Patient 108 TIA arrival at: 33.370
# Patient 109 ComplexNeuro arrival at: 33.664
# Patient 68 departs at 33.877; Length of stay: 4.305 days; Time in system: 13.932 days
# Patient 68 transferred to ESD at 33.877
# Patient 68 discharged at 33.877
# Patient 74 (ComplexNeuro) gets a bed at 33.877
# Patient 73 departs at 33.979; Length of stay: 0.795 days; Time in system: 12.690 days
# Patient 73 discharged at 33.979
# Patient 75 (Stroke) gets a bed at 33.979
# Patient 110 STROKE arrival at: 34.672
# Patient 69 departs at 35.210; Length of stay: 4.556 days; Time in system: 15.079 days
# Patient 69 discharged at 35.210
# Patient 76 (Stroke) gets a bed at 35.210
# Patient 72 departs at 35.838; Length of stay: 2.884 days; Time in system: 15.076 days
# Patient 72 discharged at 35.838
# Patient 77 (Other) gets a bed at 35.838
# Patient 111 STROKE arrival at: 36.646
# Patient 63 departs at 36.838; Length of stay: 9.289 days; Time in system: 17.635 days
# Patient 63 transferred to ESD at 36.838
# Patient 63 discharged at 36.838
# Patient 78 (Stroke) gets a bed at 36.838
# Patient 75 departs at 36.868; Length of stay: 2.888 days; Time in system: 15.322 days
# Patient 75 discharged at 36.868
# Patient 79 (Stroke) gets a bed at 36.868
# Patient 74 departs at 36.875; Length of stay: 2.998 days; Time in system: 15.563 days
# Patient 74 discharged at 36.875
# Patient 80 (Other) gets a bed at 36.875
# Patient 77 departs at 36.913; Length of stay: 1.075 days; Time in system: 14.909 days
# Patient 77 discharged at 36.913
# Patient 81 (Stroke) gets a bed at 36.913
# Patient 79 departs at 37.425; Length of stay: 0.557 days; Time in system: 14.578 days
# Patient 79 discharged at 37.425
# Patient 82 (ComplexNeuro) gets a bed at 37.425
# Patient 112 STROKE arrival at: 37.898
# Patient 113 TIA arrival at: 38.034
# Patient 114 Other arrival at: 38.083
# Patient 115 STROKE arrival at: 38.250
# Patient 116 STROKE arrival at: 38.304
# Patient 117 STROKE arrival at: 38.609
# Patient 118 Other arrival at: 38.871
# Patient 82 departs at 38.978; Length of stay: 1.553 days; Time in system: 15.350 days
# Patient 82 discharged at 38.978
# Patient 83 (TIA) gets a bed at 38.978
# Patient 71 departs at 39.220; Length of stay: 7.486 days; Time in system: 18.505 days
# Patient 71 discharged at 39.220
# Patient 84 (ComplexNeuro) gets a bed at 39.220
# Patient 66 departs at 39.278; Length of stay: 10.905 days; Time in system: 19.689 days
# Patient 66 discharged at 39.278
# Patient 85 (Stroke) gets a bed at 39.278
# Patient 119 STROKE arrival at: 39.354
# Patient 120 STROKE arrival at: 39.451
# Patient 121 ComplexNeuro arrival at: 39.865
# Patient 83 departs at 40.418; Length of stay: 1.440 days; Time in system: 16.542 days
# Patient 83 discharged at 40.418
# Patient 86 (Stroke) gets a bed at 40.418
# Patient 81 departs at 40.698; Length of stay: 3.785 days; Time in system: 17.283 days
# Patient 81 discharged at 40.698
# Patient 87 (Stroke) gets a bed at 40.698
# Patient 85 departs at 40.966; Length of stay: 1.688 days; Time in system: 16.494 days
# Patient 85 transferred to ESD at 40.966
# Patient 85 discharged at 40.966
# Patient 88 (Stroke) gets a bed at 40.966
# Patient 122 STROKE arrival at: 41.164
# Patient 80 departs at 41.239; Length of stay: 4.364 days; Time in system: 18.325 days
# Patient 80 discharged at 41.239
# Patient 89 (Stroke) gets a bed at 41.239
# Patient 123 STROKE arrival at: 41.563
# Patient 124 STROKE arrival at: 41.622
# Patient 125 STROKE arrival at: 41.885
# Patient 126 Other arrival at: 41.911
# Patient 61 departs at 42.480; Length of stay: 15.483 days; Time in system: 24.007 days
# Patient 61 discharged at 42.480
# Patient 90 (Stroke) gets a bed at 42.480
# Patient 89 departs at 42.648; Length of stay: 1.409 days; Time in system: 17.502 days
# Patient 89 discharged at 42.648
# Patient 91 (Stroke) gets a bed at 42.648
# Patient 127 STROKE arrival at: 42.732
# Patient 84 departs at 42.872; Length of stay: 3.652 days; Time in system: 18.852 days
# Patient 84 transferred to ESD at 42.872
# Patient 84 discharged at 42.872
# Patient 92 (Stroke) gets a bed at 42.872
# Patient 128 Other arrival at: 42.908
# Patient 129 ComplexNeuro arrival at: 43.316
# Patient 130 Other arrival at: 43.610
# Patient 131 STROKE arrival at: 43.717
# Patient 132 ComplexNeuro arrival at: 43.766
# Patient 133 TIA arrival at: 43.834
# Patient 88 departs at 44.163; Length of stay: 3.198 days; Time in system: 19.156 days
# Patient 88 discharged at 44.163
# Patient 93 (Stroke) gets a bed at 44.163
# Patient 134 Other arrival at: 44.432
# Patient 86 departs at 44.480; Length of stay: 4.063 days; Time in system: 19.719 days
# Patient 86 discharged at 44.480
# Patient 94 (Stroke) gets a bed at 44.480
# Patient 91 departs at 44.550; Length of stay: 1.902 days; Time in system: 19.177 days
# Patient 91 discharged at 44.550
# Patient 95 (Stroke) gets a bed at 44.550
# Patient 135 Other arrival at: 44.655
# Patient 136 STROKE arrival at: 44.949
# Patient 93 departs at 45.608; Length of stay: 1.444 days; Time in system: 18.657 days
# Patient 93 discharged at 45.608
# Patient 96 (Other) gets a bed at 45.608
# Patient 137 STROKE arrival at: 45.853
# Patient 96 departs at 46.106; Length of stay: 0.498 days; Time in system: 18.005 days
# Patient 96 discharged at 46.106
# Patient 97 (Stroke) gets a bed at 46.106
# Patient 59 departs at 46.232; Length of stay: 19.502 days; Time in system: 28.280 days
# Patient 59 discharged at 46.232
# Patient 98 (Stroke) gets a bed at 46.232
# Patient 90 departs at 46.255; Length of stay: 3.775 days; Time in system: 21.084 days
# Patient 90 discharged at 46.255
# Patient 99 (Stroke) gets a bed at 46.255
# Patient 138 STROKE arrival at: 46.274
# Patient 139 STROKE arrival at: 46.621
# Patient 140 STROKE arrival at: 46.782
# Patient 141 STROKE arrival at: 46.953
# Patient 142 ComplexNeuro arrival at: 47.010
# Patient 143 STROKE arrival at: 47.094
# Patient 144 STROKE arrival at: 47.160
# Patient 145 STROKE arrival at: 47.430
# Patient 146 ComplexNeuro arrival at: 47.900
# Patient 147 STROKE arrival at: 47.968
# Patient 148 Other arrival at: 47.977
# Patient 149 STROKE arrival at: 48.431
# Patient 150 STROKE arrival at: 49.220
# Patient 151 Other arrival at: 49.333
# Patient 95 departs at 49.408; Length of stay: 4.858 days; Time in system: 21.440 days
# Patient 95 discharged at 49.408
# Patient 100 (Other) gets a bed at 49.408
# Patient 152 ComplexNeuro arrival at: 49.433
# Patient 153 STROKE arrival at: 49.445
# Patient 154 STROKE arrival at: 49.553
# Patient 92 departs at 49.795; Length of stay: 6.922 days; Time in system: 24.362 days
# Patient 92 discharged at 49.795
# Patient 101 (Other) gets a bed at 49.795
# Patient 97 departs at 50.137; Length of stay: 4.032 days; Time in system: 21.692 days
# Patient 97 discharged at 50.137
# Patient 102 (TIA) gets a bed at 50.137
# Patient 101 departs at 50.563; Length of stay: 0.769 days; Time in system: 21.149 days
# Patient 101 discharged at 50.563
# Patient 103 (Stroke) gets a bed at 50.563
# Patient 102 departs at 50.642; Length of stay: 0.505 days; Time in system: 20.815 days
# Patient 102 discharged at 50.642
# Patient 104 (Stroke) gets a bed at 50.642
# Patient 98 departs at 51.022; Length of stay: 4.790 days; Time in system: 22.143 days
# Patient 98 transferred to ESD at 51.022
# Patient 98 discharged at 51.022
# Patient 105 (ComplexNeuro) gets a bed at 51.022
# Patient 155 ComplexNeuro arrival at: 51.077
# Patient 156 STROKE arrival at: 51.104
# Patient 157 STROKE arrival at: 51.499
# Patient 76 departs at 51.578; Length of stay: 16.368 days; Time in system: 29.612 days
# Patient 76 discharged at 51.578
# Patient 106 (Stroke) gets a bed at 51.578
# Patient 100 departs at 51.682; Length of stay: 2.274 days; Time in system: 22.382 days
# Patient 100 discharged at 51.682
# Patient 107 (Stroke) gets a bed at 51.682
# Patient 158 STROKE arrival at: 51.739
# Patient 159 STROKE arrival at: 51.747
# Patient 160 ComplexNeuro arrival at: 51.760
# Patient 161 STROKE arrival at: 52.112
# Patient 162 STROKE arrival at: 52.203
# Patient 163 STROKE arrival at: 52.377
# Patient 56 departs at 52.716; Length of stay: 27.541 days; Time in system: 36.226 days
# Patient 56 discharged at 52.716
# Patient 108 (TIA) gets a bed at 52.716
# Patient 164 ComplexNeuro arrival at: 52.787
# Patient 165 STROKE arrival at: 52.808
# Patient 166 Other arrival at: 52.837
# Patient 105 departs at 52.882; Length of stay: 1.860 days; Time in system: 21.280 days
# Patient 105 discharged at 52.882
# Patient 109 (ComplexNeuro) gets a bed at 52.882
# Patient 108 departs at 53.355; Length of stay: 0.640 days; Time in system: 19.986 days
# Patient 108 discharged at 53.355
# Patient 110 (Stroke) gets a bed at 53.355
# Patient 87 departs at 53.372; Length of stay: 12.675 days; Time in system: 28.564 days
# Patient 87 discharged at 53.372
# Patient 111 (Stroke) gets a bed at 53.372
# Patient 167 ComplexNeuro arrival at: 53.464
# Patient 168 STROKE arrival at: 54.018
# Patient 169 ComplexNeuro arrival at: 54.322
# Patient 170 Other arrival at: 54.934
# Patient 94 departs at 54.954; Length of stay: 10.474 days; Time in system: 27.327 days
# Patient 94 discharged at 54.954
# Patient 112 (Stroke) gets a bed at 54.954
# Patient 171 STROKE arrival at: 55.079
# Patient 110 departs at 55.273; Length of stay: 1.918 days; Time in system: 20.602 days
# Patient 110 discharged at 55.273
# Patient 113 (TIA) gets a bed at 55.273
# Patient 172 Other arrival at: 55.795
# Patient 103 departs at 56.287; Length of stay: 5.723 days; Time in system: 26.059 days
# Patient 103 discharged at 56.287
# Patient 114 (Other) gets a bed at 56.287
# Patient 173 Other arrival at: 56.653
# Patient 174 ComplexNeuro arrival at: 56.850
# Patient 175 Other arrival at: 57.201
# Patient 176 ComplexNeuro arrival at: 57.378
# Patient 177 STROKE arrival at: 57.535
# Patient 178 STROKE arrival at: 57.717
# Patient 109 departs at 57.763; Length of stay: 4.881 days; Time in system: 24.099 days
# Patient 109 discharged at 57.763
# Patient 115 (Stroke) gets a bed at 57.763
# Patient 114 departs at 57.771; Length of stay: 1.484 days; Time in system: 19.687 days
# Patient 114 discharged at 57.771
# Patient 116 (Stroke) gets a bed at 57.771
# Patient 113 departs at 57.973; Length of stay: 2.700 days; Time in system: 19.939 days
# Patient 113 discharged at 57.973
# Patient 117 (Stroke) gets a bed at 57.973
# Patient 116 departs at 58.361; Length of stay: 0.591 days; Time in system: 20.058 days
# Patient 116 discharged at 58.361
# Patient 118 (Other) gets a bed at 58.361
# Patient 179 TIA arrival at: 58.715
# Patient 180 STROKE arrival at: 58.876
# Patient 107 departs at 59.299; Length of stay: 7.617 days; Time in system: 27.155 days
# Patient 107 discharged at 59.299
# Patient 119 (Stroke) gets a bed at 59.299
# Patient 117 departs at 59.438; Length of stay: 1.465 days; Time in system: 20.830 days
# Patient 117 discharged at 59.438
# Patient 120 (Stroke) gets a bed at 59.438
# Patient 181 STROKE arrival at: 59.748
# Patient 182 STROKE arrival at: 59.938
# Patient 183 STROKE arrival at: 60.394
# Patient 115 departs at 60.510; Length of stay: 2.747 days; Time in system: 22.260 days
# Patient 115 discharged at 60.510
# Patient 121 (ComplexNeuro) gets a bed at 60.510
# Patient 184 ComplexNeuro arrival at: 60.536
# Patient 185 Other arrival at: 60.608
# Patient 186 ComplexNeuro arrival at: 60.618
# Patient 187 STROKE arrival at: 60.657
# Patient 188 STROKE arrival at: 61.030
# Patient 189 STROKE arrival at: 61.198
# Patient 111 departs at 61.393; Length of stay: 8.021 days; Time in system: 24.748 days
# Patient 111 discharged at 61.393
# Patient 122 (Stroke) gets a bed at 61.393
# Patient 190 STROKE arrival at: 61.424
# Patient 191 STROKE arrival at: 61.796
# Patient 118 departs at 62.232; Length of stay: 3.871 days; Time in system: 23.362 days
# Patient 118 discharged at 62.232
# Patient 123 (Stroke) gets a bed at 62.232
# Patient 192 Other arrival at: 62.320
# Patient 193 STROKE arrival at: 62.957
# Patient 194 STROKE arrival at: 63.231
# Patient 195 STROKE arrival at: 63.454
# Patient 121 departs at 63.679; Length of stay: 3.169 days; Time in system: 23.814 days
# Patient 121 discharged at 63.679
# Patient 124 (Stroke) gets a bed at 63.679
# Patient 196 STROKE arrival at: 64.052
# Patient 120 departs at 64.116; Length of stay: 4.678 days; Time in system: 24.665 days
# Patient 120 discharged at 64.116
# Patient 125 (Stroke) gets a bed at 64.116
# Patient 112 departs at 64.534; Length of stay: 9.581 days; Time in system: 26.637 days
# Patient 112 discharged at 64.534
# Patient 126 (Other) gets a bed at 64.534
# Patient 122 departs at 64.856; Length of stay: 3.462 days; Time in system: 23.692 days
# Patient 122 discharged at 64.856
# Patient 127 (Stroke) gets a bed at 64.856
# Patient 197 ComplexNeuro arrival at: 65.080
# Patient 198 STROKE arrival at: 65.902
# Patient 199 ComplexNeuro arrival at: 65.925
# Patient 200 STROKE arrival at: 66.045
# Patient 201 ComplexNeuro arrival at: 66.123
# Patient 126 departs at 66.213; Length of stay: 1.678 days; Time in system: 24.302 days
# Patient 126 transferred to ESD at 66.213
# Patient 126 discharged at 66.213
# Patient 128 (Other) gets a bed at 66.213
# Patient 123 departs at 66.243; Length of stay: 4.011 days; Time in system: 24.681 days
# Patient 123 discharged at 66.243
# Patient 129 (ComplexNeuro) gets a bed at 66.243
# Patient 202 STROKE arrival at: 66.250
# Patient 203 TIA arrival at: 66.432
# Patient 106 departs at 66.566; Length of stay: 14.988 days; Time in system: 34.688 days
# Patient 106 discharged at 66.566
# Patient 130 (Other) gets a bed at 66.566
# Patient 204 ComplexNeuro arrival at: 66.953
# Patient 129 departs at 67.182; Length of stay: 0.938 days; Time in system: 23.866 days
# Patient 129 discharged at 67.182
# Patient 131 (Stroke) gets a bed at 67.182
# Patient 128 departs at 67.275; Length of stay: 1.062 days; Time in system: 24.367 days
# Patient 128 transferred to ESD at 67.275
# Patient 128 discharged at 67.275
# Patient 132 (ComplexNeuro) gets a bed at 67.275
# Patient 205 STROKE arrival at: 67.308
# Patient 206 ComplexNeuro arrival at: 67.480
# Patient 207 ComplexNeuro arrival at: 67.509
# Patient 208 STROKE arrival at: 67.678
# Patient 209 STROKE arrival at: 67.826
# Patient 210 STROKE arrival at: 67.853
# Patient 211 STROKE arrival at: 67.938
# Patient 99 departs at 68.243; Length of stay: 21.988 days; Time in system: 39.209 days
# Patient 99 discharged at 68.243
# Patient 133 (TIA) gets a bed at 68.243
# Patient 212 STROKE arrival at: 68.306
# Patient 213 Other arrival at: 68.340
# Patient 132 departs at 68.523; Length of stay: 1.248 days; Time in system: 24.757 days
# Patient 132 discharged at 68.523
# Patient 134 (Other) gets a bed at 68.523
# Patient 133 departs at 68.835; Length of stay: 0.592 days; Time in system: 25.001 days
# Patient 133 discharged at 68.835
# Patient 135 (Other) gets a bed at 68.835
# Patient 214 STROKE arrival at: 69.036
# Patient 134 departs at 69.225; Length of stay: 0.702 days; Time in system: 24.793 days
# Patient 134 discharged at 69.225
# Patient 136 (Stroke) gets a bed at 69.225
# Patient 215 ComplexNeuro arrival at: 69.324
# Patient 216 STROKE arrival at: 69.389
# Patient 119 departs at 69.443; Length of stay: 10.144 days; Time in system: 30.089 days
# Patient 119 discharged at 69.443
# Patient 137 (Stroke) gets a bed at 69.443
# Patient 217 STROKE arrival at: 69.444
# Patient 218 STROKE arrival at: 69.472
# Patient 219 Other arrival at: 70.137
# Patient 220 TIA arrival at: 70.264
# Patient 221 STROKE arrival at: 70.441
# Patient 222 TIA arrival at: 70.674
# Patient 104 departs at 71.585; Length of stay: 20.943 days; Time in system: 41.251 days
# Patient 104 discharged at 71.585
# Patient 138 (Stroke) gets a bed at 71.585
# Patient 135 departs at 72.066; Length of stay: 3.231 days; Time in system: 27.411 days
# Patient 135 discharged at 72.066
# Patient 139 (Stroke) gets a bed at 72.066
# Patient 223 STROKE arrival at: 72.227
# Patient 224 STROKE arrival at: 72.650
# Patient 225 STROKE arrival at: 72.719
# Patient 131 departs at 73.485; Length of stay: 6.303 days; Time in system: 29.767 days
# Patient 131 discharged at 73.485
# Patient 140 (Stroke) gets a bed at 73.485
# Patient 226 Other arrival at: 73.528
# Patient 227 ComplexNeuro arrival at: 73.623
# Patient 137 departs at 73.890; Length of stay: 4.447 days; Time in system: 28.037 days
# Patient 137 discharged at 73.890
# Patient 141 (Stroke) gets a bed at 73.890
# Patient 124 departs at 74.205; Length of stay: 10.525 days; Time in system: 32.582 days
# Patient 124 transferred to ESD at 74.205
# Patient 124 discharged at 74.205
# Patient 142 (ComplexNeuro) gets a bed at 74.205
# Patient 228 Other arrival at: 74.473
# Patient 229 STROKE arrival at: 74.662
# Patient 139 departs at 74.684; Length of stay: 2.619 days; Time in system: 28.063 days
# Patient 139 discharged at 74.684
# Patient 143 (Stroke) gets a bed at 74.684
# Patient 230 ComplexNeuro arrival at: 74.685
# Patient 231 STROKE arrival at: 74.689
# Patient 232 STROKE arrival at: 74.773
# Patient 125 departs at 75.007; Length of stay: 10.891 days; Time in system: 33.122 days
# Patient 125 discharged at 75.007
# Patient 144 (Stroke) gets a bed at 75.007
# Patient 233 Other arrival at: 75.066
# Patient 141 departs at 75.120; Length of stay: 1.230 days; Time in system: 28.167 days
# Patient 141 discharged at 75.120
# Patient 145 (Stroke) gets a bed at 75.120
# Patient 78 departs at 75.253; Length of stay: 38.416 days; Time in system: 53.199 days
# Patient 78 discharged at 75.253
# Patient 146 (ComplexNeuro) gets a bed at 75.253
# Patient 234 STROKE arrival at: 75.582
# Patient 235 ComplexNeuro arrival at: 75.705
# Patient 146 departs at 75.857; Length of stay: 0.603 days; Time in system: 27.957 days
# Patient 146 discharged at 75.857
# Patient 147 (Stroke) gets a bed at 75.857
# Patient 236 ComplexNeuro arrival at: 75.942
# Patient 147 departs at 76.977; Length of stay: 1.120 days; Time in system: 29.009 days
# Patient 147 discharged at 76.977
# Patient 148 (Other) gets a bed at 76.977
# Patient 237 STROKE arrival at: 77.259
# Patient 238 Other arrival at: 77.417
# Patient 239 STROKE arrival at: 77.551
# Patient 240 ComplexNeuro arrival at: 78.118
# Patient 241 Other arrival at: 78.305
# Patient 242 Other arrival at: 78.678
# Patient 243 Other arrival at: 78.698
# Patient 244 STROKE arrival at: 78.732
# Patient 245 ComplexNeuro arrival at: 78.745
# Patient 143 departs at 78.840; Length of stay: 4.155 days; Time in system: 31.745 days
# Patient 143 discharged at 78.840
# Patient 149 (Stroke) gets a bed at 78.840
# Patient 142 departs at 78.891; Length of stay: 4.686 days; Time in system: 31.881 days
# Patient 142 discharged at 78.891
# Patient 150 (Stroke) gets a bed at 78.891
# Patient 144 departs at 78.974; Length of stay: 3.968 days; Time in system: 31.814 days
# Patient 144 discharged at 78.974
# Patient 151 (Other) gets a bed at 78.974
# Patient 246 STROKE arrival at: 79.076
# Patient 140 departs at 79.332; Length of stay: 5.848 days; Time in system: 32.550 days
# Patient 140 discharged at 79.332
# Patient 152 (ComplexNeuro) gets a bed at 79.332
# Patient 151 departs at 79.600; Length of stay: 0.626 days; Time in system: 30.267 days
# Patient 151 discharged at 79.600
# Patient 153 (Stroke) gets a bed at 79.600
# Patient 127 departs at 79.916; Length of stay: 15.060 days; Time in system: 37.184 days
# Patient 127 discharged at 79.916
# Patient 154 (Stroke) gets a bed at 79.916
# Patient 247 ComplexNeuro arrival at: 80.157
# Patient 248 ComplexNeuro arrival at: 80.213
# Patient 249 ComplexNeuro arrival at: 80.222
# Patient 250 STROKE arrival at: 81.012
# Patient 251 STROKE arrival at: 81.207
# Patient 252 ComplexNeuro arrival at: 81.338
# Patient 253 STROKE arrival at: 81.568
# Patient 254 TIA arrival at: 81.696
# Patient 145 departs at 81.823; Length of stay: 6.703 days; Time in system: 34.394 days
# Patient 145 discharged at 81.823
# Patient 155 (ComplexNeuro) gets a bed at 81.823
# Patient 152 departs at 81.865; Length of stay: 2.532 days; Time in system: 32.431 days
# Patient 152 discharged at 81.865
# Patient 156 (Stroke) gets a bed at 81.865
# Patient 130 departs at 82.092; Length of stay: 15.526 days; Time in system: 38.482 days
# Patient 130 discharged at 82.092
# Patient 157 (Stroke) gets a bed at 82.092
# Patient 255 STROKE arrival at: 82.142
# Patient 256 STROKE arrival at: 82.202
# Patient 155 departs at 82.733; Length of stay: 0.910 days; Time in system: 31.656 days
# Patient 155 transferred to ESD at 82.733
# Patient 155 discharged at 82.733
# Patient 158 (Stroke) gets a bed at 82.733
# Patient 257 STROKE arrival at: 82.768
# Patient 258 Other arrival at: 82.884
# Patient 153 departs at 82.915; Length of stay: 3.315 days; Time in system: 33.470 days
# Patient 153 discharged at 82.915
# Patient 159 (Stroke) gets a bed at 82.915
# Patient 259 STROKE arrival at: 83.046
# Patient 260 STROKE arrival at: 83.080
# Patient 261 STROKE arrival at: 83.504
# Patient 262 Other arrival at: 83.813
# Patient 154 departs at 83.828; Length of stay: 3.912 days; Time in system: 34.274 days
# Patient 154 discharged at 83.828
# Patient 160 (ComplexNeuro) gets a bed at 83.828
# Patient 156 departs at 83.939; Length of stay: 2.074 days; Time in system: 32.835 days
# Patient 156 discharged at 83.939
# Patient 161 (Stroke) gets a bed at 83.939
# Patient 150 departs at 84.744; Length of stay: 5.853 days; Time in system: 35.524 days
# Patient 150 discharged at 84.744
# Patient 162 (Stroke) gets a bed at 84.744
# Patient 263 STROKE arrival at: 84.985
# Patient 158 departs at 85.113; Length of stay: 2.380 days; Time in system: 33.374 days
# Patient 158 discharged at 85.113
# Patient 163 (Stroke) gets a bed at 85.113
# Patient 264 Other arrival at: 85.160
# Patient 138 departs at 85.341; Length of stay: 13.756 days; Time in system: 39.066 days
# Patient 138 transferred to ESD at 85.341
# Patient 138 discharged at 85.341
# Patient 164 (ComplexNeuro) gets a bed at 85.341
# Patient 160 departs at 85.520; Length of stay: 1.692 days; Time in system: 33.760 days
# Patient 160 discharged at 85.520
# Patient 165 (Stroke) gets a bed at 85.520
# Patient 265 STROKE arrival at: 85.682
# Patient 266 Other arrival at: 85.853
# Patient 267 STROKE arrival at: 86.516
# Patient 162 departs at 86.530; Length of stay: 1.786 days; Time in system: 34.327 days
# Patient 162 discharged at 86.530
# Patient 166 (Other) gets a bed at 86.530
# Patient 268 STROKE arrival at: 86.717
# Patient 159 departs at 86.942; Length of stay: 4.027 days; Time in system: 35.196 days
# Patient 159 discharged at 86.942
# Patient 167 (ComplexNeuro) gets a bed at 86.942
# Patient 149 departs at 87.301; Length of stay: 8.461 days; Time in system: 38.870 days
# Patient 149 discharged at 87.301
# Patient 168 (Stroke) gets a bed at 87.301
# Patient 148 departs at 87.557; Length of stay: 10.580 days; Time in system: 39.580 days
# Patient 148 discharged at 87.557
# Patient 169 (ComplexNeuro) gets a bed at 87.557
# Patient 163 departs at 88.634; Length of stay: 3.521 days; Time in system: 36.257 days
# Patient 163 discharged at 88.634
# Patient 170 (Other) gets a bed at 88.634
# Patient 136 departs at 88.693; Length of stay: 19.468 days; Time in system: 43.744 days
# Patient 136 transferred to ESD at 88.693
# Patient 136 discharged at 88.693
# Patient 171 (Stroke) gets a bed at 88.693
# Patient 169 departs at 88.791; Length of stay: 1.234 days; Time in system: 34.469 days
# Patient 169 discharged at 88.791
# Patient 172 (Other) gets a bed at 88.791
# Patient 167 departs at 88.843; Length of stay: 1.901 days; Time in system: 35.379 days
# Patient 167 discharged at 88.843
# Patient 173 (Other) gets a bed at 88.843
# Patient 269 Other arrival at: 88.917
# Patient 170 departs at 89.464; Length of stay: 0.831 days; Time in system: 34.531 days
# Patient 170 discharged at 89.464
# Patient 174 (ComplexNeuro) gets a bed at 89.464
# Patient 164 departs at 89.526; Length of stay: 4.185 days; Time in system: 36.739 days
# Patient 164 discharged at 89.526
# Patient 175 (Other) gets a bed at 89.526
# Patient 270 STROKE arrival at: 89.767
# Patient 157 departs at 89.881; Length of stay: 7.789 days; Time in system: 38.382 days
# Patient 157 transferred to ESD at 89.881
# Patient 157 discharged at 89.881
# Patient 176 (ComplexNeuro) gets a bed at 89.881
# Patient 171 departs at 89.929; Length of stay: 1.236 days; Time in system: 34.850 days
# Patient 171 transferred to ESD at 89.929
# Patient 171 discharged at 89.929
# Patient 177 (Stroke) gets a bed at 89.929
# Patient 173 departs at 90.008; Length of stay: 1.164 days; Time in system: 33.354 days
# Patient 173 discharged at 90.008
# Patient 178 (Stroke) gets a bed at 90.008
# Patient 271 STROKE arrival at: 90.059
# Patient 272 STROKE arrival at: 90.205
# Patient 273 ComplexNeuro arrival at: 90.540
# Patient 176 departs at 90.715; Length of stay: 0.835 days; Time in system: 33.337 days
# Patient 176 discharged at 90.715
# Patient 179 (TIA) gets a bed at 90.715
# Patient 274 STROKE arrival at: 90.861
# Patient 275 Other arrival at: 90.986
# Patient 276 STROKE arrival at: 91.014
# Patient 277 STROKE arrival at: 91.243
# Patient 278 Other arrival at: 91.376
# Patient 177 departs at 91.549; Length of stay: 1.620 days; Time in system: 34.014 days
# Patient 177 discharged at 91.549
# Patient 180 (Stroke) gets a bed at 91.549
# Patient 178 departs at 91.820; Length of stay: 1.812 days; Time in system: 34.103 days
# Patient 178 discharged at 91.820
# Patient 181 (Stroke) gets a bed at 91.820
# Patient 279 Other arrival at: 92.154
# Patient 168 departs at 92.639; Length of stay: 5.338 days; Time in system: 38.621 days
# Patient 168 discharged at 92.639
# Patient 182 (Stroke) gets a bed at 92.639
# Patient 280 STROKE arrival at: 92.854
# Patient 161 departs at 92.916; Length of stay: 8.977 days; Time in system: 40.803 days
# Patient 161 discharged at 92.916
# Patient 183 (Stroke) gets a bed at 92.916
# Patient 281 STROKE arrival at: 93.129
# Patient 282 ComplexNeuro arrival at: 93.398
# Patient 172 departs at 93.432; Length of stay: 4.641 days; Time in system: 37.636 days
# Patient 172 discharged at 93.432
# Patient 184 (ComplexNeuro) gets a bed at 93.432
# Patient 283 STROKE arrival at: 93.475
# Patient 179 departs at 93.569; Length of stay: 2.854 days; Time in system: 34.854 days
# Patient 179 discharged at 93.569
# Patient 185 (Other) gets a bed at 93.569
# Patient 284 STROKE arrival at: 94.007
# Patient 183 departs at 94.010; Length of stay: 1.094 days; Time in system: 33.616 days
# Patient 183 discharged at 94.010
# Patient 186 (ComplexNeuro) gets a bed at 94.010
# Patient 285 STROKE arrival at: 94.033
# Patient 286 ComplexNeuro arrival at: 94.282
# Patient 180 departs at 94.312; Length of stay: 2.763 days; Time in system: 35.436 days
# Patient 180 discharged at 94.312
# Patient 187 (Stroke) gets a bed at 94.312
# Patient 166 departs at 94.717; Length of stay: 8.187 days; Time in system: 41.880 days
# Patient 166 discharged at 94.717
# Patient 188 (Stroke) gets a bed at 94.717
# Patient 287 STROKE arrival at: 94.906
# Patient 175 departs at 95.072; Length of stay: 5.546 days; Time in system: 37.871 days
# Patient 175 discharged at 95.072
# Patient 189 (Stroke) gets a bed at 95.072
# Patient 288 STROKE arrival at: 95.336
# Patient 289 Other arrival at: 95.445
# Patient 185 departs at 95.544; Length of stay: 1.974 days; Time in system: 34.936 days
# Patient 185 discharged at 95.544
# Patient 190 (Stroke) gets a bed at 95.544
# Patient 182 departs at 96.214; Length of stay: 3.575 days; Time in system: 36.276 days
# Patient 182 discharged at 96.214
# Patient 191 (Stroke) gets a bed at 96.214
# Patient 290 STROKE arrival at: 96.254
# Patient 291 STROKE arrival at: 96.312
# Patient 292 ComplexNeuro arrival at: 96.456
# Patient 293 STROKE arrival at: 96.677
# Patient 294 STROKE arrival at: 96.680
# Patient 184 departs at 96.960; Length of stay: 3.528 days; Time in system: 36.423 days
# Patient 184 discharged at 96.960
# Patient 192 (Other) gets a bed at 96.960
# Patient 295 STROKE arrival at: 97.347
# Patient 296 ComplexNeuro arrival at: 97.694
# Patient 165 departs at 97.821; Length of stay: 12.302 days; Time in system: 45.014 days
# Patient 165 discharged at 97.821
# Patient 193 (Stroke) gets a bed at 97.821
# Patient 192 departs at 97.895; Length of stay: 0.936 days; Time in system: 35.575 days
# Patient 192 discharged at 97.895
# Patient 194 (Stroke) gets a bed at 97.895
# Patient 297 Other arrival at: 98.663
# Patient 298 STROKE arrival at: 98.955
# Patient 193 departs at 99.059; Length of stay: 1.238 days; Time in system: 36.102 days
# Patient 193 transferred to ESD at 99.059
# Patient 193 discharged at 99.059
# Patient 195 (Stroke) gets a bed at 99.059
# Patient 191 departs at 99.179; Length of stay: 2.965 days; Time in system: 37.383 days
# Patient 191 discharged at 99.179
# Patient 196 (Stroke) gets a bed at 99.179
# Patient 299 ComplexNeuro arrival at: 99.229
# Patient 300 STROKE arrival at: 99.238
# Patient 301 STROKE arrival at: 99.318
# Patient 302 STROKE arrival at: 99.461
# Patient 303 ComplexNeuro arrival at: 99.476
# Patient 304 ComplexNeuro arrival at: 99.791
# end of run. simulation clock time = 100
# {'n_stroke': 0, 'n_tia': 0, 'n_cn': 0, 'n_other': 0}

# %% [markdown]
# ## Running metrics

# %%
# check between minutes and days

# %%
discharged_patients = [p for p in model.patients if hasattr(p, 'length_of_stay') and p.length_of_stay > 0]

mean_length_of_stay = np.mean([p.length_of_stay for p in discharged_patients])

print(f"Mean Length of Stay: {mean_length_of_stay:.2f} days")
# Out:
# Mean Length of Stay: 4.93 days

# %%
# Ensure there are patients in the system
if model.patients:

    # Group patients by their type (e.g., "Stroke", "TIA", etc.)
    patient_types = set(p.patient_type for p in model.patients)  # Get unique patient types
    for patient_type in patient_types:
        # Filter patients by type
        patients_by_type = [p for p in model.patients if p.patient_type == patient_type]

        # 1. Mean time in system (from arrival to discharge)
        mean_time_in_system = np.mean([p.time_in_system for p in patients_by_type])

        # 2. Mean length of stay (from bed assignment to discharge)
        discharged_patients = [p for p in patients_by_type if hasattr(p, 'length_of_stay') and p.length_of_stay > 0]
        mean_length_of_stay = np.mean([p.length_of_stay for p in discharged_patients]) if discharged_patients else 0

        # 3. Proportion of patients who met the 4-hour target
        four_hours = np.mean([p.four_hour_target for p in patients_by_type])

        # 4. Mean time to bed (arrival → bed assignment)
        mean_time_to_bed = np.mean([p.time_to_bed for p in patients_by_type])

        # 5. Mean time to ESD transfer (bed → ESD transfer, only for transferred patients)
        patients_with_esd = [p for p in patients_by_type if p.time_to_esd > 0]
        mean_time_to_esd = np.mean([p.time_to_esd - p.time_to_bed for p in patients_with_esd]) if patients_with_esd else 0

        # Print results for this patient type
        print(f'\nResults for {patient_type} Patients\n------------------')
        print(f'Mean Time in System (days): {mean_time_in_system:.2f}')
        print(f'Mean Length of Stay (days): {mean_length_of_stay:.2f}')  # ✅ Corrected Calculation
        print(f'Mean Time to Bed (days): {mean_time_to_bed:.2f}')
        print(f'Mean Time to ESD (days): {mean_time_to_esd:.2f}' if patients_with_esd else "No ESD transfers")
        print(f'Proportion Discharged Before 4 Hours: {four_hours:.2f}')
else:
    print("No patients recorded in this simulation run.")
# Out:
# Results for Other Patients
# ------------------
# Mean Time in System (days): 12.41
# Mean Length of Stay (days): 3.21
# Mean Time to Bed (days): 10.23
# Mean Time to ESD (days): 43.78
# Proportion Discharged Before 4 Hours: 0.68
#
# Results for ComplexNeuro Patients
# ------------------
# Mean Time in System (days): 10.34
# Mean Length of Stay (days): 2.86
# Mean Time to Bed (days): 10.00
# Mean Time to ESD (days): 25.14
# Proportion Discharged Before 4 Hours: 0.53
#
# Results for Stroke Patients
# ------------------
# Mean Time in System (days): 14.13
# Mean Length of Stay (days): 6.41
# Mean Time to Bed (days): 11.75
# Mean Time to ESD (days): 42.08
# Proportion Discharged Before 4 Hours: 0.61
#
# Results for TIA Patients
# ------------------
# Mean Time in System (days): 12.15
# Mean Length of Stay (days): 1.37
# Mean Time to Bed (days): 11.24
# Mean Time to ESD (days): 10.93
# Proportion Discharged Before 4 Hours: 0.67

# %%
# new

# %%
import pandas as pd
import numpy as np
import simpy

def summarize_results(model):
    """ Generate a summary DataFrame with mean results for each patient type. """

    if not model.patients:
        print("⚠ No patients recorded in this simulation run.")
        return pd.DataFrame()  # Return an empty DataFrame

    patient_types = set(p.patient_type for p in model.patients)  # Unique patient types
    summary_data = {}

    for patient_type in patient_types:
        patients_by_type = [p for p in model.patients if p.patient_type == patient_type]

        # Compute mean length of stay (only for patients with a valid length_of_stay)
        discharged_patients = [p for p in patients_by_type if hasattr(p, 'length_of_stay') and p.length_of_stay > 0]
        mean_length_of_stay = np.mean([p.length_of_stay for p in discharged_patients]) if discharged_patients else np.nan

        summary_data[patient_type] = mean_length_of_stay  # Store in dictionary

    # Convert dictionary to DataFrame with a single row
    return pd.DataFrame([summary_data])

TRACE = False 

def single_run(scenario, rc_period=1445):
    ''' Runs the model for a single scenario and returns results as a DataFrame. '''
    
    env = simpy.Environment()
    model = AcuteStrokeUnit(env, scenario)

    # Start patient arrival processes
    env.process(model.stroke_arrivals_generator())
    env.process(model.tia_arrivals_generator())
    env.process(model.complexneuro_arrivals_generator())
    env.process(model.other_arrivals_generator())

    env.run(until=rc_period)  # Run simulation

    return summarize_results(model)  # Return DataFrame with results

# %%
# Create the default scenario
args = Scenario()

# Run the model
print('Running simulation ...', end=' => ')
results = single_run(args)
print('simulation complete.')

# Display the DataFrame
results
# Out:
# Running simulation ... => simulation complete.
#       Other  ComplexNeuro    Stroke       TIA
# 0  3.814586      4.003766  7.365782  1.495207

# %%
# REPS

# %%
from joblib import Parallel, delayed
import pandas as pd
import numpy as np

def multiple_replications(scenario, rc_period=1445, n_reps=150, n_jobs=-1):
    """
    Run multiple independent replications of the model and return results in a DataFrame.
    Each row represents a single replication, and columns represent patient types.
    """
    # Run multiple replications in parallel
    res = Parallel(n_jobs=n_jobs)(
        delayed(single_run)(Scenario()) for _ in range(n_reps) 
    )
    # Concatenate results, keeping each replication as a row
    df_results = pd.concat(res, keys=range(1, n_reps + 1), names=["rep"])
    
    # Reset index to have 'rep' as a column
    df_results.reset_index(level=0, inplace=True)

    return df_results.set_index("rep")  # Final format with replications as rows

# Run multiple replications
args = Scenario()
print("Running multiple replications ... => ", end="")
results = multiple_replications(args, rc_period=1445, n_reps=150, n_jobs=-1)
print("Simulation complete.")

# Display the results
results
# Out:
# Running multiple replications ... => Simulation complete.
#        Stroke  ComplexNeuro     Other       TIA
# rep
# 1    7.365782      4.003766  3.814586  1.495207
# 2    7.365782      4.003766  3.814586  1.495207
# 3    7.365782      4.003766  3.814586  1.495207
# 4    7.365782      4.003766  3.814586  1.495207
# 5    7.365782      4.003766  3.814586  1.495207
# ..        ...           ...       ...       ...
# 146  7.365782      4.003766  3.814586  1.495207
# 147  7.365782      4.003766  3.814586  1.495207
# 148  7.365782      4.003766  3.814586  1.495207
# 149  7.365782      4.003766  3.814586  1.495207
# 150  7.365782      4.003766  3.814586  1.495207
#
# [150 rows x 4 columns]

# %%
results.mean()
# Out:
# Stroke          7.365782
# ComplexNeuro    4.003766
# Other           3.814586
# TIA             1.495207
# dtype: float64
